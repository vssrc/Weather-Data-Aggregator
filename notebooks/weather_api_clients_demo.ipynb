# %% [markdown]
# # Weather API Client Demos
# Use this notebook to verify the local weather API wrappers for Tomorrow.io, Open-Meteo, Visual Crossing, NOAA CDO, WeatherAPI.com, OpenWeather, and Weatherbit.

# %%
import json
from pathlib import Path
import sys
PROJECT_ROOT = Path('..').resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
CONFIG_PATH = Path('../weather_config.json')
CONFIG = json.loads(CONFIG_PATH.read_text())
LOCATIONS = CONFIG.get('locations', {})
LOCATION_ITEMS = []
for name, coords in LOCATIONS.items():
    try:
        lat = float(coords['lat'])
        lon = float(coords['lon'])
    except (KeyError, TypeError, ValueError) as exc:
        raise ValueError(f"Invalid coordinates for location '{name}'. Provide numeric 'lat' and 'lon'.") from exc
    LOCATION_ITEMS.append((name, lat, lon))
if not LOCATION_ITEMS:
    raise ValueError("Define at least one location under 'locations' in weather_config.json.")
def iter_locations():
    for item in LOCATION_ITEMS:
        yield item
LOCATION_ITEMS
# Out:
# [('new_york_ny', 40.78, -73.97),
#  ('austin_tx', 30.18, -97.68),
#  ('chicago_midway_il', 41.78, -87.76),
#  ('los_angeles_ca', 33.94, -118.39),
#  ('miami_fl', 25.79, -80.32)]

# %%
import datetime as dt
import json
import logging
import threading
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path
from typing import Dict, Iterable, List, Optional, Sequence, Tuple, Union

import matplotlib
matplotlib.use("Agg")

import matplotlib.pyplot as plt  # noqa: E402  (import after backend selection)
import numpy as np  # noqa: E402
import pandas as pd  # noqa: E402

from clients.copernicus_cds_client import CopernicusCdsClient
from clients.iem_asos_client import IemAsosClient
from clients.meteostat_client import MeteostatClient
from clients.nasa_power_client import NasaPowerClient
from clients.noaa_access_client import NoaaIsdClient, NoaaLcdClient
from clients.open_meteo_client import OpenMeteoClient
from clients.openweather_client import OpenWeatherClient
from clients.tomorrow_io_client import TomorrowIOClient
from clients.visual_crossing_client import VisualCrossingClient
from clients.weatherapi_com_client import WeatherApiClient
from clients.weatherbit_client import WeatherbitClient

# %% [markdown]
# ## Tomorrow.io client
# The client reads API keys and defaults from `weather_config.json`. Update the config file before running the calls below.

# %%
from clients.tomorrow_io_client import TomorrowIOClient

client = TomorrowIOClient(config_path="../weather_config.json")
client.base_url
# Out:
# 'https://api.tomorrow.io/v4'

# %% [markdown]
# ## Forecast example
# Requests the next 6 hours of weather data for Boston, MA. Adjust the location or fields for your use case.

# %%
forecast_results = {}
for name, lat, lon in iter_locations():
    request = {
        "location": f"{lat},{lon}",
        "timeframe_hours": 6,
        "fields": ["temperature", "humidity", "windSpeed"],
        "timesteps": ["1h"],
        "units": "metric",
        "timezone": "UTC",
    }
    forecast_results[name] = {
        "single": client.get_forecast(**request),
        "batch": client.get_forecast_batch([request])[0],
    }
forecast_results
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[3], line 12
#       2 for name, lat, lon in iter_locations():
#       3     request = {
#       4         "location": f"{lat},{lon}",
#       5         "timeframe_hours": 6,
#    (...)
#       9         "timezone": "UTC",
#      10     }
#      11     forecast_results[name] = {
# ---> 12         "single": client.get_forecast(**request),
#      13         "batch": client.get_forecast_batch([request])[0],
#      14     }
#      15 forecast_results
#
# File D:\DL Project\clients\tomorrow_io_client.py:223, in TomorrowIOClient.get_forecast(self, location, timeframe_hours, fields, timesteps, units, timezone, start_time, end_time)
#     220 start = start_time or now_utc
#     221 end = end_time or (now_utc + dt.timedelta(hours=timeframe_hours))
# --> 223 return self._request_timelines(
#     224     location=location,
#     225     fields=fields,
#     226     timesteps=timesteps,
#     227     units=units,
#     228     timezone=timezone,
#     229     start_time=start,
#     230     end_time=end,
#     231 )
#
# File D:\DL Project\clients\tomorrow_io_client.py:160, in TomorrowIOClient._request_timelines(self, location, fields, timesteps, units, timezone, start_time, end_time)
#     153 response = requests.get(
#     154     f"{self.base_url}/timelines",
#     155     params=params,
#     156     timeout=30,
#     157     headers=build_request_headers(),
#     158 )
#     159 if response.status_code >= 400:
# --> 160     raise ApiError(f"Tomorrow.io error {response.status_code}: {response.text}")
#     161 try:
#     162     return response.json()
#
# ApiError: Tomorrow.io error 429: {"code":429001,"type":"Too Many Calls","message":"The request limit for this resource has been reached for the current rate limit window. Wait and retry the operation, or examine your API request volume."}

# %% [markdown]
# ## Historical example
# Fetches the last 24 hours leading up to the current time. `start` and `end` must be in ISO-8601.

# %%
import datetime as dt

historical_results = {}
end_time = dt.datetime.now(dt.timezone.utc).replace(microsecond=0)
start_time = end_time - dt.timedelta(hours=24)

for name, lat, lon in iter_locations():
    request = {
        "location": f"{lat},{lon}",
        "start_time": start_time,
        "end_time": end_time,
        "fields": ["temperature", "humidity", "windSpeed"],
        "timesteps": ["1h"],
        "units": "metric",
        "timezone": "UTC",
    }
    historical_results[name] = {
        "single": client.get_historical(**request),
        "batch": client.get_historical_batch([request])[0],
    }
historical_results

# %% [markdown]
# ## Next steps
# Explore the payloads, convert them to pandas DataFrames, or export to other formats as needed.

# %% [markdown]
# ## Open-Meteo client
# Open-Meteo does not require an API key. Defaults (timezone, hourly variables, units) come from `weather_config.json`.

# %%
from clients.open_meteo_client import OpenMeteoClient

open_meteo = OpenMeteoClient(config_path="../weather_config.json")
open_meteo.forecast_url
# Out:
# 'https://api.open-meteo.com/v1/forecast'

# %% [markdown]
# ## Open-Meteo forecast example
# Requests the upcoming 2 days of data for Boston, MA. Adjust location, variables, or duration to suit your needs.

# %%
open_meteo_forecasts = {}
for name, lat, lon in iter_locations():
    request = {
        "location": (lat, lon),
        "hourly": ["temperature_2m", "relative_humidity_2m", "wind_speed_10m"],
        "daily": ["temperature_2m_max", "temperature_2m_min"],
        "forecast_days": 2,
    }
    open_meteo_forecasts[name] = {
        "single": open_meteo.get_forecast(**request),
        "batch": open_meteo.get_forecast_batch([request])[0],
    }
open_meteo_forecasts
# Out:
# {'new_york_ny': {'single': {'latitude': 40.78858,
#    'longitude': -73.96611,
#    'generationtime_ms': 0.11396408081054688,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 40.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [9.3,
#      9.8,
#      9.6,
#      7.6,
#      6.7,
#      5.8,
#      5.5,
#      5.0,
#      4.7,
#      4.6,
#      4.2,
#      3.6,
#      3.4,
#      5.4,
#      7.3,
#      8.7,
#      9.6,
#      8.5,
#      9.0,
#      9.6,
#      9.6,
#      8.6,
#      6.8,
#      5.4,
#      4.4,
#      4.4,
#      3.7,
#      3.6,
#      3.3,
#      2.7,
#      2.4,
#      2.1,
#      1.7,
#      1.4,
#      0.9,
#      0.6,
#      0.2,
#      2.7,
#      4.2,
#      5.8,
#      6.4,
#      6.7,
#      6.6,
#      7.6,
#      7.1,
#      6.4,
#      4.8,
#      3.9],
#     'relative_humidity_2m': [42,
#      47,
#      49,
#      61,
#      66,
#      71,
#      74,
#      78,
#      79,
#      80,
#      79,
#      82,
#      80,
#      75,
#      68,
#      59,
#      53,
#      56,
#      45,
#      43,
#      43,
#      53,
#      59,
#      65,
#      68,
#      60,
#      65,
#      67,
#      67,
#      71,
#      72,
#      74,
#      76,
#      78,
#      80,
#      81,
#      84,
#      78,
#      75,
#      69,
#      68,
#      67,
#      67,
#      54,
#      52,
#      55,
#      58,
#      59],
#     'wind_speed_10m': [13.8,
#      20.4,
#      17.9,
#      9.2,
#      9.3,
#      8.9,
#      11.7,
#      12.3,
#      13.2,
#      13.8,
#      12.8,
#      10.9,
#      12.9,
#      16.9,
#      22.5,
#      24.0,
#      25.1,
#      29.2,
#      24.9,
#      22.3,
#      22.2,
#      26.0,
#      18.3,
#      9.0,
#      8.0,
#      13.4,
#      11.6,
#      17.3,
#      16.9,
#      14.1,
#      14.0,
#      13.5,
#      14.0,
#      13.1,
#      9.6,
#      10.8,
#      9.9,
#      14.3,
#      15.5,
#      19.9,
#      19.2,
#      19.4,
#      22.1,
#      21.1,
#      22.7,
#      21.6,
#      12.1,
#      10.7]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [9.8, 7.6],
#     'temperature_2m_min': [3.4, 0.2]}},
#   'batch': {'latitude': 40.78858,
#    'longitude': -73.96611,
#    'generationtime_ms': 0.10073184967041016,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 40.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [9.3,
#      9.8,
#      9.6,
#      7.6,
#      6.7,
#      5.8,
#      5.5,
#      5.0,
#      4.7,
#      4.6,
#      4.2,
#      3.6,
#      3.4,
#      5.4,
#      7.3,
#      8.7,
#      9.6,
#      8.5,
#      9.0,
#      9.6,
#      9.6,
#      8.6,
#      6.8,
#      5.4,
#      4.4,
#      4.4,
#      3.7,
#      3.6,
#      3.3,
#      2.7,
#      2.4,
#      2.1,
#      1.7,
#      1.4,
#      0.9,
#      0.6,
#      0.2,
#      2.7,
#      4.2,
#      5.8,
#      6.4,
#      6.7,
#      6.6,
#      7.6,
#      7.1,
#      6.4,
#      4.8,
#      3.9],
#     'relative_humidity_2m': [42,
#      47,
#      49,
#      61,
#      66,
#      71,
#      74,
#      78,
#      79,
#      80,
#      79,
#      82,
#      80,
#      75,
#      68,
#      59,
#      53,
#      56,
#      45,
#      43,
#      43,
#      53,
#      59,
#      65,
#      68,
#      60,
#      65,
#      67,
#      67,
#      71,
#      72,
#      74,
#      76,
#      78,
#      80,
#      81,
#      84,
#      78,
#      75,
#      69,
#      68,
#      67,
#      67,
#      54,
#      52,
#      55,
#      58,
#      59],
#     'wind_speed_10m': [13.8,
#      20.4,
#      17.9,
#      9.2,
#      9.3,
#      8.9,
#      11.7,
#      12.3,
#      13.2,
#      13.8,
#      12.8,
#      10.9,
#      12.9,
#      16.9,
#      22.5,
#      24.0,
#      25.1,
#      29.2,
#      24.9,
#      22.3,
#      22.2,
#      26.0,
#      18.3,
#      9.0,
#      8.0,
#      13.4,
#      11.6,
#      17.3,
#      16.9,
#      14.1,
#      14.0,
#      13.5,
#      14.0,
#      13.1,
#      9.6,
#      10.8,
#      9.9,
#      14.3,
#      15.5,
#      19.9,
#      19.2,
#      19.4,
#      22.1,
#      21.1,
#      22.7,
#      21.6,
#      12.1,
#      10.7]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [9.8, 7.6],
#     'temperature_2m_min': [3.4, 0.2]}}},
#  'austin_tx': {'single': {'latitude': 30.189165,
#    'longitude': -97.69134,
#    'generationtime_ms': 0.09644031524658203,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 146.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [24.7,
#      22.1,
#      21.0,
#      20.2,
#      19.2,
#      18.5,
#      17.9,
#      17.3,
#      16.6,
#      16.2,
#      15.7,
#      15.2,
#      14.8,
#      14.3,
#      14.9,
#      20.5,
#      23.0,
#      25.0,
#      26.7,
#      27.8,
#      28.5,
#      28.8,
#      28.6,
#      27.2,
#      24.6,
#      23.1,
#      23.5,
#      21.9,
#      20.8,
#      20.0,
#      19.3,
#      18.4,
#      17.6,
#      17.2,
#      16.8,
#      16.3,
#      15.9,
#      15.7,
#      17.4,
#      20.4,
#      23.0,
#      24.8,
#      26.3,
#      27.6,
#      28.1,
#      28.4,
#      28.2,
#      27.0],
#     'relative_humidity_2m': [43,
#      54,
#      62,
#      65,
#      74,
#      81,
#      83,
#      83,
#      84,
#      88,
#      88,
#      90,
#      91,
#      93,
#      100,
#      80,
#      66,
#      57,
#      48,
#      42,
#      39,
#      37,
#      35,
#      38,
#      42,
#      47,
#      51,
#      64,
#      74,
#      80,
#      82,
#      86,
#      90,
#      92,
#      92,
#      92,
#      93,
#      93,
#      96,
#      84,
#      68,
#      59,
#      50,
#      43,
#      40,
#      39,
#      38,
#      40],
#     'wind_speed_10m': [7.0,
#      8.5,
#      9.4,
#      7.9,
#      6.6,
#      6.5,
#      9.2,
#      6.0,
#      6.2,
#      5.8,
#      2.1,
#      0.0,
#      2.3,
#      1.8,
#      1.5,
#      17.9,
#      22.8,
#      22.5,
#      22.1,
#      21.3,
#      20.5,
#      20.2,
#      20.7,
#      16.2,
#      12.6,
#      12.7,
#      15.3,
#      22.6,
#      19.9,
#      15.1,
#      12.6,
#      9.6,
#      8.8,
#      8.2,
#      8.1,
#      6.5,
#      6.5,
#      8.3,
#      7.7,
#      17.0,
#      21.1,
#      22.0,
#      20.2,
#      19.9,
#      18.9,
#      17.6,
#      17.3,
#      12.7]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [28.8, 28.4],
#     'temperature_2m_min': [14.3, 15.7]}},
#   'batch': {'latitude': 30.189165,
#    'longitude': -97.69134,
#    'generationtime_ms': 0.07915496826171875,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 146.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [24.7,
#      22.1,
#      21.0,
#      20.2,
#      19.2,
#      18.5,
#      17.9,
#      17.3,
#      16.6,
#      16.2,
#      15.7,
#      15.2,
#      14.8,
#      14.3,
#      14.9,
#      20.5,
#      23.0,
#      25.0,
#      26.7,
#      27.8,
#      28.5,
#      28.8,
#      28.6,
#      27.2,
#      24.6,
#      23.1,
#      23.5,
#      21.9,
#      20.8,
#      20.0,
#      19.3,
#      18.4,
#      17.6,
#      17.2,
#      16.8,
#      16.3,
#      15.9,
#      15.7,
#      17.4,
#      20.4,
#      23.0,
#      24.8,
#      26.3,
#      27.6,
#      28.1,
#      28.4,
#      28.2,
#      27.0],
#     'relative_humidity_2m': [43,
#      54,
#      62,
#      65,
#      74,
#      81,
#      83,
#      83,
#      84,
#      88,
#      88,
#      90,
#      91,
#      93,
#      100,
#      80,
#      66,
#      57,
#      48,
#      42,
#      39,
#      37,
#      35,
#      38,
#      42,
#      47,
#      51,
#      64,
#      74,
#      80,
#      82,
#      86,
#      90,
#      92,
#      92,
#      92,
#      93,
#      93,
#      96,
#      84,
#      68,
#      59,
#      50,
#      43,
#      40,
#      39,
#      38,
#      40],
#     'wind_speed_10m': [7.0,
#      8.5,
#      9.4,
#      7.9,
#      6.6,
#      6.5,
#      9.2,
#      6.0,
#      6.2,
#      5.8,
#      2.1,
#      0.0,
#      2.3,
#      1.8,
#      1.5,
#      17.9,
#      22.8,
#      22.5,
#      22.1,
#      21.3,
#      20.5,
#      20.2,
#      20.7,
#      16.2,
#      12.6,
#      12.7,
#      15.3,
#      22.6,
#      19.9,
#      15.1,
#      12.6,
#      9.6,
#      8.8,
#      8.2,
#      8.1,
#      6.5,
#      6.5,
#      8.3,
#      7.7,
#      17.0,
#      21.1,
#      22.0,
#      20.2,
#      19.9,
#      18.9,
#      17.6,
#      17.3,
#      12.7]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [28.8, 28.4],
#     'temperature_2m_min': [14.3, 15.7]}}},
#  'chicago_midway_il': {'single': {'latitude': 41.780952,
#    'longitude': -87.77293,
#    'generationtime_ms': 0.1112222671508789,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 187.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [8.3,
#      7.0,
#      6.3,
#      5.4,
#      4.8,
#      4.3,
#      3.8,
#      3.2,
#      2.8,
#      2.2,
#      1.8,
#      1.4,
#      0.9,
#      0.4,
#      2.5,
#      5.5,
#      7.8,
#      9.4,
#      10.8,
#      11.9,
#      12.1,
#      12.4,
#      10.1,
#      8.6,
#      8.2,
#      7.7,
#      7.4,
#      7.3,
#      7.1,
#      6.7,
#      5.4,
#      4.8,
#      4.4,
#      4.2,
#      4.2,
#      4.3,
#      4.3,
#      4.2,
#      6.2,
#      9.5,
#      11.5,
#      13.4,
#      15.1,
#      16.8,
#      17.9,
#      17.8,
#      15.9,
#      13.8],
#     'relative_humidity_2m': [51,
#      62,
#      63,
#      66,
#      66,
#      69,
#      73,
#      75,
#      74,
#      75,
#      76,
#      76,
#      78,
#      80,
#      80,
#      69,
#      62,
#      57,
#      50,
#      42,
#      43,
#      36,
#      49,
#      50,
#      52,
#      55,
#      58,
#      59,
#      60,
#      58,
#      57,
#      58,
#      60,
#      66,
#      70,
#      73,
#      77,
#      82,
#      84,
#      82,
#      80,
#      77,
#      73,
#      69,
#      68,
#      69,
#      76,
#      82],
#     'wind_speed_10m': [10.9,
#      8.5,
#      10.7,
#      10.4,
#      10.8,
#      11.5,
#      10.4,
#      10.5,
#      9.5,
#      9.7,
#      9.7,
#      9.4,
#      9.0,
#      8.4,
#      5.9,
#      6.6,
#      4.0,
#      3.7,
#      5.6,
#      8.6,
#      11.4,
#      9.1,
#      8.9,
#      7.9,
#      7.7,
#      7.3,
#      7.6,
#      8.6,
#      8.3,
#      8.8,
#      10.5,
#      10.1,
#      10.4,
#      10.4,
#      10.8,
#      10.2,
#      10.2,
#      9.5,
#      9.8,
#      13.0,
#      12.8,
#      12.7,
#      13.2,
#      12.2,
#      12.5,
#      11.2,
#      7.8,
#      9.4]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [12.4, 17.9],
#     'temperature_2m_min': [0.4, 4.2]}},
#   'batch': {'latitude': 41.780952,
#    'longitude': -87.77293,
#    'generationtime_ms': 0.09357929229736328,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 187.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [8.3,
#      7.0,
#      6.3,
#      5.4,
#      4.8,
#      4.3,
#      3.8,
#      3.2,
#      2.8,
#      2.2,
#      1.8,
#      1.4,
#      0.9,
#      0.4,
#      2.5,
#      5.5,
#      7.8,
#      9.4,
#      10.8,
#      11.9,
#      12.1,
#      12.4,
#      10.1,
#      8.6,
#      8.2,
#      7.7,
#      7.4,
#      7.3,
#      7.1,
#      6.7,
#      5.4,
#      4.8,
#      4.4,
#      4.2,
#      4.2,
#      4.3,
#      4.3,
#      4.2,
#      6.2,
#      9.5,
#      11.5,
#      13.4,
#      15.1,
#      16.8,
#      17.9,
#      17.8,
#      15.9,
#      13.8],
#     'relative_humidity_2m': [51,
#      62,
#      63,
#      66,
#      66,
#      69,
#      73,
#      75,
#      74,
#      75,
#      76,
#      76,
#      78,
#      80,
#      80,
#      69,
#      62,
#      57,
#      50,
#      42,
#      43,
#      36,
#      49,
#      50,
#      52,
#      55,
#      58,
#      59,
#      60,
#      58,
#      57,
#      58,
#      60,
#      66,
#      70,
#      73,
#      77,
#      82,
#      84,
#      82,
#      80,
#      77,
#      73,
#      69,
#      68,
#      69,
#      76,
#      82],
#     'wind_speed_10m': [10.9,
#      8.5,
#      10.7,
#      10.4,
#      10.8,
#      11.5,
#      10.4,
#      10.5,
#      9.5,
#      9.7,
#      9.7,
#      9.4,
#      9.0,
#      8.4,
#      5.9,
#      6.6,
#      4.0,
#      3.7,
#      5.6,
#      8.6,
#      11.4,
#      9.1,
#      8.9,
#      7.9,
#      7.7,
#      7.3,
#      7.6,
#      8.6,
#      8.3,
#      8.8,
#      10.5,
#      10.1,
#      10.4,
#      10.4,
#      10.8,
#      10.2,
#      10.2,
#      9.5,
#      9.8,
#      13.0,
#      12.8,
#      12.7,
#      13.2,
#      12.2,
#      12.5,
#      11.2,
#      7.8,
#      9.4]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [12.4, 17.9],
#     'temperature_2m_min': [0.4, 4.2]}}},
#  'los_angeles_ca': {'single': {'latitude': 33.945427,
#    'longitude': -118.40222,
#    'generationtime_ms': 0.0890493392944336,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 30.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [18.8,
#      17.5,
#      16.7,
#      15.9,
#      15.5,
#      15.2,
#      14.7,
#      14.5,
#      14.7,
#      14.7,
#      14.5,
#      13.6,
#      12.8,
#      12.8,
#      13.0,
#      13.1,
#      13.6,
#      15.6,
#      18.2,
#      19.0,
#      19.8,
#      19.8,
#      18.7,
#      18.1,
#      17.6,
#      17.1,
#      16.4,
#      15.1,
#      14.6,
#      14.7,
#      15.1,
#      15.6,
#      15.4,
#      15.3,
#      15.2,
#      14.4,
#      14.4,
#      14.7,
#      14.4,
#      14.8,
#      14.9,
#      15.6,
#      16.1,
#      16.9,
#      16.7,
#      16.5,
#      16.7,
#      16.6],
#     'relative_humidity_2m': [82,
#      88,
#      85,
#      87,
#      86,
#      89,
#      88,
#      89,
#      90,
#      91,
#      97,
#      95,
#      96,
#      100,
#      100,
#      100,
#      100,
#      93,
#      81,
#      77,
#      74,
#      73,
#      81,
#      82,
#      83,
#      83,
#      86,
#      91,
#      93,
#      93,
#      92,
#      90,
#      94,
#      97,
#      97,
#      92,
#      92,
#      91,
#      88,
#      88,
#      90,
#      89,
#      89,
#      87,
#      89,
#      90,
#      88,
#      88],
#     'wind_speed_10m': [2.6,
#      8.8,
#      3.6,
#      6.1,
#      3.5,
#      7.1,
#      5.0,
#      5.2,
#      6.6,
#      4.0,
#      5.1,
#      5.1,
#      4.7,
#      2.6,
#      4.0,
#      3.4,
#      3.3,
#      3.2,
#      6.3,
#      7.2,
#      8.0,
#      8.0,
#      12.6,
#      12.7,
#      11.6,
#      8.0,
#      2.1,
#      5.1,
#      6.1,
#      2.5,
#      6.3,
#      6.5,
#      4.3,
#      6.0,
#      12.4,
#      17.0,
#      11.3,
#      17.9,
#      15.2,
#      14.3,
#      11.9,
#      11.2,
#      14.7,
#      16.5,
#      14.7,
#      15.6,
#      15.8,
#      13.9]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [19.8, 17.6],
#     'temperature_2m_min': [12.8, 14.4]}},
#   'batch': {'latitude': 33.945427,
#    'longitude': -118.40222,
#    'generationtime_ms': 0.08869171142578125,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 30.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [18.8,
#      17.5,
#      16.7,
#      15.9,
#      15.5,
#      15.2,
#      14.7,
#      14.5,
#      14.7,
#      14.7,
#      14.5,
#      13.6,
#      12.8,
#      12.8,
#      13.0,
#      13.1,
#      13.6,
#      15.6,
#      18.2,
#      19.0,
#      19.8,
#      19.8,
#      18.7,
#      18.1,
#      17.6,
#      17.1,
#      16.4,
#      15.1,
#      14.6,
#      14.7,
#      15.1,
#      15.6,
#      15.4,
#      15.3,
#      15.2,
#      14.4,
#      14.4,
#      14.7,
#      14.4,
#      14.8,
#      14.9,
#      15.6,
#      16.1,
#      16.9,
#      16.7,
#      16.5,
#      16.7,
#      16.6],
#     'relative_humidity_2m': [82,
#      88,
#      85,
#      87,
#      86,
#      89,
#      88,
#      89,
#      90,
#      91,
#      97,
#      95,
#      96,
#      100,
#      100,
#      100,
#      100,
#      93,
#      81,
#      77,
#      74,
#      73,
#      81,
#      82,
#      83,
#      83,
#      86,
#      91,
#      93,
#      93,
#      92,
#      90,
#      94,
#      97,
#      97,
#      92,
#      92,
#      91,
#      88,
#      88,
#      90,
#      89,
#      89,
#      87,
#      89,
#      90,
#      88,
#      88],
#     'wind_speed_10m': [2.6,
#      8.8,
#      3.6,
#      6.1,
#      3.5,
#      7.1,
#      5.0,
#      5.2,
#      6.6,
#      4.0,
#      5.1,
#      5.1,
#      4.7,
#      2.6,
#      4.0,
#      3.4,
#      3.3,
#      3.2,
#      6.3,
#      7.2,
#      8.0,
#      8.0,
#      12.6,
#      12.7,
#      11.6,
#      8.0,
#      2.1,
#      5.1,
#      6.1,
#      2.5,
#      6.3,
#      6.5,
#      4.3,
#      6.0,
#      12.4,
#      17.0,
#      11.3,
#      17.9,
#      15.2,
#      14.3,
#      11.9,
#      11.2,
#      14.7,
#      16.5,
#      14.7,
#      15.6,
#      15.8,
#      13.9]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [19.8, 17.6],
#     'temperature_2m_min': [12.8, 14.4]}}},
#  'miami_fl': {'single': {'latitude': 25.792543,
#    'longitude': -80.31333,
#    'generationtime_ms': 0.10693073272705078,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 8.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [21.6,
#      21.3,
#      21.4,
#      21.0,
#      21.0,
#      20.4,
#      19.9,
#      19.5,
#      18.1,
#      17.5,
#      17.4,
#      16.6,
#      17.1,
#      19.1,
#      19.9,
#      21.4,
#      22.7,
#      22.9,
#      23.6,
#      24.0,
#      24.2,
#      23.7,
#      23.0,
#      21.2,
#      21.6,
#      21.1,
#      19.9,
#      20.4,
#      19.6,
#      18.6,
#      17.8,
#      17.0,
#      16.1,
#      15.6,
#      15.3,
#      14.9,
#      14.8,
#      18.4,
#      21.2,
#      22.4,
#      24.5,
#      25.5,
#      26.0,
#      26.4,
#      25.9,
#      25.5,
#      24.5,
#      22.5],
#     'relative_humidity_2m': [55,
#      56,
#      56,
#      55,
#      57,
#      58,
#      60,
#      63,
#      68,
#      71,
#      69,
#      71,
#      72,
#      66,
#      65,
#      61,
#      59,
#      58,
#      55,
#      54,
#      53,
#      55,
#      57,
#      61,
#      59,
#      56,
#      58,
#      56,
#      54,
#      49,
#      48,
#      51,
#      59,
#      71,
#      77,
#      80,
#      80,
#      66,
#      56,
#      55,
#      48,
#      48,
#      49,
#      50,
#      50,
#      56,
#      52,
#      61],
#     'wind_speed_10m': [4.6,
#      5.9,
#      4.3,
#      5.5,
#      3.1,
#      4.0,
#      7.6,
#      8.8,
#      9.8,
#      8.2,
#      8.6,
#      9.2,
#      8.1,
#      13.2,
#      10.7,
#      13.0,
#      16.0,
#      13.7,
#      13.8,
#      12.7,
#      12.3,
#      13.1,
#      11.0,
#      7.6,
#      11.5,
#      13.0,
#      9.4,
#      6.6,
#      9.1,
#      7.9,
#      9.6,
#      9.0,
#      9.1,
#      10.0,
#      10.5,
#      9.0,
#      10.3,
#      12.2,
#      14.1,
#      14.8,
#      15.7,
#      17.4,
#      15.2,
#      13.1,
#      18.5,
#      15.6,
#      12.9,
#      7.6]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [24.2, 26.4],
#     'temperature_2m_min': [16.6, 14.8]}},
#   'batch': {'latitude': 25.792543,
#    'longitude': -80.31333,
#    'generationtime_ms': 0.09107589721679688,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 8.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00',
#      '2025-11-14T00:00',
#      '2025-11-14T01:00',
#      '2025-11-14T02:00',
#      '2025-11-14T03:00',
#      '2025-11-14T04:00',
#      '2025-11-14T05:00',
#      '2025-11-14T06:00',
#      '2025-11-14T07:00',
#      '2025-11-14T08:00',
#      '2025-11-14T09:00',
#      '2025-11-14T10:00',
#      '2025-11-14T11:00',
#      '2025-11-14T12:00',
#      '2025-11-14T13:00',
#      '2025-11-14T14:00',
#      '2025-11-14T15:00',
#      '2025-11-14T16:00',
#      '2025-11-14T17:00',
#      '2025-11-14T18:00',
#      '2025-11-14T19:00',
#      '2025-11-14T20:00',
#      '2025-11-14T21:00',
#      '2025-11-14T22:00',
#      '2025-11-14T23:00'],
#     'temperature_2m': [21.6,
#      21.3,
#      21.4,
#      21.0,
#      21.0,
#      20.4,
#      19.9,
#      19.5,
#      18.1,
#      17.5,
#      17.4,
#      16.6,
#      17.1,
#      19.1,
#      19.9,
#      21.4,
#      22.7,
#      22.9,
#      23.6,
#      24.0,
#      24.2,
#      23.7,
#      23.0,
#      21.2,
#      21.6,
#      21.1,
#      19.9,
#      20.4,
#      19.6,
#      18.6,
#      17.8,
#      17.0,
#      16.1,
#      15.6,
#      15.3,
#      14.9,
#      14.8,
#      18.4,
#      21.2,
#      22.4,
#      24.5,
#      25.5,
#      26.0,
#      26.4,
#      25.9,
#      25.5,
#      24.5,
#      22.5],
#     'relative_humidity_2m': [55,
#      56,
#      56,
#      55,
#      57,
#      58,
#      60,
#      63,
#      68,
#      71,
#      69,
#      71,
#      72,
#      66,
#      65,
#      61,
#      59,
#      58,
#      55,
#      54,
#      53,
#      55,
#      57,
#      61,
#      59,
#      56,
#      58,
#      56,
#      54,
#      49,
#      48,
#      51,
#      59,
#      71,
#      77,
#      80,
#      80,
#      66,
#      56,
#      55,
#      48,
#      48,
#      49,
#      50,
#      50,
#      56,
#      52,
#      61],
#     'wind_speed_10m': [4.6,
#      5.9,
#      4.3,
#      5.5,
#      3.1,
#      4.0,
#      7.6,
#      8.8,
#      9.8,
#      8.2,
#      8.6,
#      9.2,
#      8.1,
#      13.2,
#      10.7,
#      13.0,
#      16.0,
#      13.7,
#      13.8,
#      12.7,
#      12.3,
#      13.1,
#      11.0,
#      7.6,
#      11.5,
#      13.0,
#      9.4,
#      6.6,
#      9.1,
#      7.9,
#      9.6,
#      9.0,
#      9.1,
#      10.0,
#      10.5,
#      9.0,
#      10.3,
#      12.2,
#      14.1,
#      14.8,
#      15.7,
#      17.4,
#      15.2,
#      13.1,
#      18.5,
#      15.6,
#      12.9,
#      7.6]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-13', '2025-11-14'],
#     'temperature_2m_max': [24.2, 26.4],
#     'temperature_2m_min': [16.6, 14.8]}}}}

# %% [markdown]
# ## Open-Meteo historical example
# Fetches the previous 5 days of archive data for the same location. Dates must be provided in ISO format.

# %%
import datetime as dt
historical_end = dt.date.today()
historical_start = historical_end - dt.timedelta(days=5)

open_meteo_historical = {}
for name, lat, lon in iter_locations():
    request = {
        "location": (lat, lon),
        "start_date": historical_start,
        "end_date": historical_end,
        "hourly": ["temperature_2m", "relative_humidity_2m", "wind_speed_10m"],
        "daily": ["temperature_2m_max", "temperature_2m_min"],
    }
    open_meteo_historical[name] = {
        "single": open_meteo.get_historical(**request),
        "batch": open_meteo.get_historical_batch([request])[0],
    }
open_meteo_historical
# Out:
# {'new_york_ny': {'single': {'latitude': 40.808434,
#    'longitude': -74.0199,
#    'generationtime_ms': 5.565881729125977,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 40.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-08T00:00',
#      '2025-11-08T01:00',
#      '2025-11-08T02:00',
#      '2025-11-08T03:00',
#      '2025-11-08T04:00',
#      '2025-11-08T05:00',
#      '2025-11-08T06:00',
#      '2025-11-08T07:00',
#      '2025-11-08T08:00',
#      '2025-11-08T09:00',
#      '2025-11-08T10:00',
#      '2025-11-08T11:00',
#      '2025-11-08T12:00',
#      '2025-11-08T13:00',
#      '2025-11-08T14:00',
#      '2025-11-08T15:00',
#      '2025-11-08T16:00',
#      '2025-11-08T17:00',
#      '2025-11-08T18:00',
#      '2025-11-08T19:00',
#      '2025-11-08T20:00',
#      '2025-11-08T21:00',
#      '2025-11-08T22:00',
#      '2025-11-08T23:00',
#      '2025-11-09T00:00',
#      '2025-11-09T01:00',
#      '2025-11-09T02:00',
#      '2025-11-09T03:00',
#      '2025-11-09T04:00',
#      '2025-11-09T05:00',
#      '2025-11-09T06:00',
#      '2025-11-09T07:00',
#      '2025-11-09T08:00',
#      '2025-11-09T09:00',
#      '2025-11-09T10:00',
#      '2025-11-09T11:00',
#      '2025-11-09T12:00',
#      '2025-11-09T13:00',
#      '2025-11-09T14:00',
#      '2025-11-09T15:00',
#      '2025-11-09T16:00',
#      '2025-11-09T17:00',
#      '2025-11-09T18:00',
#      '2025-11-09T19:00',
#      '2025-11-09T20:00',
#      '2025-11-09T21:00',
#      '2025-11-09T22:00',
#      '2025-11-09T23:00',
#      '2025-11-10T00:00',
#      '2025-11-10T01:00',
#      '2025-11-10T02:00',
#      '2025-11-10T03:00',
#      '2025-11-10T04:00',
#      '2025-11-10T05:00',
#      '2025-11-10T06:00',
#      '2025-11-10T07:00',
#      '2025-11-10T08:00',
#      '2025-11-10T09:00',
#      '2025-11-10T10:00',
#      '2025-11-10T11:00',
#      '2025-11-10T12:00',
#      '2025-11-10T13:00',
#      '2025-11-10T14:00',
#      '2025-11-10T15:00',
#      '2025-11-10T16:00',
#      '2025-11-10T17:00',
#      '2025-11-10T18:00',
#      '2025-11-10T19:00',
#      '2025-11-10T20:00',
#      '2025-11-10T21:00',
#      '2025-11-10T22:00',
#      '2025-11-10T23:00',
#      '2025-11-11T00:00',
#      '2025-11-11T01:00',
#      '2025-11-11T02:00',
#      '2025-11-11T03:00',
#      '2025-11-11T04:00',
#      '2025-11-11T05:00',
#      '2025-11-11T06:00',
#      '2025-11-11T07:00',
#      '2025-11-11T08:00',
#      '2025-11-11T09:00',
#      '2025-11-11T10:00',
#      '2025-11-11T11:00',
#      '2025-11-11T12:00',
#      '2025-11-11T13:00',
#      '2025-11-11T14:00',
#      '2025-11-11T15:00',
#      '2025-11-11T16:00',
#      '2025-11-11T17:00',
#      '2025-11-11T18:00',
#      '2025-11-11T19:00',
#      '2025-11-11T20:00',
#      '2025-11-11T21:00',
#      '2025-11-11T22:00',
#      '2025-11-11T23:00',
#      '2025-11-12T00:00',
#      '2025-11-12T01:00',
#      '2025-11-12T02:00',
#      '2025-11-12T03:00',
#      '2025-11-12T04:00',
#      '2025-11-12T05:00',
#      '2025-11-12T06:00',
#      '2025-11-12T07:00',
#      '2025-11-12T08:00',
#      '2025-11-12T09:00',
#      '2025-11-12T10:00',
#      '2025-11-12T11:00',
#      '2025-11-12T12:00',
#      '2025-11-12T13:00',
#      '2025-11-12T14:00',
#      '2025-11-12T15:00',
#      '2025-11-12T16:00',
#      '2025-11-12T17:00',
#      '2025-11-12T18:00',
#      '2025-11-12T19:00',
#      '2025-11-12T20:00',
#      '2025-11-12T21:00',
#      '2025-11-12T22:00',
#      '2025-11-12T23:00',
#      '2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00'],
#     'temperature_2m': [12.4,
#      12.5,
#      12.8,
#      12.9,
#      13.2,
#      12.5,
#      11.9,
#      11.8,
#      11.9,
#      11.9,
#      11.9,
#      11.5,
#      11.9,
#      12.6,
#      13.4,
#      15.2,
#      16.2,
#      16.8,
#      17.8,
#      18.0,
#      17.8,
#      16.3,
#      14.8,
#      13.7,
#      12.8,
#      12.2,
#      11.6,
#      11.3,
#      11.0,
#      10.7,
#      9.9,
#      9.1,
#      8.5,
#      8.2,
#      8.7,
#      8.9,
#      8.9,
#      10.0,
#      12.5,
#      13.6,
#      15.1,
#      14.8,
#      14.9,
#      16.1,
#      15.8,
#      15.3,
#      14.7,
#      14.6,
#      14.2,
#      13.8,
#      13.5,
#      13.4,
#      13.5,
#      13.2,
#      13.4,
#      12.9,
#      12.8,
#      12.5,
#      12.0,
#      11.9,
#      11.9,
#      12.0,
#      12.8,
#      12.0,
#      11.7,
#      10.9,
#      10.0,
#      10.2,
#      10.2,
#      8.6,
#      6.4,
#      4.9,
#      4.1,
#      3.3,
#      2.5,
#      2.1,
#      1.6,
#      1.1,
#      1.0,
#      0.7,
#      0.7,
#      0.7,
#      0.9,
#      1.2,
#      1.2,
#      1.4,
#      1.9,
#      2.4,
#      2.5,
#      2.4,
#      3.1,
#      3.0,
#      3.9,
#      4.2,
#      4.0,
#      3.7,
#      3.6,
#      3.8,
#      3.8,
#      3.5,
#      3.0,
#      2.5,
#      2.5,
#      2.4,
#      2.6,
#      2.4,
#      2.5,
#      2.4,
#      2.1,
#      3.0,
#      3.9,
#      4.6,
#      5.6,
#      6.5,
#      8.8,
#      8.8,
#      7.8,
#      7.7,
#      8.1,
#      7.6,
#      7.0,
#      7.3,
#      6.9,
#      6.9,
#      6.6,
#      6.5,
#      5.9,
#      5.5,
#      5.4,
#      5.3,
#      5.1,
#      4.8,
#      4.6,
#      5.5,
#      7.1,
#      8.0,
#      8.5,
#      8.8,
#      9.5,
#      10.0,
#      9.3,
#      8.6,
#      7.9,
#      6.9],
#     'relative_humidity_2m': [59,
#      59,
#      56,
#      56,
#      59,
#      69,
#      84,
#      92,
#      94,
#      95,
#      95,
#      96,
#      94,
#      91,
#      89,
#      75,
#      65,
#      58,
#      51,
#      47,
#      47,
#      63,
#      63,
#      68,
#      67,
#      70,
#      73,
#      73,
#      74,
#      73,
#      75,
#      79,
#      85,
#      88,
#      90,
#      91,
#      87,
#      86,
#      82,
#      82,
#      82,
#      83,
#      87,
#      83,
#      86,
#      90,
#      94,
#      95,
#      97,
#      99,
#      99,
#      100,
#      99,
#      100,
#      90,
#      95,
#      92,
#      92,
#      93,
#      94,
#      93,
#      96,
#      93,
#      93,
#      84,
#      80,
#      89,
#      85,
#      76,
#      64,
#      67,
#      67,
#      67,
#      67,
#      67,
#      65,
#      64,
#      60,
#      59,
#      61,
#      61,
#      62,
#      59,
#      58,
#      57,
#      60,
#      53,
#      49,
#      55,
#      63,
#      52,
#      56,
#      50,
#      50,
#      51,
#      55,
#      59,
#      61,
#      61,
#      62,
#      62,
#      64,
#      63,
#      62,
#      60,
#      60,
#      62,
#      64,
#      66,
#      67,
#      63,
#      62,
#      61,
#      61,
#      44,
#      46,
#      54,
#      59,
#      56,
#      60,
#      63,
#      67,
#      70,
#      70,
#      72,
#      73,
#      77,
#      80,
#      81,
#      81,
#      81,
#      79,
#      79,
#      77,
#      70,
#      59,
#      57,
#      53,
#      48,
#      44,
#      50,
#      54,
#      55,
#      61],
#     'wind_speed_10m': [14.2,
#      13.3,
#      13.4,
#      14.0,
#      14.6,
#      12.2,
#      13.1,
#      13.8,
#      11.5,
#      10.2,
#      9.4,
#      8.4,
#      10.0,
#      9.9,
#      7.7,
#      8.9,
#      7.7,
#      7.5,
#      9.4,
#      8.6,
#      8.4,
#      3.6,
#      2.6,
#      4.0,
#      1.4,
#      2.6,
#      4.4,
#      5.3,
#      5.8,
#      6.4,
#      3.8,
#      3.6,
#      3.2,
#      2.8,
#      3.6,
#      3.2,
#      1.3,
#      4.3,
#      3.5,
#      3.7,
#      11.9,
#      11.0,
#      11.1,
#      15.7,
#      12.9,
#      11.0,
#      9.6,
#      5.4,
#      4.2,
#      4.7,
#      1.9,
#      0.2,
#      2.8,
#      6.7,
#      8.9,
#      8.8,
#      9.2,
#      5.1,
#      1.9,
#      2.7,
#      4.0,
#      3.3,
#      5.9,
#      6.9,
#      12.7,
#      12.7,
#      12.2,
#      10.4,
#      13.6,
#      16.0,
#      17.5,
#      17.3,
#      16.1,
#      15.8,
#      15.7,
#      17.4,
#      17.3,
#      16.5,
#      16.4,
#      14.8,
#      12.1,
#      11.1,
#      11.2,
#      14.4,
#      16.0,
#      18.9,
#      22.8,
#      24.5,
#      23.1,
#      22.6,
#      28.3,
#      24.5,
#      25.9,
#      21.0,
#      18.4,
#      17.8,
#      18.7,
#      19.8,
#      17.2,
#      15.5,
#      16.1,
#      15.6,
#      15.4,
#      14.8,
#      14.0,
#      13.0,
#      13.2,
#      11.0,
#      8.3,
#      8.2,
#      9.0,
#      8.6,
#      6.6,
#      6.0,
#      13.9,
#      16.1,
#      8.8,
#      6.8,
#      11.4,
#      9.0,
#      12.2,
#      12.6,
#      14.1,
#      15.2,
#      14.7,
#      13.9,
#      13.1,
#      12.8,
#      13.2,
#      13.0,
#      13.0,
#      12.6,
#      12.2,
#      13.7,
#      13.9,
#      19.4,
#      20.9,
#      20.2,
#      18.4,
#      19.9,
#      16.4,
#      14.7,
#      15.5,
#      11.9]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-08',
#      '2025-11-09',
#      '2025-11-10',
#      '2025-11-11',
#      '2025-11-12',
#      '2025-11-13'],
#     'temperature_2m_max': [18.0, 16.1, 14.2, 4.2, 8.8, 10.0],
#     'temperature_2m_min': [11.5, 8.2, 4.9, 0.7, 2.1, 4.6]}},
#   'batch': {'latitude': 40.808434,
#    'longitude': -74.0199,
#    'generationtime_ms': 0.6440877914428711,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 40.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-08T00:00',
#      '2025-11-08T01:00',
#      '2025-11-08T02:00',
#      '2025-11-08T03:00',
#      '2025-11-08T04:00',
#      '2025-11-08T05:00',
#      '2025-11-08T06:00',
#      '2025-11-08T07:00',
#      '2025-11-08T08:00',
#      '2025-11-08T09:00',
#      '2025-11-08T10:00',
#      '2025-11-08T11:00',
#      '2025-11-08T12:00',
#      '2025-11-08T13:00',
#      '2025-11-08T14:00',
#      '2025-11-08T15:00',
#      '2025-11-08T16:00',
#      '2025-11-08T17:00',
#      '2025-11-08T18:00',
#      '2025-11-08T19:00',
#      '2025-11-08T20:00',
#      '2025-11-08T21:00',
#      '2025-11-08T22:00',
#      '2025-11-08T23:00',
#      '2025-11-09T00:00',
#      '2025-11-09T01:00',
#      '2025-11-09T02:00',
#      '2025-11-09T03:00',
#      '2025-11-09T04:00',
#      '2025-11-09T05:00',
#      '2025-11-09T06:00',
#      '2025-11-09T07:00',
#      '2025-11-09T08:00',
#      '2025-11-09T09:00',
#      '2025-11-09T10:00',
#      '2025-11-09T11:00',
#      '2025-11-09T12:00',
#      '2025-11-09T13:00',
#      '2025-11-09T14:00',
#      '2025-11-09T15:00',
#      '2025-11-09T16:00',
#      '2025-11-09T17:00',
#      '2025-11-09T18:00',
#      '2025-11-09T19:00',
#      '2025-11-09T20:00',
#      '2025-11-09T21:00',
#      '2025-11-09T22:00',
#      '2025-11-09T23:00',
#      '2025-11-10T00:00',
#      '2025-11-10T01:00',
#      '2025-11-10T02:00',
#      '2025-11-10T03:00',
#      '2025-11-10T04:00',
#      '2025-11-10T05:00',
#      '2025-11-10T06:00',
#      '2025-11-10T07:00',
#      '2025-11-10T08:00',
#      '2025-11-10T09:00',
#      '2025-11-10T10:00',
#      '2025-11-10T11:00',
#      '2025-11-10T12:00',
#      '2025-11-10T13:00',
#      '2025-11-10T14:00',
#      '2025-11-10T15:00',
#      '2025-11-10T16:00',
#      '2025-11-10T17:00',
#      '2025-11-10T18:00',
#      '2025-11-10T19:00',
#      '2025-11-10T20:00',
#      '2025-11-10T21:00',
#      '2025-11-10T22:00',
#      '2025-11-10T23:00',
#      '2025-11-11T00:00',
#      '2025-11-11T01:00',
#      '2025-11-11T02:00',
#      '2025-11-11T03:00',
#      '2025-11-11T04:00',
#      '2025-11-11T05:00',
#      '2025-11-11T06:00',
#      '2025-11-11T07:00',
#      '2025-11-11T08:00',
#      '2025-11-11T09:00',
#      '2025-11-11T10:00',
#      '2025-11-11T11:00',
#      '2025-11-11T12:00',
#      '2025-11-11T13:00',
#      '2025-11-11T14:00',
#      '2025-11-11T15:00',
#      '2025-11-11T16:00',
#      '2025-11-11T17:00',
#      '2025-11-11T18:00',
#      '2025-11-11T19:00',
#      '2025-11-11T20:00',
#      '2025-11-11T21:00',
#      '2025-11-11T22:00',
#      '2025-11-11T23:00',
#      '2025-11-12T00:00',
#      '2025-11-12T01:00',
#      '2025-11-12T02:00',
#      '2025-11-12T03:00',
#      '2025-11-12T04:00',
#      '2025-11-12T05:00',
#      '2025-11-12T06:00',
#      '2025-11-12T07:00',
#      '2025-11-12T08:00',
#      '2025-11-12T09:00',
#      '2025-11-12T10:00',
#      '2025-11-12T11:00',
#      '2025-11-12T12:00',
#      '2025-11-12T13:00',
#      '2025-11-12T14:00',
#      '2025-11-12T15:00',
#      '2025-11-12T16:00',
#      '2025-11-12T17:00',
#      '2025-11-12T18:00',
#      '2025-11-12T19:00',
#      '2025-11-12T20:00',
#      '2025-11-12T21:00',
#      '2025-11-12T22:00',
#      '2025-11-12T23:00',
#      '2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00'],
#     'temperature_2m': [12.4,
#      12.5,
#      12.8,
#      12.9,
#      13.2,
#      12.5,
#      11.9,
#      11.8,
#      11.9,
#      11.9,
#      11.9,
#      11.5,
#      11.9,
#      12.6,
#      13.4,
#      15.2,
#      16.2,
#      16.8,
#      17.8,
#      18.0,
#      17.8,
#      16.3,
#      14.8,
#      13.7,
#      12.8,
#      12.2,
#      11.6,
#      11.3,
#      11.0,
#      10.7,
#      9.9,
#      9.1,
#      8.5,
#      8.2,
#      8.7,
#      8.9,
#      8.9,
#      10.0,
#      12.5,
#      13.6,
#      15.1,
#      14.8,
#      14.9,
#      16.1,
#      15.8,
#      15.3,
#      14.7,
#      14.6,
#      14.2,
#      13.8,
#      13.5,
#      13.4,
#      13.5,
#      13.2,
#      13.4,
#      12.9,
#      12.8,
#      12.5,
#      12.0,
#      11.9,
#      11.9,
#      12.0,
#      12.8,
#      12.0,
#      11.7,
#      10.9,
#      10.0,
#      10.2,
#      10.2,
#      8.6,
#      6.4,
#      4.9,
#      4.1,
#      3.3,
#      2.5,
#      2.1,
#      1.6,
#      1.1,
#      1.0,
#      0.7,
#      0.7,
#      0.7,
#      0.9,
#      1.2,
#      1.2,
#      1.4,
#      1.9,
#      2.4,
#      2.5,
#      2.4,
#      3.1,
#      3.0,
#      3.9,
#      4.2,
#      4.0,
#      3.7,
#      3.6,
#      3.8,
#      3.8,
#      3.5,
#      3.0,
#      2.5,
#      2.5,
#      2.4,
#      2.6,
#      2.4,
#      2.5,
#      2.4,
#      2.1,
#      3.0,
#      3.9,
#      4.6,
#      5.6,
#      6.5,
#      8.8,
#      8.8,
#      7.8,
#      7.7,
#      8.1,
#      7.6,
#      7.0,
#      7.3,
#      6.9,
#      6.9,
#      6.6,
#      6.5,
#      5.9,
#      5.5,
#      5.4,
#      5.3,
#      5.1,
#      4.8,
#      4.6,
#      5.5,
#      7.1,
#      8.0,
#      8.5,
#      8.8,
#      9.5,
#      10.0,
#      9.3,
#      8.6,
#      7.9,
#      6.9],
#     'relative_humidity_2m': [59,
#      59,
#      56,
#      56,
#      59,
#      69,
#      84,
#      92,
#      94,
#      95,
#      95,
#      96,
#      94,
#      91,
#      89,
#      75,
#      65,
#      58,
#      51,
#      47,
#      47,
#      63,
#      63,
#      68,
#      67,
#      70,
#      73,
#      73,
#      74,
#      73,
#      75,
#      79,
#      85,
#      88,
#      90,
#      91,
#      87,
#      86,
#      82,
#      82,
#      82,
#      83,
#      87,
#      83,
#      86,
#      90,
#      94,
#      95,
#      97,
#      99,
#      99,
#      100,
#      99,
#      100,
#      90,
#      95,
#      92,
#      92,
#      93,
#      94,
#      93,
#      96,
#      93,
#      93,
#      84,
#      80,
#      89,
#      85,
#      76,
#      64,
#      67,
#      67,
#      67,
#      67,
#      67,
#      65,
#      64,
#      60,
#      59,
#      61,
#      61,
#      62,
#      59,
#      58,
#      57,
#      60,
#      53,
#      49,
#      55,
#      63,
#      52,
#      56,
#      50,
#      50,
#      51,
#      55,
#      59,
#      61,
#      61,
#      62,
#      62,
#      64,
#      63,
#      62,
#      60,
#      60,
#      62,
#      64,
#      66,
#      67,
#      63,
#      62,
#      61,
#      61,
#      44,
#      46,
#      54,
#      59,
#      56,
#      60,
#      63,
#      67,
#      70,
#      70,
#      72,
#      73,
#      77,
#      80,
#      81,
#      81,
#      81,
#      79,
#      79,
#      77,
#      70,
#      59,
#      57,
#      53,
#      48,
#      44,
#      50,
#      54,
#      55,
#      61],
#     'wind_speed_10m': [14.2,
#      13.3,
#      13.4,
#      14.0,
#      14.6,
#      12.2,
#      13.1,
#      13.8,
#      11.5,
#      10.2,
#      9.4,
#      8.4,
#      10.0,
#      9.9,
#      7.7,
#      8.9,
#      7.7,
#      7.5,
#      9.4,
#      8.6,
#      8.4,
#      3.6,
#      2.6,
#      4.0,
#      1.4,
#      2.6,
#      4.4,
#      5.3,
#      5.8,
#      6.4,
#      3.8,
#      3.6,
#      3.2,
#      2.8,
#      3.6,
#      3.2,
#      1.3,
#      4.3,
#      3.5,
#      3.7,
#      11.9,
#      11.0,
#      11.1,
#      15.7,
#      12.9,
#      11.0,
#      9.6,
#      5.4,
#      4.2,
#      4.7,
#      1.9,
#      0.2,
#      2.8,
#      6.7,
#      8.9,
#      8.8,
#      9.2,
#      5.1,
#      1.9,
#      2.7,
#      4.0,
#      3.3,
#      5.9,
#      6.9,
#      12.7,
#      12.7,
#      12.2,
#      10.4,
#      13.6,
#      16.0,
#      17.5,
#      17.3,
#      16.1,
#      15.8,
#      15.7,
#      17.4,
#      17.3,
#      16.5,
#      16.4,
#      14.8,
#      12.1,
#      11.1,
#      11.2,
#      14.4,
#      16.0,
#      18.9,
#      22.8,
#      24.5,
#      23.1,
#      22.6,
#      28.3,
#      24.5,
#      25.9,
#      21.0,
#      18.4,
#      17.8,
#      18.7,
#      19.8,
#      17.2,
#      15.5,
#      16.1,
#      15.6,
#      15.4,
#      14.8,
#      14.0,
#      13.0,
#      13.2,
#      11.0,
#      8.3,
#      8.2,
#      9.0,
#      8.6,
#      6.6,
#      6.0,
#      13.9,
#      16.1,
#      8.8,
#      6.8,
#      11.4,
#      9.0,
#      12.2,
#      12.6,
#      14.1,
#      15.2,
#      14.7,
#      13.9,
#      13.1,
#      12.8,
#      13.2,
#      13.0,
#      13.0,
#      12.6,
#      12.2,
#      13.7,
#      13.9,
#      19.4,
#      20.9,
#      20.2,
#      18.4,
#      19.9,
#      16.4,
#      14.7,
#      15.5,
#      11.9]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-08',
#      '2025-11-09',
#      '2025-11-10',
#      '2025-11-11',
#      '2025-11-12',
#      '2025-11-13'],
#     'temperature_2m_max': [18.0, 16.1, 14.2, 4.2, 8.8, 10.0],
#     'temperature_2m_min': [11.5, 8.2, 4.9, 0.7, 2.1, 4.6]}}},
#  'austin_tx': {'single': {'latitude': 30.193321,
#    'longitude': -97.684204,
#    'generationtime_ms': 4.76837158203125,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 146.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-08T00:00',
#      '2025-11-08T01:00',
#      '2025-11-08T02:00',
#      '2025-11-08T03:00',
#      '2025-11-08T04:00',
#      '2025-11-08T05:00',
#      '2025-11-08T06:00',
#      '2025-11-08T07:00',
#      '2025-11-08T08:00',
#      '2025-11-08T09:00',
#      '2025-11-08T10:00',
#      '2025-11-08T11:00',
#      '2025-11-08T12:00',
#      '2025-11-08T13:00',
#      '2025-11-08T14:00',
#      '2025-11-08T15:00',
#      '2025-11-08T16:00',
#      '2025-11-08T17:00',
#      '2025-11-08T18:00',
#      '2025-11-08T19:00',
#      '2025-11-08T20:00',
#      '2025-11-08T21:00',
#      '2025-11-08T22:00',
#      '2025-11-08T23:00',
#      '2025-11-09T00:00',
#      '2025-11-09T01:00',
#      '2025-11-09T02:00',
#      '2025-11-09T03:00',
#      '2025-11-09T04:00',
#      '2025-11-09T05:00',
#      '2025-11-09T06:00',
#      '2025-11-09T07:00',
#      '2025-11-09T08:00',
#      '2025-11-09T09:00',
#      '2025-11-09T10:00',
#      '2025-11-09T11:00',
#      '2025-11-09T12:00',
#      '2025-11-09T13:00',
#      '2025-11-09T14:00',
#      '2025-11-09T15:00',
#      '2025-11-09T16:00',
#      '2025-11-09T17:00',
#      '2025-11-09T18:00',
#      '2025-11-09T19:00',
#      '2025-11-09T20:00',
#      '2025-11-09T21:00',
#      '2025-11-09T22:00',
#      '2025-11-09T23:00',
#      '2025-11-10T00:00',
#      '2025-11-10T01:00',
#      '2025-11-10T02:00',
#      '2025-11-10T03:00',
#      '2025-11-10T04:00',
#      '2025-11-10T05:00',
#      '2025-11-10T06:00',
#      '2025-11-10T07:00',
#      '2025-11-10T08:00',
#      '2025-11-10T09:00',
#      '2025-11-10T10:00',
#      '2025-11-10T11:00',
#      '2025-11-10T12:00',
#      '2025-11-10T13:00',
#      '2025-11-10T14:00',
#      '2025-11-10T15:00',
#      '2025-11-10T16:00',
#      '2025-11-10T17:00',
#      '2025-11-10T18:00',
#      '2025-11-10T19:00',
#      '2025-11-10T20:00',
#      '2025-11-10T21:00',
#      '2025-11-10T22:00',
#      '2025-11-10T23:00',
#      '2025-11-11T00:00',
#      '2025-11-11T01:00',
#      '2025-11-11T02:00',
#      '2025-11-11T03:00',
#      '2025-11-11T04:00',
#      '2025-11-11T05:00',
#      '2025-11-11T06:00',
#      '2025-11-11T07:00',
#      '2025-11-11T08:00',
#      '2025-11-11T09:00',
#      '2025-11-11T10:00',
#      '2025-11-11T11:00',
#      '2025-11-11T12:00',
#      '2025-11-11T13:00',
#      '2025-11-11T14:00',
#      '2025-11-11T15:00',
#      '2025-11-11T16:00',
#      '2025-11-11T17:00',
#      '2025-11-11T18:00',
#      '2025-11-11T19:00',
#      '2025-11-11T20:00',
#      '2025-11-11T21:00',
#      '2025-11-11T22:00',
#      '2025-11-11T23:00',
#      '2025-11-12T00:00',
#      '2025-11-12T01:00',
#      '2025-11-12T02:00',
#      '2025-11-12T03:00',
#      '2025-11-12T04:00',
#      '2025-11-12T05:00',
#      '2025-11-12T06:00',
#      '2025-11-12T07:00',
#      '2025-11-12T08:00',
#      '2025-11-12T09:00',
#      '2025-11-12T10:00',
#      '2025-11-12T11:00',
#      '2025-11-12T12:00',
#      '2025-11-12T13:00',
#      '2025-11-12T14:00',
#      '2025-11-12T15:00',
#      '2025-11-12T16:00',
#      '2025-11-12T17:00',
#      '2025-11-12T18:00',
#      '2025-11-12T19:00',
#      '2025-11-12T20:00',
#      '2025-11-12T21:00',
#      '2025-11-12T22:00',
#      '2025-11-12T23:00',
#      '2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00'],
#     'temperature_2m': [27.0,
#      25.8,
#      23.8,
#      22.2,
#      20.8,
#      20.1,
#      18.8,
#      17.5,
#      16.4,
#      15.9,
#      15.9,
#      15.7,
#      15.1,
#      14.5,
#      16.4,
#      19.2,
#      22.1,
#      24.5,
#      26.5,
#      28.3,
#      29.4,
#      29.9,
#      29.8,
#      27.9,
#      24.8,
#      24.0,
#      23.0,
#      21.6,
#      21.4,
#      20.8,
#      19.7,
#      19.2,
#      18.9,
#      18.0,
#      17.0,
#      16.2,
#      15.9,
#      15.4,
#      15.9,
#      16.6,
#      17.4,
#      18.1,
#      20.1,
#      20.8,
#      20.9,
#      20.7,
#      19.8,
#      18.4,
#      17.2,
#      16.1,
#      15.1,
#      14.2,
#      13.3,
#      12.5,
#      10.5,
#      9.4,
#      8.5,
#      7.9,
#      7.3,
#      6.9,
#      6.0,
#      4.8,
#      6.1,
#      7.9,
#      9.3,
#      10.6,
#      12.7,
#      14.0,
#      14.7,
#      15.0,
#      14.8,
#      14.1,
#      12.1,
#      11.2,
#      10.6,
#      9.8,
#      9.2,
#      8.7,
#      7.1,
#      5.8,
#      6.0,
#      6.0,
#      6.0,
#      5.9,
#      5.2,
#      4.7,
#      6.4,
#      9.5,
#      12.9,
#      15.8,
#      19.6,
#      21.1,
#      21.9,
#      22.2,
#      22.1,
#      21.0,
#      19.3,
#      18.6,
#      17.9,
#      17.1,
#      16.6,
#      16.1,
#      14.9,
#      14.7,
#      14.5,
#      14.2,
#      13.7,
#      13.1,
#      13.2,
#      12.3,
#      13.9,
#      16.8,
#      19.6,
#      21.9,
#      24.9,
#      26.4,
#      27.2,
#      27.5,
#      27.4,
#      26.2,
#      23.4,
#      22.1,
#      21.7,
#      21.1,
#      20.3,
#      19.5,
#      18.8,
#      18.1,
#      17.7,
#      17.3,
#      16.9,
#      16.6,
#      16.4,
#      16.1,
#      17.7,
#      20.5,
#      23.2,
#      25.2,
#      26.7,
#      27.6,
#      28.1,
#      28.2,
#      27.8,
#      26.9],
#     'relative_humidity_2m': [46,
#      40,
#      42,
#      45,
#      49,
#      53,
#      58,
#      65,
#      72,
#      75,
#      77,
#      80,
#      86,
#      90,
#      81,
#      69,
#      59,
#      53,
#      49,
#      43,
#      38,
#      36,
#      35,
#      44,
#      47,
#      52,
#      56,
#      62,
#      64,
#      68,
#      70,
#      70,
#      57,
#      45,
#      40,
#      36,
#      35,
#      35,
#      35,
#      32,
#      31,
#      30,
#      26,
#      25,
#      24,
#      24,
#      26,
#      28,
#      28,
#      29,
#      30,
#      32,
#      33,
#      32,
#      37,
#      39,
#      41,
#      41,
#      42,
#      43,
#      47,
#      54,
#      52,
#      45,
#      38,
#      33,
#      26,
#      23,
#      22,
#      23,
#      23,
#      24,
#      30,
#      31,
#      33,
#      34,
#      33,
#      32,
#      40,
#      46,
#      47,
#      47,
#      48,
#      48,
#      48,
#      48,
#      46,
#      38,
#      30,
#      29,
#      26,
#      25,
#      24,
#      25,
#      26,
#      28,
#      32,
#      39,
#      51,
#      59,
#      62,
#      66,
#      76,
#      79,
#      80,
#      81,
#      83,
#      85,
#      85,
#      88,
#      81,
#      69,
#      60,
#      55,
#      48,
#      43,
#      41,
#      40,
#      39,
#      42,
#      47,
#      50,
#      59,
#      61,
#      66,
#      70,
#      74,
#      79,
#      82,
#      86,
#      89,
#      91,
#      92,
#      92,
#      86,
#      74,
#      64,
#      55,
#      48,
#      44,
#      43,
#      42,
#      43,
#      45],
#     'wind_speed_10m': [2.3,
#      12.5,
#      13.2,
#      10.6,
#      7.4,
#      8.2,
#      9.1,
#      7.2,
#      5.6,
#      6.3,
#      8.1,
#      7.8,
#      8.0,
#      8.0,
#      7.3,
#      5.4,
#      5.8,
#      4.3,
#      2.5,
#      1.6,
#      1.2,
#      2.2,
#      3.6,
#      4.0,
#      6.6,
#      8.1,
#      7.6,
#      6.9,
#      9.8,
#      8.2,
#      10.0,
#      16.2,
#      22.0,
#      23.3,
#      23.1,
#      23.1,
#      22.9,
#      21.9,
#      18.9,
#      24.8,
#      24.1,
#      24.3,
#      23.2,
#      23.6,
#      22.7,
#      22.9,
#      22.7,
#      20.7,
#      16.2,
#      18.4,
#      18.1,
#      16.7,
#      15.1,
#      16.9,
#      17.8,
#      17.6,
#      15.6,
#      14.0,
#      12.1,
#      12.0,
#      10.9,
#      9.8,
#      10.2,
#      11.1,
#      9.2,
#      7.6,
#      7.8,
#      7.6,
#      7.8,
#      7.6,
#      6.6,
#      6.2,
#      5.3,
#      5.1,
#      3.5,
#      6.1,
#      6.4,
#      6.5,
#      5.4,
#      5.8,
#      7.3,
#      7.3,
#      8.0,
#      8.2,
#      9.2,
#      10.0,
#      11.5,
#      10.1,
#      13.9,
#      18.1,
#      21.1,
#      22.8,
#      23.3,
#      22.7,
#      22.8,
#      19.1,
#      15.2,
#      16.6,
#      20.6,
#      21.1,
#      19.6,
#      18.3,
#      17.4,
#      16.5,
#      15.6,
#      13.4,
#      10.3,
#      9.8,
#      11.7,
#      10.2,
#      12.0,
#      9.7,
#      12.3,
#      15.7,
#      16.5,
#      16.1,
#      14.9,
#      14.4,
#      14.5,
#      11.4,
#      9.5,
#      11.2,
#      18.1,
#      18.0,
#      15.4,
#      13.3,
#      11.4,
#      9.6,
#      9.4,
#      9.4,
#      9.1,
#      8.6,
#      7.9,
#      7.8,
#      10.1,
#      9.0,
#      13.5,
#      18.8,
#      19.7,
#      19.3,
#      18.6,
#      17.4,
#      17.5,
#      15.0]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-08',
#      '2025-11-09',
#      '2025-11-10',
#      '2025-11-11',
#      '2025-11-12',
#      '2025-11-13'],
#     'temperature_2m_max': [29.9, 24.8, 17.2, 22.2, 27.5, 28.2],
#     'temperature_2m_min': [14.5, 15.4, 4.8, 4.7, 12.3, 16.1]}},
#   'batch': {'latitude': 30.193321,
#    'longitude': -97.684204,
#    'generationtime_ms': 0.4388093948364258,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 146.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-08T00:00',
#      '2025-11-08T01:00',
#      '2025-11-08T02:00',
#      '2025-11-08T03:00',
#      '2025-11-08T04:00',
#      '2025-11-08T05:00',
#      '2025-11-08T06:00',
#      '2025-11-08T07:00',
#      '2025-11-08T08:00',
#      '2025-11-08T09:00',
#      '2025-11-08T10:00',
#      '2025-11-08T11:00',
#      '2025-11-08T12:00',
#      '2025-11-08T13:00',
#      '2025-11-08T14:00',
#      '2025-11-08T15:00',
#      '2025-11-08T16:00',
#      '2025-11-08T17:00',
#      '2025-11-08T18:00',
#      '2025-11-08T19:00',
#      '2025-11-08T20:00',
#      '2025-11-08T21:00',
#      '2025-11-08T22:00',
#      '2025-11-08T23:00',
#      '2025-11-09T00:00',
#      '2025-11-09T01:00',
#      '2025-11-09T02:00',
#      '2025-11-09T03:00',
#      '2025-11-09T04:00',
#      '2025-11-09T05:00',
#      '2025-11-09T06:00',
#      '2025-11-09T07:00',
#      '2025-11-09T08:00',
#      '2025-11-09T09:00',
#      '2025-11-09T10:00',
#      '2025-11-09T11:00',
#      '2025-11-09T12:00',
#      '2025-11-09T13:00',
#      '2025-11-09T14:00',
#      '2025-11-09T15:00',
#      '2025-11-09T16:00',
#      '2025-11-09T17:00',
#      '2025-11-09T18:00',
#      '2025-11-09T19:00',
#      '2025-11-09T20:00',
#      '2025-11-09T21:00',
#      '2025-11-09T22:00',
#      '2025-11-09T23:00',
#      '2025-11-10T00:00',
#      '2025-11-10T01:00',
#      '2025-11-10T02:00',
#      '2025-11-10T03:00',
#      '2025-11-10T04:00',
#      '2025-11-10T05:00',
#      '2025-11-10T06:00',
#      '2025-11-10T07:00',
#      '2025-11-10T08:00',
#      '2025-11-10T09:00',
#      '2025-11-10T10:00',
#      '2025-11-10T11:00',
#      '2025-11-10T12:00',
#      '2025-11-10T13:00',
#      '2025-11-10T14:00',
#      '2025-11-10T15:00',
#      '2025-11-10T16:00',
#      '2025-11-10T17:00',
#      '2025-11-10T18:00',
#      '2025-11-10T19:00',
#      '2025-11-10T20:00',
#      '2025-11-10T21:00',
#      '2025-11-10T22:00',
#      '2025-11-10T23:00',
#      '2025-11-11T00:00',
#      '2025-11-11T01:00',
#      '2025-11-11T02:00',
#      '2025-11-11T03:00',
#      '2025-11-11T04:00',
#      '2025-11-11T05:00',
#      '2025-11-11T06:00',
#      '2025-11-11T07:00',
#      '2025-11-11T08:00',
#      '2025-11-11T09:00',
#      '2025-11-11T10:00',
#      '2025-11-11T11:00',
#      '2025-11-11T12:00',
#      '2025-11-11T13:00',
#      '2025-11-11T14:00',
#      '2025-11-11T15:00',
#      '2025-11-11T16:00',
#      '2025-11-11T17:00',
#      '2025-11-11T18:00',
#      '2025-11-11T19:00',
#      '2025-11-11T20:00',
#      '2025-11-11T21:00',
#      '2025-11-11T22:00',
#      '2025-11-11T23:00',
#      '2025-11-12T00:00',
#      '2025-11-12T01:00',
#      '2025-11-12T02:00',
#      '2025-11-12T03:00',
#      '2025-11-12T04:00',
#      '2025-11-12T05:00',
#      '2025-11-12T06:00',
#      '2025-11-12T07:00',
#      '2025-11-12T08:00',
#      '2025-11-12T09:00',
#      '2025-11-12T10:00',
#      '2025-11-12T11:00',
#      '2025-11-12T12:00',
#      '2025-11-12T13:00',
#      '2025-11-12T14:00',
#      '2025-11-12T15:00',
#      '2025-11-12T16:00',
#      '2025-11-12T17:00',
#      '2025-11-12T18:00',
#      '2025-11-12T19:00',
#      '2025-11-12T20:00',
#      '2025-11-12T21:00',
#      '2025-11-12T22:00',
#      '2025-11-12T23:00',
#      '2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00'],
#     'temperature_2m': [27.0,
#      25.8,
#      23.8,
#      22.2,
#      20.8,
#      20.1,
#      18.8,
#      17.5,
#      16.4,
#      15.9,
#      15.9,
#      15.7,
#      15.1,
#      14.5,
#      16.4,
#      19.2,
#      22.1,
#      24.5,
#      26.5,
#      28.3,
#      29.4,
#      29.9,
#      29.8,
#      27.9,
#      24.8,
#      24.0,
#      23.0,
#      21.6,
#      21.4,
#      20.8,
#      19.7,
#      19.2,
#      18.9,
#      18.0,
#      17.0,
#      16.2,
#      15.9,
#      15.4,
#      15.9,
#      16.6,
#      17.4,
#      18.1,
#      20.1,
#      20.8,
#      20.9,
#      20.7,
#      19.8,
#      18.4,
#      17.2,
#      16.1,
#      15.1,
#      14.2,
#      13.3,
#      12.5,
#      10.5,
#      9.4,
#      8.5,
#      7.9,
#      7.3,
#      6.9,
#      6.0,
#      4.8,
#      6.1,
#      7.9,
#      9.3,
#      10.6,
#      12.7,
#      14.0,
#      14.7,
#      15.0,
#      14.8,
#      14.1,
#      12.1,
#      11.2,
#      10.6,
#      9.8,
#      9.2,
#      8.7,
#      7.1,
#      5.8,
#      6.0,
#      6.0,
#      6.0,
#      5.9,
#      5.2,
#      4.7,
#      6.4,
#      9.5,
#      12.9,
#      15.8,
#      19.6,
#      21.1,
#      21.9,
#      22.2,
#      22.1,
#      21.0,
#      19.3,
#      18.6,
#      17.9,
#      17.1,
#      16.6,
#      16.1,
#      14.9,
#      14.7,
#      14.5,
#      14.2,
#      13.7,
#      13.1,
#      13.2,
#      12.3,
#      13.9,
#      16.8,
#      19.6,
#      21.9,
#      24.9,
#      26.4,
#      27.2,
#      27.5,
#      27.4,
#      26.2,
#      23.4,
#      22.1,
#      21.7,
#      21.1,
#      20.3,
#      19.5,
#      18.8,
#      18.1,
#      17.7,
#      17.3,
#      16.9,
#      16.6,
#      16.4,
#      16.1,
#      17.7,
#      20.5,
#      23.2,
#      25.2,
#      26.7,
#      27.6,
#      28.1,
#      28.2,
#      27.8,
#      26.9],
#     'relative_humidity_2m': [46,
#      40,
#      42,
#      45,
#      49,
#      53,
#      58,
#      65,
#      72,
#      75,
#      77,
#      80,
#      86,
#      90,
#      81,
#      69,
#      59,
#      53,
#      49,
#      43,
#      38,
#      36,
#      35,
#      44,
#      47,
#      52,
#      56,
#      62,
#      64,
#      68,
#      70,
#      70,
#      57,
#      45,
#      40,
#      36,
#      35,
#      35,
#      35,
#      32,
#      31,
#      30,
#      26,
#      25,
#      24,
#      24,
#      26,
#      28,
#      28,
#      29,
#      30,
#      32,
#      33,
#      32,
#      37,
#      39,
#      41,
#      41,
#      42,
#      43,
#      47,
#      54,
#      52,
#      45,
#      38,
#      33,
#      26,
#      23,
#      22,
#      23,
#      23,
#      24,
#      30,
#      31,
#      33,
#      34,
#      33,
#      32,
#      40,
#      46,
#      47,
#      47,
#      48,
#      48,
#      48,
#      48,
#      46,
#      38,
#      30,
#      29,
#      26,
#      25,
#      24,
#      25,
#      26,
#      28,
#      32,
#      39,
#      51,
#      59,
#      62,
#      66,
#      76,
#      79,
#      80,
#      81,
#      83,
#      85,
#      85,
#      88,
#      81,
#      69,
#      60,
#      55,
#      48,
#      43,
#      41,
#      40,
#      39,
#      42,
#      47,
#      50,
#      59,
#      61,
#      66,
#      70,
#      74,
#      79,
#      82,
#      86,
#      89,
#      91,
#      92,
#      92,
#      86,
#      74,
#      64,
#      55,
#      48,
#      44,
#      43,
#      42,
#      43,
#      45],
#     'wind_speed_10m': [2.3,
#      12.5,
#      13.2,
#      10.6,
#      7.4,
#      8.2,
#      9.1,
#      7.2,
#      5.6,
#      6.3,
#      8.1,
#      7.8,
#      8.0,
#      8.0,
#      7.3,
#      5.4,
#      5.8,
#      4.3,
#      2.5,
#      1.6,
#      1.2,
#      2.2,
#      3.6,
#      4.0,
#      6.6,
#      8.1,
#      7.6,
#      6.9,
#      9.8,
#      8.2,
#      10.0,
#      16.2,
#      22.0,
#      23.3,
#      23.1,
#      23.1,
#      22.9,
#      21.9,
#      18.9,
#      24.8,
#      24.1,
#      24.3,
#      23.2,
#      23.6,
#      22.7,
#      22.9,
#      22.7,
#      20.7,
#      16.2,
#      18.4,
#      18.1,
#      16.7,
#      15.1,
#      16.9,
#      17.8,
#      17.6,
#      15.6,
#      14.0,
#      12.1,
#      12.0,
#      10.9,
#      9.8,
#      10.2,
#      11.1,
#      9.2,
#      7.6,
#      7.8,
#      7.6,
#      7.8,
#      7.6,
#      6.6,
#      6.2,
#      5.3,
#      5.1,
#      3.5,
#      6.1,
#      6.4,
#      6.5,
#      5.4,
#      5.8,
#      7.3,
#      7.3,
#      8.0,
#      8.2,
#      9.2,
#      10.0,
#      11.5,
#      10.1,
#      13.9,
#      18.1,
#      21.1,
#      22.8,
#      23.3,
#      22.7,
#      22.8,
#      19.1,
#      15.2,
#      16.6,
#      20.6,
#      21.1,
#      19.6,
#      18.3,
#      17.4,
#      16.5,
#      15.6,
#      13.4,
#      10.3,
#      9.8,
#      11.7,
#      10.2,
#      12.0,
#      9.7,
#      12.3,
#      15.7,
#      16.5,
#      16.1,
#      14.9,
#      14.4,
#      14.5,
#      11.4,
#      9.5,
#      11.2,
#      18.1,
#      18.0,
#      15.4,
#      13.3,
#      11.4,
#      9.6,
#      9.4,
#      9.4,
#      9.1,
#      8.6,
#      7.9,
#      7.8,
#      10.1,
#      9.0,
#      13.5,
#      18.8,
#      19.7,
#      19.3,
#      18.6,
#      17.4,
#      17.5,
#      15.0]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-08',
#      '2025-11-09',
#      '2025-11-10',
#      '2025-11-11',
#      '2025-11-12',
#      '2025-11-13'],
#     'temperature_2m_max': [29.9, 24.8, 17.2, 22.2, 27.5, 28.2],
#     'temperature_2m_min': [14.5, 15.4, 4.8, 4.7, 12.3, 16.1]}}},
#  'chicago_midway_il': {'single': {'latitude': 41.792618,
#    'longitude': -87.78262,
#    'generationtime_ms': 3.5202503204345703,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 187.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-08T00:00',
#      '2025-11-08T01:00',
#      '2025-11-08T02:00',
#      '2025-11-08T03:00',
#      '2025-11-08T04:00',
#      '2025-11-08T05:00',
#      '2025-11-08T06:00',
#      '2025-11-08T07:00',
#      '2025-11-08T08:00',
#      '2025-11-08T09:00',
#      '2025-11-08T10:00',
#      '2025-11-08T11:00',
#      '2025-11-08T12:00',
#      '2025-11-08T13:00',
#      '2025-11-08T14:00',
#      '2025-11-08T15:00',
#      '2025-11-08T16:00',
#      '2025-11-08T17:00',
#      '2025-11-08T18:00',
#      '2025-11-08T19:00',
#      '2025-11-08T20:00',
#      '2025-11-08T21:00',
#      '2025-11-08T22:00',
#      '2025-11-08T23:00',
#      '2025-11-09T00:00',
#      '2025-11-09T01:00',
#      '2025-11-09T02:00',
#      '2025-11-09T03:00',
#      '2025-11-09T04:00',
#      '2025-11-09T05:00',
#      '2025-11-09T06:00',
#      '2025-11-09T07:00',
#      '2025-11-09T08:00',
#      '2025-11-09T09:00',
#      '2025-11-09T10:00',
#      '2025-11-09T11:00',
#      '2025-11-09T12:00',
#      '2025-11-09T13:00',
#      '2025-11-09T14:00',
#      '2025-11-09T15:00',
#      '2025-11-09T16:00',
#      '2025-11-09T17:00',
#      '2025-11-09T18:00',
#      '2025-11-09T19:00',
#      '2025-11-09T20:00',
#      '2025-11-09T21:00',
#      '2025-11-09T22:00',
#      '2025-11-09T23:00',
#      '2025-11-10T00:00',
#      '2025-11-10T01:00',
#      '2025-11-10T02:00',
#      '2025-11-10T03:00',
#      '2025-11-10T04:00',
#      '2025-11-10T05:00',
#      '2025-11-10T06:00',
#      '2025-11-10T07:00',
#      '2025-11-10T08:00',
#      '2025-11-10T09:00',
#      '2025-11-10T10:00',
#      '2025-11-10T11:00',
#      '2025-11-10T12:00',
#      '2025-11-10T13:00',
#      '2025-11-10T14:00',
#      '2025-11-10T15:00',
#      '2025-11-10T16:00',
#      '2025-11-10T17:00',
#      '2025-11-10T18:00',
#      '2025-11-10T19:00',
#      '2025-11-10T20:00',
#      '2025-11-10T21:00',
#      '2025-11-10T22:00',
#      '2025-11-10T23:00',
#      '2025-11-11T00:00',
#      '2025-11-11T01:00',
#      '2025-11-11T02:00',
#      '2025-11-11T03:00',
#      '2025-11-11T04:00',
#      '2025-11-11T05:00',
#      '2025-11-11T06:00',
#      '2025-11-11T07:00',
#      '2025-11-11T08:00',
#      '2025-11-11T09:00',
#      '2025-11-11T10:00',
#      '2025-11-11T11:00',
#      '2025-11-11T12:00',
#      '2025-11-11T13:00',
#      '2025-11-11T14:00',
#      '2025-11-11T15:00',
#      '2025-11-11T16:00',
#      '2025-11-11T17:00',
#      '2025-11-11T18:00',
#      '2025-11-11T19:00',
#      '2025-11-11T20:00',
#      '2025-11-11T21:00',
#      '2025-11-11T22:00',
#      '2025-11-11T23:00',
#      '2025-11-12T00:00',
#      '2025-11-12T01:00',
#      '2025-11-12T02:00',
#      '2025-11-12T03:00',
#      '2025-11-12T04:00',
#      '2025-11-12T05:00',
#      '2025-11-12T06:00',
#      '2025-11-12T07:00',
#      '2025-11-12T08:00',
#      '2025-11-12T09:00',
#      '2025-11-12T10:00',
#      '2025-11-12T11:00',
#      '2025-11-12T12:00',
#      '2025-11-12T13:00',
#      '2025-11-12T14:00',
#      '2025-11-12T15:00',
#      '2025-11-12T16:00',
#      '2025-11-12T17:00',
#      '2025-11-12T18:00',
#      '2025-11-12T19:00',
#      '2025-11-12T20:00',
#      '2025-11-12T21:00',
#      '2025-11-12T22:00',
#      '2025-11-12T23:00',
#      '2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00'],
#     'temperature_2m': [13.1,
#      10.5,
#      10.5,
#      10.2,
#      10.2,
#      10.0,
#      9.3,
#      9.1,
#      8.7,
#      8.4,
#      8.1,
#      7.8,
#      7.5,
#      7.4,
#      7.5,
#      7.9,
#      8.2,
#      8.2,
#      7.6,
#      7.4,
#      7.1,
#      6.9,
#      6.7,
#      6.4,
#      6.2,
#      5.9,
#      5.4,
#      4.5,
#      3.3,
#      4.0,
#      4.0,
#      4.2,
#      4.0,
#      2.9,
#      1.8,
#      0.9,
#      0.7,
#      -0.1,
#      -0.6,
#      -0.5,
#      -0.5,
#      -0.4,
#      0.3,
#      -0.2,
#      0.1,
#      0.4,
#      -0.4,
#      -1.4,
#      -1.3,
#      -1.6,
#      -2.1,
#      -2.6,
#      -3.0,
#      -3.1,
#      -2.7,
#      -3.0,
#      -2.9,
#      -2.9,
#      -3.2,
#      -2.8,
#      -2.6,
#      -3.1,
#      -3.1,
#      -3.2,
#      -2.3,
#      -2.4,
#      -0.9,
#      -0.5,
#      -0.6,
#      -1.1,
#      -1.8,
#      -2.1,
#      -2.5,
#      -3.3,
#      -3.7,
#      -3.9,
#      -4.2,
#      -4.5,
#      -4.9,
#      -5.3,
#      -5.1,
#      -4.7,
#      -4.2,
#      -3.8,
#      -3.2,
#      -2.7,
#      -2.2,
#      -1.5,
#      -0.9,
#      -0.1,
#      1.1,
#      1.3,
#      2.0,
#      2.8,
#      3.0,
#      2.6,
#      2.8,
#      2.4,
#      2.3,
#      2.4,
#      2.6,
#      2.6,
#      2.7,
#      2.8,
#      2.8,
#      2.9,
#      3.1,
#      3.4,
#      3.3,
#      2.9,
#      3.4,
#      4.5,
#      5.8,
#      8.4,
#      10.4,
#      11.4,
#      11.6,
#      11.1,
#      10.0,
#      8.7,
#      8.0,
#      7.4,
#      6.7,
#      6.1,
#      5.6,
#      5.2,
#      4.9,
#      4.6,
#      3.9,
#      3.3,
#      2.7,
#      2.3,
#      1.9,
#      1.7,
#      3.2,
#      5.2,
#      7.3,
#      9.1,
#      10.3,
#      11.0,
#      11.4,
#      11.5,
#      9.8,
#      9.0],
#     'relative_humidity_2m': [60,
#      77,
#      79,
#      80,
#      81,
#      79,
#      85,
#      83,
#      83,
#      82,
#      82,
#      80,
#      82,
#      82,
#      80,
#      76,
#      72,
#      72,
#      76,
#      76,
#      77,
#      76,
#      76,
#      79,
#      81,
#      88,
#      91,
#      95,
#      99,
#      95,
#      92,
#      90,
#      91,
#      97,
#      99,
#      99,
#      89,
#      87,
#      86,
#      80,
#      77,
#      71,
#      73,
#      67,
#      62,
#      55,
#      57,
#      59,
#      63,
#      63,
#      66,
#      71,
#      79,
#      77,
#      78,
#      78,
#      79,
#      77,
#      78,
#      85,
#      81,
#      85,
#      87,
#      83,
#      76,
#      78,
#      72,
#      66,
#      62,
#      63,
#      66,
#      71,
#      73,
#      74,
#      75,
#      76,
#      76,
#      77,
#      79,
#      81,
#      82,
#      83,
#      83,
#      83,
#      81,
#      81,
#      78,
#      73,
#      70,
#      68,
#      70,
#      78,
#      80,
#      68,
#      66,
#      67,
#      67,
#      70,
#      72,
#      74,
#      76,
#      79,
#      80,
#      81,
#      83,
#      85,
#      84,
#      82,
#      80,
#      79,
#      76,
#      70,
#      65,
#      60,
#      46,
#      42,
#      42,
#      45,
#      50,
#      52,
#      55,
#      57,
#      61,
#      64,
#      67,
#      68,
#      70,
#      71,
#      73,
#      76,
#      78,
#      80,
#      81,
#      82,
#      79,
#      75,
#      70,
#      64,
#      59,
#      57,
#      56,
#      57,
#      69,
#      71],
#     'wind_speed_10m': [13.0,
#      4.5,
#      11.6,
#      9.2,
#      8.6,
#      5.9,
#      7.1,
#      8.9,
#      8.8,
#      10.5,
#      10.2,
#      8.8,
#      7.7,
#      5.7,
#      7.2,
#      8.2,
#      8.4,
#      9.7,
#      9.0,
#      9.1,
#      9.9,
#      10.7,
#      10.7,
#      9.6,
#      9.9,
#      8.4,
#      11.4,
#      11.3,
#      13.1,
#      13.9,
#      15.4,
#      16.5,
#      14.2,
#      16.3,
#      19.5,
#      17.7,
#      17.1,
#      16.6,
#      17.0,
#      17.9,
#      18.6,
#      18.5,
#      18.9,
#      17.2,
#      18.8,
#      18.2,
#      18.3,
#      17.8,
#      15.8,
#      16.1,
#      16.1,
#      17.1,
#      15.4,
#      20.0,
#      21.3,
#      23.7,
#      23.1,
#      21.2,
#      16.7,
#      18.1,
#      13.5,
#      14.8,
#      15.8,
#      15.6,
#      12.6,
#      12.4,
#      11.9,
#      11.4,
#      11.7,
#      12.7,
#      12.2,
#      14.4,
#      14.3,
#      12.0,
#      12.0,
#      12.1,
#      11.7,
#      11.5,
#      10.7,
#      9.4,
#      8.9,
#      9.0,
#      10.6,
#      11.1,
#      13.0,
#      14.4,
#      15.0,
#      16.9,
#      20.2,
#      20.8,
#      15.2,
#      10.3,
#      13.6,
#      15.6,
#      13.9,
#      15.4,
#      15.7,
#      14.9,
#      14.8,
#      14.5,
#      14.4,
#      13.7,
#      14.4,
#      15.1,
#      15.1,
#      15.5,
#      15.5,
#      15.5,
#      14.5,
#      14.1,
#      14.7,
#      12.6,
#      14.2,
#      14.4,
#      16.7,
#      17.7,
#      17.4,
#      16.7,
#      15.5,
#      14.4,
#      14.1,
#      14.1,
#      13.5,
#      12.4,
#      12.4,
#      11.9,
#      11.6,
#      11.1,
#      10.2,
#      9.6,
#      9.8,
#      9.8,
#      8.9,
#      8.4,
#      8.9,
#      5.8,
#      5.0,
#      5.5,
#      6.6,
#      8.0,
#      7.6,
#      5.5,
#      4.1,
#      4.9]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-08',
#      '2025-11-09',
#      '2025-11-10',
#      '2025-11-11',
#      '2025-11-12',
#      '2025-11-13'],
#     'temperature_2m_max': [13.1, 6.2, -0.5, 3.0, 11.6, 11.5],
#     'temperature_2m_min': [6.4, -1.4, -3.2, -5.3, 2.3, 1.7]}},
#   'batch': {'latitude': 41.792618,
#    'longitude': -87.78262,
#    'generationtime_ms': 0.44727325439453125,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 187.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-08T00:00',
#      '2025-11-08T01:00',
#      '2025-11-08T02:00',
#      '2025-11-08T03:00',
#      '2025-11-08T04:00',
#      '2025-11-08T05:00',
#      '2025-11-08T06:00',
#      '2025-11-08T07:00',
#      '2025-11-08T08:00',
#      '2025-11-08T09:00',
#      '2025-11-08T10:00',
#      '2025-11-08T11:00',
#      '2025-11-08T12:00',
#      '2025-11-08T13:00',
#      '2025-11-08T14:00',
#      '2025-11-08T15:00',
#      '2025-11-08T16:00',
#      '2025-11-08T17:00',
#      '2025-11-08T18:00',
#      '2025-11-08T19:00',
#      '2025-11-08T20:00',
#      '2025-11-08T21:00',
#      '2025-11-08T22:00',
#      '2025-11-08T23:00',
#      '2025-11-09T00:00',
#      '2025-11-09T01:00',
#      '2025-11-09T02:00',
#      '2025-11-09T03:00',
#      '2025-11-09T04:00',
#      '2025-11-09T05:00',
#      '2025-11-09T06:00',
#      '2025-11-09T07:00',
#      '2025-11-09T08:00',
#      '2025-11-09T09:00',
#      '2025-11-09T10:00',
#      '2025-11-09T11:00',
#      '2025-11-09T12:00',
#      '2025-11-09T13:00',
#      '2025-11-09T14:00',
#      '2025-11-09T15:00',
#      '2025-11-09T16:00',
#      '2025-11-09T17:00',
#      '2025-11-09T18:00',
#      '2025-11-09T19:00',
#      '2025-11-09T20:00',
#      '2025-11-09T21:00',
#      '2025-11-09T22:00',
#      '2025-11-09T23:00',
#      '2025-11-10T00:00',
#      '2025-11-10T01:00',
#      '2025-11-10T02:00',
#      '2025-11-10T03:00',
#      '2025-11-10T04:00',
#      '2025-11-10T05:00',
#      '2025-11-10T06:00',
#      '2025-11-10T07:00',
#      '2025-11-10T08:00',
#      '2025-11-10T09:00',
#      '2025-11-10T10:00',
#      '2025-11-10T11:00',
#      '2025-11-10T12:00',
#      '2025-11-10T13:00',
#      '2025-11-10T14:00',
#      '2025-11-10T15:00',
#      '2025-11-10T16:00',
#      '2025-11-10T17:00',
#      '2025-11-10T18:00',
#      '2025-11-10T19:00',
#      '2025-11-10T20:00',
#      '2025-11-10T21:00',
#      '2025-11-10T22:00',
#      '2025-11-10T23:00',
#      '2025-11-11T00:00',
#      '2025-11-11T01:00',
#      '2025-11-11T02:00',
#      '2025-11-11T03:00',
#      '2025-11-11T04:00',
#      '2025-11-11T05:00',
#      '2025-11-11T06:00',
#      '2025-11-11T07:00',
#      '2025-11-11T08:00',
#      '2025-11-11T09:00',
#      '2025-11-11T10:00',
#      '2025-11-11T11:00',
#      '2025-11-11T12:00',
#      '2025-11-11T13:00',
#      '2025-11-11T14:00',
#      '2025-11-11T15:00',
#      '2025-11-11T16:00',
#      '2025-11-11T17:00',
#      '2025-11-11T18:00',
#      '2025-11-11T19:00',
#      '2025-11-11T20:00',
#      '2025-11-11T21:00',
#      '2025-11-11T22:00',
#      '2025-11-11T23:00',
#      '2025-11-12T00:00',
#      '2025-11-12T01:00',
#      '2025-11-12T02:00',
#      '2025-11-12T03:00',
#      '2025-11-12T04:00',
#      '2025-11-12T05:00',
#      '2025-11-12T06:00',
#      '2025-11-12T07:00',
#      '2025-11-12T08:00',
#      '2025-11-12T09:00',
#      '2025-11-12T10:00',
#      '2025-11-12T11:00',
#      '2025-11-12T12:00',
#      '2025-11-12T13:00',
#      '2025-11-12T14:00',
#      '2025-11-12T15:00',
#      '2025-11-12T16:00',
#      '2025-11-12T17:00',
#      '2025-11-12T18:00',
#      '2025-11-12T19:00',
#      '2025-11-12T20:00',
#      '2025-11-12T21:00',
#      '2025-11-12T22:00',
#      '2025-11-12T23:00',
#      '2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00'],
#     'temperature_2m': [13.1,
#      10.5,
#      10.5,
#      10.2,
#      10.2,
#      10.0,
#      9.3,
#      9.1,
#      8.7,
#      8.4,
#      8.1,
#      7.8,
#      7.5,
#      7.4,
#      7.5,
#      7.9,
#      8.2,
#      8.2,
#      7.6,
#      7.4,
#      7.1,
#      6.9,
#      6.7,
#      6.4,
#      6.2,
# ...
#      '2025-11-09T23:00',
#      '2025-11-10T00:00',
#      '2025-11-10T01:00',
#      '2025-11-10T02:00',
#      '2025-11-10T03:00',
#      '2025-11-10T04:00',
#      '2025-11-10T05:00',
#      '2025-11-10T06:00',
#      '2025-11-10T07:00',
#      '2025-11-10T08:00',
#      '2025-11-10T09:00',
#      '2025-11-10T10:00',
#      '2025-11-10T11:00',
#      '2025-11-10T12:00',
#      '2025-11-10T13:00',
#      '2025-11-10T14:00',
#      '2025-11-10T15:00',
#      '2025-11-10T16:00',
#      '2025-11-10T17:00',
#      '2025-11-10T18:00',
#      '2025-11-10T19:00',
#      '2025-11-10T20:00',
#      '2025-11-10T21:00',
#      '2025-11-10T22:00',
#      '2025-11-10T23:00',
#      '2025-11-11T00:00',
#      '2025-11-11T01:00',
#      '2025-11-11T02:00',
#      '2025-11-11T03:00',
#      '2025-11-11T04:00',
#      '2025-11-11T05:00',
#      '2025-11-11T06:00',
#      '2025-11-11T07:00',
#      '2025-11-11T08:00',
#      '2025-11-11T09:00',
#      '2025-11-11T10:00',
#      '2025-11-11T11:00',
#      '2025-11-11T12:00',
#      '2025-11-11T13:00',
#      '2025-11-11T14:00',
#      '2025-11-11T15:00',
#      '2025-11-11T16:00',
#      '2025-11-11T17:00',
#      '2025-11-11T18:00',
#      '2025-11-11T19:00',
#      '2025-11-11T20:00',
#      '2025-11-11T21:00',
#      '2025-11-11T22:00',
#      '2025-11-11T23:00',
#      '2025-11-12T00:00',
#      '2025-11-12T01:00',
#      '2025-11-12T02:00',
#      '2025-11-12T03:00',
#      '2025-11-12T04:00',
#      '2025-11-12T05:00',
#      '2025-11-12T06:00',
#      '2025-11-12T07:00',
#      '2025-11-12T08:00',
#      '2025-11-12T09:00',
#      '2025-11-12T10:00',
#      '2025-11-12T11:00',
#      '2025-11-12T12:00',
#      '2025-11-12T13:00',
#      '2025-11-12T14:00',
#      '2025-11-12T15:00',
#      '2025-11-12T16:00',
#      '2025-11-12T17:00',
#      '2025-11-12T18:00',
#      '2025-11-12T19:00',
#      '2025-11-12T20:00',
#      '2025-11-12T21:00',
#      '2025-11-12T22:00',
#      '2025-11-12T23:00',
#      '2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00'],
#     'temperature_2m': [25.7,
#      25.3,
#      24.9,
#      25.3,
#      24.9,
#      24.6,
#      23.8,
#      23.7,
#      23.4,
#      22.6,
#      22.5,
#      22.2,
#      22.2,
#      24.5,
#      26.9,
#      28.0,
#      28.5,
#      28.9,
#      29.5,
#      29.4,
#      28.5,
#      28.3,
#      27.4,
#      26.2,
#      26.0,
#      25.8,
#      25.2,
#      24.8,
#      24.4,
#      24.0,
#      23.7,
#      23.7,
#      23.5,
#      23.4,
#      23.2,
#      23.0,
#      22.5,
#      24.6,
#      27.2,
#      28.3,
#      29.0,
#      29.5,
#      27.9,
#      29.3,
#      29.3,
#      26.8,
#      26.0,
#      25.1,
#      26.0,
#      25.3,
#      24.8,
#      24.1,
#      23.8,
#      23.6,
#      23.7,
#      23.7,
#      23.6,
#      23.4,
#      23.2,
#      23.1,
#      22.8,
#      23.9,
#      25.6,
#      27.0,
#      27.4,
#      27.5,
#      26.8,
#      25.3,
#      25.3,
#      23.6,
#      22.2,
#      20.7,
#      19.3,
#      17.8,
#      16.3,
#      15.1,
#      14.3,
#      13.6,
#      13.0,
#      12.7,
#      12.4,
#      12.1,
#      11.5,
#      10.2,
#      9.0,
#      9.3,
#      10.5,
#      12.4,
#      14.4,
#      16.2,
#      17.3,
#      18.0,
#      18.3,
#      18.1,
#      18.4,
#      17.2,
#      16.2,
#      15.1,
#      14.3,
#      13.7,
#      13.0,
#      12.9,
#      12.1,
#      11.5,
#      11.2,
#      11.2,
#      11.8,
#      12.0,
#      12.7,
#      13.7,
#      15.7,
#      18.8,
#      21.0,
#      22.9,
#      23.4,
#      23.1,
#      22.7,
#      22.2,
#      21.3,
#      19.9,
#      19.8,
#      19.8,
#      18.9,
#      18.8,
#      18.0,
#      17.4,
#      17.0,
#      16.5,
#      16.1,
#      15.4,
#      15.1,
#      14.9,
#      14.7,
#      16.4,
#      18.3,
#      20.4,
#      21.8,
#      22.6,
#      23.7,
#      24.5,
#      24.1,
#      23.6,
#      22.5,
#      21.0],
#     'relative_humidity_2m': [78,
#      78,
#      80,
#      81,
#      84,
#      85,
#      89,
#      91,
#      92,
#      94,
#      93,
#      94,
#      93,
#      89,
#      77,
#      70,
#      69,
#      67,
#      64,
#      63,
#      64,
#      65,
#      71,
#      77,
#      77,
#      79,
#      82,
#      84,
#      85,
#      86,
#      89,
#      90,
#      90,
#      90,
#      91,
#      91,
#      94,
#      89,
#      74,
#      68,
#      66,
#      65,
#      71,
#      67,
#      67,
#      73,
#      76,
#      82,
#      82,
#      86,
#      88,
#      91,
#      92,
#      94,
#      95,
#      96,
#      96,
#      97,
#      98,
#      98,
#      98,
#      96,
#      86,
#      72,
#      70,
#      66,
#      67,
#      63,
#      54,
#      51,
#      48,
#      45,
#      53,
#      55,
#      57,
#      56,
#      59,
#      62,
#      64,
#      65,
#      68,
#      69,
#      63,
#      52,
#      53,
#      51,
#      51,
#      51,
#      49,
#      48,
#      56,
#      56,
#      54,
#      55,
#      56,
#      61,
#      66,
#      68,
#      70,
#      72,
#      75,
#      77,
#      79,
#      84,
#      86,
#      87,
#      85,
#      85,
#      84,
#      83,
#      79,
#      74,
#      69,
#      61,
#      50,
#      49,
#      50,
#      53,
#      58,
#      66,
#      70,
#      70,
#      73,
#      75,
#      78,
#      77,
#      78,
#      80,
#      79,
#      82,
#      84,
#      85,
#      86,
#      80,
#      72,
#      65,
#      59,
#      56,
#      57,
#      55,
#      56,
#      56,
#      60,
#      62],
#     'wind_speed_10m': [3.4,
#      4.1,
#      4.2,
#      5.8,
#      1.5,
#      2.8,
#      4.5,
#      6.5,
#      7.5,
#      4.0,
#      1.0,
#      0.7,
#      0.7,
#      0.0,
#      1.7,
#      3.9,
#      4.0,
#      5.2,
#      7.7,
#      6.6,
#      5.6,
#      6.3,
#      5.5,
#      5.9,
#      5.1,
#      6.9,
#      4.8,
#      2.8,
#      1.9,
#      4.5,
#      3.6,
#      3.8,
#      3.2,
#      1.3,
#      0.9,
#      1.1,
#      1.9,
#      3.4,
#      2.3,
#      5.6,
#      6.9,
#      6.3,
#      3.4,
#      3.3,
#      5.0,
#      7.6,
#      6.4,
#      3.6,
#      5.7,
#      5.1,
#      5.6,
#      4.5,
#      4.9,
#      6.7,
#      6.1,
#      6.2,
#      6.8,
#      7.2,
#      7.3,
#      8.4,
#      6.6,
#      6.4,
#      9.0,
#      14.1,
#      14.4,
#      14.1,
#      15.9,
#      16.8,
#      17.1,
#      18.8,
#      16.0,
#      15.2,
#      16.0,
#      16.1,
#      16.3,
#      15.1,
#      12.3,
#      11.4,
#      11.7,
#      11.7,
#      10.9,
#      11.3,
#      15.7,
#      15.3,
#      15.0,
#      13.5,
#      13.7,
#      14.6,
#      14.0,
#      13.6,
#      13.1,
#      12.7,
#      13.2,
#      11.8,
#      9.0,
#      9.1,
#      11.4,
#      12.8,
#      13.0,
#      12.7,
#      11.8,
#      11.1,
#      11.3,
#      11.7,
#      11.4,
#      10.4,
#      10.3,
#      10.0,
#      10.4,
#      10.3,
#      9.0,
#      9.2,
#      9.9,
#      10.5,
#      12.5,
#      13.2,
#      12.5,
#      12.0,
#      8.5,
#      6.5,
#      5.0,
#      4.6,
#      6.1,
#      6.0,
#      5.1,
#      6.1,
#      7.6,
#      9.6,
#      8.9,
#      8.9,
#      8.9,
#      8.8,
#      9.0,
#      9.1,
#      7.1,
#      8.8,
#      11.7,
#      11.2,
#      8.9,
#      10.1,
#      12.9,
#      11.7,
#      10.3,
#      7.8]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-08',
#      '2025-11-09',
#      '2025-11-10',
#      '2025-11-11',
#      '2025-11-12',
#      '2025-11-13'],
#     'temperature_2m_max': [29.5, 29.5, 27.5, 19.3, 23.4, 24.5],
#     'temperature_2m_min': [22.2, 22.5, 20.7, 9.0, 11.2, 14.7]}},
#   'batch': {'latitude': 25.764498,
#    'longitude': -80.2941,
#    'generationtime_ms': 0.38695335388183594,
#    'utc_offset_seconds': 0,
#    'timezone': 'GMT',
#    'timezone_abbreviation': 'GMT',
#    'elevation': 8.0,
#    'hourly_units': {'time': 'iso8601',
#     'temperature_2m': '°C',
#     'relative_humidity_2m': '%',
#     'wind_speed_10m': 'km/h'},
#    'hourly': {'time': ['2025-11-08T00:00',
#      '2025-11-08T01:00',
#      '2025-11-08T02:00',
#      '2025-11-08T03:00',
#      '2025-11-08T04:00',
#      '2025-11-08T05:00',
#      '2025-11-08T06:00',
#      '2025-11-08T07:00',
#      '2025-11-08T08:00',
#      '2025-11-08T09:00',
#      '2025-11-08T10:00',
#      '2025-11-08T11:00',
#      '2025-11-08T12:00',
#      '2025-11-08T13:00',
#      '2025-11-08T14:00',
#      '2025-11-08T15:00',
#      '2025-11-08T16:00',
#      '2025-11-08T17:00',
#      '2025-11-08T18:00',
#      '2025-11-08T19:00',
#      '2025-11-08T20:00',
#      '2025-11-08T21:00',
#      '2025-11-08T22:00',
#      '2025-11-08T23:00',
#      '2025-11-09T00:00',
#      '2025-11-09T01:00',
#      '2025-11-09T02:00',
#      '2025-11-09T03:00',
#      '2025-11-09T04:00',
#      '2025-11-09T05:00',
#      '2025-11-09T06:00',
#      '2025-11-09T07:00',
#      '2025-11-09T08:00',
#      '2025-11-09T09:00',
#      '2025-11-09T10:00',
#      '2025-11-09T11:00',
#      '2025-11-09T12:00',
#      '2025-11-09T13:00',
#      '2025-11-09T14:00',
#      '2025-11-09T15:00',
#      '2025-11-09T16:00',
#      '2025-11-09T17:00',
#      '2025-11-09T18:00',
#      '2025-11-09T19:00',
#      '2025-11-09T20:00',
#      '2025-11-09T21:00',
#      '2025-11-09T22:00',
#      '2025-11-09T23:00',
#      '2025-11-10T00:00',
#      '2025-11-10T01:00',
#      '2025-11-10T02:00',
#      '2025-11-10T03:00',
#      '2025-11-10T04:00',
#      '2025-11-10T05:00',
#      '2025-11-10T06:00',
#      '2025-11-10T07:00',
#      '2025-11-10T08:00',
#      '2025-11-10T09:00',
#      '2025-11-10T10:00',
#      '2025-11-10T11:00',
#      '2025-11-10T12:00',
#      '2025-11-10T13:00',
#      '2025-11-10T14:00',
#      '2025-11-10T15:00',
#      '2025-11-10T16:00',
#      '2025-11-10T17:00',
#      '2025-11-10T18:00',
#      '2025-11-10T19:00',
#      '2025-11-10T20:00',
#      '2025-11-10T21:00',
#      '2025-11-10T22:00',
#      '2025-11-10T23:00',
#      '2025-11-11T00:00',
#      '2025-11-11T01:00',
#      '2025-11-11T02:00',
#      '2025-11-11T03:00',
#      '2025-11-11T04:00',
#      '2025-11-11T05:00',
#      '2025-11-11T06:00',
#      '2025-11-11T07:00',
#      '2025-11-11T08:00',
#      '2025-11-11T09:00',
#      '2025-11-11T10:00',
#      '2025-11-11T11:00',
#      '2025-11-11T12:00',
#      '2025-11-11T13:00',
#      '2025-11-11T14:00',
#      '2025-11-11T15:00',
#      '2025-11-11T16:00',
#      '2025-11-11T17:00',
#      '2025-11-11T18:00',
#      '2025-11-11T19:00',
#      '2025-11-11T20:00',
#      '2025-11-11T21:00',
#      '2025-11-11T22:00',
#      '2025-11-11T23:00',
#      '2025-11-12T00:00',
#      '2025-11-12T01:00',
#      '2025-11-12T02:00',
#      '2025-11-12T03:00',
#      '2025-11-12T04:00',
#      '2025-11-12T05:00',
#      '2025-11-12T06:00',
#      '2025-11-12T07:00',
#      '2025-11-12T08:00',
#      '2025-11-12T09:00',
#      '2025-11-12T10:00',
#      '2025-11-12T11:00',
#      '2025-11-12T12:00',
#      '2025-11-12T13:00',
#      '2025-11-12T14:00',
#      '2025-11-12T15:00',
#      '2025-11-12T16:00',
#      '2025-11-12T17:00',
#      '2025-11-12T18:00',
#      '2025-11-12T19:00',
#      '2025-11-12T20:00',
#      '2025-11-12T21:00',
#      '2025-11-12T22:00',
#      '2025-11-12T23:00',
#      '2025-11-13T00:00',
#      '2025-11-13T01:00',
#      '2025-11-13T02:00',
#      '2025-11-13T03:00',
#      '2025-11-13T04:00',
#      '2025-11-13T05:00',
#      '2025-11-13T06:00',
#      '2025-11-13T07:00',
#      '2025-11-13T08:00',
#      '2025-11-13T09:00',
#      '2025-11-13T10:00',
#      '2025-11-13T11:00',
#      '2025-11-13T12:00',
#      '2025-11-13T13:00',
#      '2025-11-13T14:00',
#      '2025-11-13T15:00',
#      '2025-11-13T16:00',
#      '2025-11-13T17:00',
#      '2025-11-13T18:00',
#      '2025-11-13T19:00',
#      '2025-11-13T20:00',
#      '2025-11-13T21:00',
#      '2025-11-13T22:00',
#      '2025-11-13T23:00'],
#     'temperature_2m': [25.7,
#      25.3,
#      24.9,
#      25.3,
#      24.9,
#      24.6,
#      23.8,
#      23.7,
#      23.4,
#      22.6,
#      22.5,
#      22.2,
#      22.2,
#      24.5,
#      26.9,
#      28.0,
#      28.5,
#      28.9,
#      29.5,
#      29.4,
#      28.5,
#      28.3,
#      27.4,
#      26.2,
#      26.0,
#      25.8,
#      25.2,
#      24.8,
#      24.4,
#      24.0,
#      23.7,
#      23.7,
#      23.5,
#      23.4,
#      23.2,
#      23.0,
#      22.5,
#      24.6,
#      27.2,
#      28.3,
#      29.0,
#      29.5,
#      27.9,
#      29.3,
#      29.3,
#      26.8,
#      26.0,
#      25.1,
#      26.0,
#      25.3,
#      24.8,
#      24.1,
#      23.8,
#      23.6,
#      23.7,
#      23.7,
#      23.6,
#      23.4,
#      23.2,
#      23.1,
#      22.8,
#      23.9,
#      25.6,
#      27.0,
#      27.4,
#      27.5,
#      26.8,
#      25.3,
#      25.3,
#      23.6,
#      22.2,
#      20.7,
#      19.3,
#      17.8,
#      16.3,
#      15.1,
#      14.3,
#      13.6,
#      13.0,
#      12.7,
#      12.4,
#      12.1,
#      11.5,
#      10.2,
#      9.0,
#      9.3,
#      10.5,
#      12.4,
#      14.4,
#      16.2,
#      17.3,
#      18.0,
#      18.3,
#      18.1,
#      18.4,
#      17.2,
#      16.2,
#      15.1,
#      14.3,
#      13.7,
#      13.0,
#      12.9,
#      12.1,
#      11.5,
#      11.2,
#      11.2,
#      11.8,
#      12.0,
#      12.7,
#      13.7,
#      15.7,
#      18.8,
#      21.0,
#      22.9,
#      23.4,
#      23.1,
#      22.7,
#      22.2,
#      21.3,
#      19.9,
#      19.8,
#      19.8,
#      18.9,
#      18.8,
#      18.0,
#      17.4,
#      17.0,
#      16.5,
#      16.1,
#      15.4,
#      15.1,
#      14.9,
#      14.7,
#      16.4,
#      18.3,
#      20.4,
#      21.8,
#      22.6,
#      23.7,
#      24.5,
#      24.1,
#      23.6,
#      22.5,
#      21.0],
#     'relative_humidity_2m': [78,
#      78,
#      80,
#      81,
#      84,
#      85,
#      89,
#      91,
#      92,
#      94,
#      93,
#      94,
#      93,
#      89,
#      77,
#      70,
#      69,
#      67,
#      64,
#      63,
#      64,
#      65,
#      71,
#      77,
#      77,
#      79,
#      82,
#      84,
#      85,
#      86,
#      89,
#      90,
#      90,
#      90,
#      91,
#      91,
#      94,
#      89,
#      74,
#      68,
#      66,
#      65,
#      71,
#      67,
#      67,
#      73,
#      76,
#      82,
#      82,
#      86,
#      88,
#      91,
#      92,
#      94,
#      95,
#      96,
#      96,
#      97,
#      98,
#      98,
#      98,
#      96,
#      86,
#      72,
#      70,
#      66,
#      67,
#      63,
#      54,
#      51,
#      48,
#      45,
#      53,
#      55,
#      57,
#      56,
#      59,
#      62,
#      64,
#      65,
#      68,
#      69,
#      63,
#      52,
#      53,
#      51,
#      51,
#      51,
#      49,
#      48,
#      56,
#      56,
#      54,
#      55,
#      56,
#      61,
#      66,
#      68,
#      70,
#      72,
#      75,
#      77,
#      79,
#      84,
#      86,
#      87,
#      85,
#      85,
#      84,
#      83,
#      79,
#      74,
#      69,
#      61,
#      50,
#      49,
#      50,
#      53,
#      58,
#      66,
#      70,
#      70,
#      73,
#      75,
#      78,
#      77,
#      78,
#      80,
#      79,
#      82,
#      84,
#      85,
#      86,
#      80,
#      72,
#      65,
#      59,
#      56,
#      57,
#      55,
#      56,
#      56,
#      60,
#      62],
#     'wind_speed_10m': [3.4,
#      4.1,
#      4.2,
#      5.8,
#      1.5,
#      2.8,
#      4.5,
#      6.5,
#      7.5,
#      4.0,
#      1.0,
#      0.7,
#      0.7,
#      0.0,
#      1.7,
#      3.9,
#      4.0,
#      5.2,
#      7.7,
#      6.6,
#      5.6,
#      6.3,
#      5.5,
#      5.9,
#      5.1,
#      6.9,
#      4.8,
#      2.8,
#      1.9,
#      4.5,
#      3.6,
#      3.8,
#      3.2,
#      1.3,
#      0.9,
#      1.1,
#      1.9,
#      3.4,
#      2.3,
#      5.6,
#      6.9,
#      6.3,
#      3.4,
#      3.3,
#      5.0,
#      7.6,
#      6.4,
#      3.6,
#      5.7,
#      5.1,
#      5.6,
#      4.5,
#      4.9,
#      6.7,
#      6.1,
#      6.2,
#      6.8,
#      7.2,
#      7.3,
#      8.4,
#      6.6,
#      6.4,
#      9.0,
#      14.1,
#      14.4,
#      14.1,
#      15.9,
#      16.8,
#      17.1,
#      18.8,
#      16.0,
#      15.2,
#      16.0,
#      16.1,
#      16.3,
#      15.1,
#      12.3,
#      11.4,
#      11.7,
#      11.7,
#      10.9,
#      11.3,
#      15.7,
#      15.3,
#      15.0,
#      13.5,
#      13.7,
#      14.6,
#      14.0,
#      13.6,
#      13.1,
#      12.7,
#      13.2,
#      11.8,
#      9.0,
#      9.1,
#      11.4,
#      12.8,
#      13.0,
#      12.7,
#      11.8,
#      11.1,
#      11.3,
#      11.7,
#      11.4,
#      10.4,
#      10.3,
#      10.0,
#      10.4,
#      10.3,
#      9.0,
#      9.2,
#      9.9,
#      10.5,
#      12.5,
#      13.2,
#      12.5,
#      12.0,
#      8.5,
#      6.5,
#      5.0,
#      4.6,
#      6.1,
#      6.0,
#      5.1,
#      6.1,
#      7.6,
#      9.6,
#      8.9,
#      8.9,
#      8.9,
#      8.8,
#      9.0,
#      9.1,
#      7.1,
#      8.8,
#      11.7,
#      11.2,
#      8.9,
#      10.1,
#      12.9,
#      11.7,
#      10.3,
#      7.8]},
#    'daily_units': {'time': 'iso8601',
#     'temperature_2m_max': '°C',
#     'temperature_2m_min': '°C'},
#    'daily': {'time': ['2025-11-08',
#      '2025-11-09',
#      '2025-11-10',
#      '2025-11-11',
#      '2025-11-12',
#      '2025-11-13'],
#     'temperature_2m_max': [29.5, 29.5, 27.5, 19.3, 23.4, 24.5],
#     'temperature_2m_min': [22.2, 22.5, 20.7, 9.0, 11.2, 14.7]}}}}

# %% [markdown]
# ## Visual Crossing client
# Visual Crossing uses the Timeline Weather API and requires an API key provided in `weather_config.json`.

# %%
from clients.visual_crossing_client import VisualCrossingClient

visual_crossing = VisualCrossingClient(config_path="../weather_config.json")
visual_crossing.base_url
# Out:
# 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline'

# %% [markdown]
# ## Visual Crossing forecast example
# Retrieves upcoming conditions for the configured coordinates, including current, daily, and hourly data segments.

# %%
visual_crossing_forecasts = {}
# Limit to first location to reduce API cost/quota
first = next(iter_locations())
name, lat, lon = first
request = {
    "location": f"{lat},{lon}",
    "start": None,
    "end": None,
    "include": ["hours"],
    "unit_group": "metric",
}
try:
    single = visual_crossing.get_forecast(**request)
except Exception as e:
    single = {"error": str(e)}
try:
    batch = visual_crossing.get_forecast_batch([request])[0]
except Exception as e:
    batch = {"error": str(e)}
visual_crossing_forecasts[name] = {"single": single, "batch": batch}
visual_crossing_forecasts
# Out:
# {'new_york_ny': {'single': {'queryCost': 1,
#    'latitude': 40.78,
#    'longitude': -73.97,
#    'resolvedAddress': '40.78,-73.97',
#    'address': '40.78,-73.97',
#    'timezone': 'America/New_York',
#    'tzoffset': -5.0,
#    'days': [{'datetime': '2025-11-12',
#      'datetimeEpoch': 1762923600,
#      'tempmax': 9.4,
#      'tempmin': 3.4,
#      'temp': 6.6,
#      'feelslikemax': 8.7,
#      'feelslikemin': -1.1,
#      'feelslike': 4.3,
#      'dew': -4.3,
#      'humidity': 45.9,
#      'precip': 0.0,
#      'precipprob': 2.0,
#      'precipcover': 0.0,
#      'preciptype': None,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'windgust': 51.8,
#      'windspeed': 26.0,
#      'winddir': 246.5,
#      'pressure': 1009.2,
#      'cloudcover': 83.0,
#      'visibility': 16.0,
#      'solarradiation': 73.7,
#      'solarenergy': 6.3,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'sunrise': '06:39:45',
#      'sunriseEpoch': 1762947585,
#      'sunset': '16:40:02',
#      'sunsetEpoch': 1762983602,
#      'moonphase': 0.75,
#      'conditions': 'Partially cloudy',
#      'description': 'Partly cloudy throughout the day.',
#      'icon': 'partly-cloudy-day',
#      'stations': ['KTEB', 'KLGA', 'F8726', 'F1417', 'KNYC'],
#      'source': 'comb',
#      'hours': [{'datetime': '00:00:00',
#        'datetimeEpoch': 1762923600,
#        'temp': 4.4,
#        'feelslike': 0.6,
#        'humidity': 50.08,
#        'dew': -5.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 45.4,
#        'windspeed': 17.6,
#        'winddir': 250.0,
#        'pressure': 1012.3,
#        'visibility': 16.0,
#        'cloudcover': 87.4,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '01:00:00',
#        'datetimeEpoch': 1762927200,
#        'temp': 3.9,
#        'feelslike': -1.0,
#        'humidity': 47.87,
#        'dew': -6.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 48.2,
#        'windspeed': 26.0,
#        'winddir': 238.0,
#        'pressure': 1012.4,
#        'visibility': 16.0,
#        'cloudcover': 5.1,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '02:00:00',
#        'datetimeEpoch': 1762930800,
#        'temp': 3.4,
#        'feelslike': 0.3,
#        'humidity': 47.81,
#        'dew': -6.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 32.0,
#        'windspeed': 11.9,
#        'winddir': 245.0,
#        'pressure': 1012.4,
#        'visibility': 16.0,
#        'cloudcover': 5.1,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '03:00:00',
#        'datetimeEpoch': 1762934400,
#        'temp': 3.4,
#        'feelslike': -1.1,
#        'humidity': 49.52,
#        'dew': -6.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.9,
#        'windspeed': 20.9,
#        'winddir': 248.0,
#        'pressure': 1012.3,
#        'visibility': 16.0,
#        'cloudcover': 52.5,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '04:00:00',
#        'datetimeEpoch': 1762938000,
#        'temp': 3.4,
#        'feelslike': -0.2,
#        'humidity': 49.32,
#        'dew': -6.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 27.7,
#        'windspeed': 14.8,
#        'winddir': 240.0,
#        'pressure': 1011.8,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '05:00:00',
#        'datetimeEpoch': 1762941600,
#        'temp': 3.9,
#        'feelslike': 1.8,
#        'humidity': 46.04,
#        'dew': -6.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 29.5,
#        'windspeed': 8.0,
#        'winddir': 258.0,
#        'pressure': 1011.3,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '06:00:00',
#        'datetimeEpoch': 1762945200,
#        'temp': 3.9,
#        'feelslike': 1.7,
#        'humidity': 46.04,
#        'dew': -6.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.1,
#        'windspeed': 8.4,
#        'winddir': 243.0,
#        'pressure': 1010.8,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '07:00:00',
#        'datetimeEpoch': 1762948800,
#        'temp': 4.4,
#        'feelslike': 2.4,
#        'humidity': 44.38,
#        'dew': -6.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.5,
#        'windspeed': 8.1,
#        'winddir': 220.0,
#        'pressure': 1010.5,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 4.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '08:00:00',
#        'datetimeEpoch': 1762952400,
#        'temp': 4.9,
#        'feelslike': 3.7,
#        'humidity': 45.9,
#        'dew': -5.8,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.1,
#        'windspeed': 5.9,
#        'winddir': 202.0,
#        'pressure': 1009.9,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 29.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '09:00:00',
#        'datetimeEpoch': 1762956000,
#        'temp': 5.0,
#        'feelslike': 1.7,
#        'humidity': 44.26,
#        'dew': -6.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 29.5,
#        'windspeed': 14.9,
#        'winddir': 239.0,
#        'pressure': 1009.7,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 62.0,
#        'solarenergy': 0.2,
#        'uvindex': 1.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '10:00:00',
#        'datetimeEpoch': 1762959600,
#        'temp': 5.6,
#        'feelslike': 3.1,
#        'humidity': 45.85,
#        'dew': -5.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 42.5,
#        'windspeed': 11.6,
#        'winddir': 258.0,
#        'pressure': 1009.2,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 249.0,
#        'solarenergy': 0.9,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '11:00:00',
#        'datetimeEpoch': 1762963200,
#        'temp': 6.2,
#        'feelslike': 3.8,
#        'humidity': 44.22,
#        'dew': -5.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 44.3,
#        'windspeed': 11.4,
#        'winddir': 230.0,
#        'pressure': 1008.6,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 223.0,
#        'solarenergy': 0.8,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '12:00:00',
#        'datetimeEpoch': 1762966800,
#        'temp': 6.8,
#        'feelslike': 4.1,
#        'humidity': 42.48,
#        'dew': -5.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 31.2,
#        'windspeed': 13.8,
#        'winddir': 258.0,
#        'pressure': 1007.5,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 252.0,
#        'solarenergy': 0.9,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '13:00:00',
#        'datetimeEpoch': 1762970400,
#        'temp': 7.9,
#        'feelslike': 7.9,
#        'humidity': 41.58,
#        'dew': -4.4,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.5,
#        'windspeed': 1.3,
#        'winddir': 352.0,
#        'pressure': 1006.6,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 380.0,
#        'solarenergy': 1.4,
#        'uvindex': 4.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '14:00:00',
#        'datetimeEpoch': 1762974000,
#        'temp': 8.4,
#        'feelslike': 5.1,
#        'humidity': 38.12,
#        'dew': -5.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.5,
#        'windspeed': 22.3,
#        'winddir': 250.0,
#        'pressure': 1005.8,
#        'visibility': 16.0,
#        'cloudcover': 88.6,
#        'solarradiation': 330.0,
#        'solarenergy': 1.2,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '15:00:00',
#        'datetimeEpoch': 1762977600,
#        'temp': 8.9,
#        'feelslike': 7.6,
#        'humidity': 40.34,
#        'dew': -3.9,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 44.1,
#        'windspeed': 8.4,
#        'winddir': 255.0,
#        'pressure': 1006.2,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 148.0,
#        'solarenergy': 0.5,
#        'uvindex': 1.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '16:00:00',
#        'datetimeEpoch': 1762981200,
#        'temp': 8.9,
#        'feelslike': 7.6,
#        'humidity': 40.28,
#        'dew': -3.9,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 46.4,
#        'windspeed': 8.4,
#        'winddir': 248.0,
#        'pressure': 1006.7,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 58.0,
#        'solarenergy': 0.2,
#        'uvindex': 1.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '17:00:00',
#        'datetimeEpoch': 1762984800,
#        'temp': 8.9,
#        'feelslike': 7.0,
#        'humidity': 42.15,
#        'dew': -3.3,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 42.5,
#        'windspeed': 11.7,
#        'winddir': 232.0,
#        'pressure': 1006.8,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 9.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '18:00:00',
#        'datetimeEpoch': 1762988400,
#        'temp': 9.4,
#        'feelslike': 8.3,
#        'humidity': 42.33,
#        'dew': -2.8,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 40.7,
#        'windspeed': 8.0,
#        'winddir': 233.0,
#        'pressure': 1006.9,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 25.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '19:00:00',
#        'datetimeEpoch': 1762992000,
#        'temp': 9.4,
#        'feelslike': 8.7,
#        'humidity': 44.25,
#        'dew': -2.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.9,
#        'windspeed': 6.1,
#        'winddir': 228.0,
#        'pressure': 1007.5,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F8726', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '20:00:00',
#        'datetimeEpoch': 1762995600,
#        'temp': 9.4,
#        'feelslike': 8.1,
#        'humidity': 47.71,
#        'dew': -1.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 51.8,
#        'windspeed': 8.8,
#        'winddir': 258.0,
#        'pressure': 1007.9,
#        'visibility': 16.0,
#        'cloudcover': 98.2,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '21:00:00',
#        'datetimeEpoch': 1762999200,
#        'temp': 9.4,
#        'feelslike': 7.6,
#        'humidity': 54.12,
#        'dew': 0.6,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.5,
#        'windspeed': 12.0,
#        'winddir': 262.0,
#        'pressure': 1008.3,
#        'visibility': 16.0,
#        'cloudcover': 51.1,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '22:00:00',
#        'datetimeEpoch': 1763002800,
#        'temp': 9.4,
#        'feelslike': 7.9,
#        'humidity': 54.25,
#        'dew': 0.6,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 43.0,
#        'windspeed': 10.0,
#        'winddir': 270.0,
#        'pressure': 1008.8,
#        'visibility': 16.0,
#        'cloudcover': 51.1,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '23:00:00',
#        'datetimeEpoch': 1763006400,
#        'temp': 8.9,
#        'feelslike': 5.9,
#        'humidity': 53.64,
#        'dew': 0.0,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.1,
#        'windspeed': 20.5,
#        'winddir': 260.0,
#        'pressure': 1010.0,
#        'visibility': 16.2,
#        'cloudcover': 55.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'}]},
#     {'datetime': '2025-11-13',
#      'datetimeEpoch': 1763010000,
#      'tempmax': 10.6,
#      'tempmin': 5.0,
#      'temp': 7.8,
#      'feelslikemax': 10.6,
#      'feelslikemin': 1.2,
#      'feelslike': 4.9,
#      'dew': 0.0,
#      'humidity': 58.6,
#      'precip': 0.0,
#      'precipprob': 2.0,
#      'precipcover': 0.0,
#      'preciptype': None,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'windgust': 48.2,
#      'windspeed': 25.9,
#      'winddir': 280.2,
#      'pressure': 1012.4,
#      'cloudcover': 27.0,
#      'visibility': 16.3,
#      'solarradiation': 89.5,
#      'solarenergy': 7.7,
#      'uvindex': 4.0,
#      'severerisk': 10.0,
#      'sunrise': '06:40:56',
#      'sunriseEpoch': 1763034056,
#      'sunset': '16:39:08',
#      'sunsetEpoch': 1763069948,
#      'moonphase': 0.78,
#      'conditions': 'Partially cloudy',
#      'description': 'Partly cloudy throughout the day.',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst',
#      'hours': [{'datetime': '00:00:00',
#        'datetimeEpoch': 1763010000,
#        'temp': 8.9,
#        'feelslike': 6.1,
#        'humidity': 56.02,
#        'dew': 0.6,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 18.4,
#        'winddir': 260.0,
#        'pressure': 1010.0,
#        'visibility': 16.2,
#        'cloudcover': 47.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '01:00:00',
#        'datetimeEpoch': 1763013600,
#        'temp': 8.4,
#        'feelslike': 5.5,
#        'humidity': 57.95,
#        'dew': 0.6,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 18.4,
#        'winddir': 260.0,
#        'pressure': 1010.0,
#        'visibility': 16.2,
#        'cloudcover': 38.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '02:00:00',
#        'datetimeEpoch': 1763017200,
#        'temp': 7.8,
#        'feelslike': 4.7,
#        'humidity': 60.36,
#        'dew': 0.6,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 18.4,
#        'winddir': 260.0,
#        'pressure': 1009.0,
#        'visibility': 16.2,
#        'cloudcover': 28.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '03:00:00',
#        'datetimeEpoch': 1763020800,
#        'temp': 7.3,
#        'feelslike': 4.1,
#        'humidity': 65.21,
#        'dew': 1.2,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 18.4,
#        'winddir': 270.0,
#        'pressure': 1010.0,
#        'visibility': 16.2,
#        'cloudcover': 18.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '04:00:00',
#        'datetimeEpoch': 1763024400,
#        'temp': 6.2,
#        'feelslike': 2.7,
#        'humidity': 70.33,
#        'dew': 1.2,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 18.4,
#        'winddir': 270.0,
#        'pressure': 1010.0,
#        'visibility': 16.2,
#        'cloudcover': 8.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '05:00:00',
#        'datetimeEpoch': 1763028000,
#        'temp': 5.6,
#        'feelslike': 2.2,
#        'humidity': 73.31,
#        'dew': 1.2,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 16.6,
#        'winddir': 270.0,
#        'pressure': 1011.0,
#        'visibility': 16.3,
#        'cloudcover': 12.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '06:00:00',
#        'datetimeEpoch': 1763031600,
#        'temp': 5.0,
#        'feelslike': 1.5,
#        'humidity': 76.43,
#        'dew': 1.2,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 16.6,
#        'winddir': 260.0,
#        'pressure': 1011.0,
#        'visibility': 16.2,
#        'cloudcover': 16.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '07:00:00',
#        'datetimeEpoch': 1763035200,
#        'temp': 5.0,
#        'feelslike': 1.2,
#        'humidity': 76.43,
#        'dew': 1.2,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 18.4,
#        'winddir': 260.0,
#        'pressure': 1011.0,
#        'visibility': 16.3,
#        'cloudcover': 20.0,
#        'solarradiation': 3.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '08:00:00',
#        'datetimeEpoch': 1763038800,
#        'temp': 5.6,
#        'feelslike': 1.7,
#        'humidity': 70.21,
#        'dew': 0.6,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.9,
#        'windspeed': 20.5,
#        'winddir': 270.0,
#        'pressure': 1012.0,
#        'visibility': 16.3,
#        'cloudcover': 25.0,
#        'solarradiation': 140.0,
#        'solarenergy': 0.5,
#        'uvindex': 1.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '09:00:00',
#        'datetimeEpoch': 1763042400,
#        'temp': 6.7,
#        'feelslike': 2.9,
#        'humidity': 65.08,
#        'dew': 0.6,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 40.7,
#        'windspeed': 22.3,
#        'winddir': 280.0,
#        'pressure': 1012.0,
#        'visibility': 16.2,
#        'cloudcover': 31.0,
#        'solarradiation': 286.0,
#        'solarenergy': 1.0,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '10:00:00',
#        'datetimeEpoch': 1763046000,
#        'temp': 8.4,
#        'feelslike': 4.9,
#        'humidity': 55.49,
#        'dew': 0.0,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 44.3,
#        'windspeed': 24.1,
#        'winddir': 280.0,
#        'pressure': 1011.0,
#        'visibility': 16.2,
#        'cloudcover': 37.0,
#        'solarradiation': 368.0,
#        'solarenergy': 1.3,
#        'uvindex': 4.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '11:00:00',
#        'datetimeEpoch': 1763049600,
#        'temp': 9.5,
#        'feelslike': 6.3,
#        'humidity': 49.68,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 44.3,
#        'windspeed': 24.1,
#        'winddir': 280.0,
#        'pressure': 1012.0,
#        'visibility': 16.3,
#        'cloudcover': 40.0,
#        'solarradiation': 332.0,
#        'solarenergy': 1.2,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '12:00:00',
#        'datetimeEpoch': 1763053200,
#        'temp': 10.0,
#        'feelslike': 6.8,
#        'humidity': 48.04,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 46.4,
#        'windspeed': 25.9,
#        'winddir': 290.0,
#        'pressure': 1012.0,
#        'visibility': 16.2,
#        'cloudcover': 43.0,
#        'solarradiation': 280.0,
#        'solarenergy': 1.0,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '13:00:00',
#        'datetimeEpoch': 1763056800,
#        'temp': 10.6,
#        'feelslike': 10.6,
#        'humidity': 46.15,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 48.2,
#        'windspeed': 25.9,
#        'winddir': 290.0,
#        'pressure': 1012.0,
#        'visibility': 16.3,
#        'cloudcover': 47.0,
#        'solarradiation': 268.0,
#        'solarenergy': 1.0,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '14:00:00',
#        'datetimeEpoch': 1763060400,
#        'temp': 10.6,
#        'feelslike': 10.6,
#        'humidity': 44.17,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 46.4,
#        'windspeed': 25.9,
#        'winddir': 290.0,
#        'pressure': 1011.0,
#        'visibility': 16.3,
#        'cloudcover': 40.0,
#        'solarradiation': 155.0,
#        'solarenergy': 0.6,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '15:00:00',
#        'datetimeEpoch': 1763064000,
#        'temp': 10.6,
#        'feelslike': 10.6,
#        'humidity': 44.17,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 46.4,
#        'windspeed': 24.1,
#        'winddir': 290.0,
#        'pressure': 1012.0,
#        'visibility': 16.2,
#        'cloudcover': 34.0,
#        'solarradiation': 152.0,
#        'solarenergy': 0.5,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '16:00:00',
#        'datetimeEpoch': 1763067600,
#        'temp': 10.0,
#        'feelslike': 7.0,
#        'humidity': 45.98,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 44.3,
#        'windspeed': 24.1,
#        'winddir': 290.0,
#        'pressure': 1013.0,
#        'visibility': 16.2,
#        'cloudcover': 28.0,
#        'solarradiation': 77.0,
#        'solarenergy': 0.3,
#        'uvindex': 1.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '17:00:00',
#        'datetimeEpoch': 1763071200,
#        'temp': 8.9,
#        'feelslike': 5.7,
#        'humidity': 49.51,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 42.5,
#        'windspeed': 22.3,
#        'winddir': 290.0,
#        'pressure': 1014.0,
#        'visibility': 16.3,
#        'cloudcover': 24.0,
#        'solarradiation': 35.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '18:00:00',
#        'datetimeEpoch': 1763074800,
#        'temp': 8.4,
#        'feelslike': 5.3,
#        'humidity': 51.21,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 1.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 40.7,
#        'windspeed': 20.5,
#        'winddir': 290.0,
#        'pressure': 1015.0,
#        'visibility': 16.3,
#        'cloudcover': 21.0,
#        'solarradiation': 28.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '19:00:00',
#        'datetimeEpoch': 1763078400,
#        'temp': 7.8,
#        'feelslike': 4.7,
#        'humidity': 55.73,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.9,
#        'windspeed': 18.4,
#        'winddir': 290.0,
#        'pressure': 1016.0,
#        'visibility': 16.3,
#        'cloudcover': 18.0,
#        'solarradiation': 23.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '20:00:00',
#        'datetimeEpoch': 1763082000,
#        'temp': 7.3,
#        'feelslike': 4.1,
#        'humidity': 57.67,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.1,
#        'windspeed': 18.4,
#        'winddir': 290.0,
#        'pressure': 1016.0,
#        'visibility': 16.3,
#        'cloudcover': 18.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '21:00:00',
#        'datetimeEpoch': 1763085600,
#        'temp': 6.7,
#        'feelslike': 3.4,
#        'humidity': 60.09,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 18.4,
#        'winddir': 290.0,
#        'pressure': 1015.0,
#        'visibility': 16.3,
#        'cloudcover': 19.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '22:00:00',
#        'datetimeEpoch': 1763089200,
#        'temp': 6.2,
#        'feelslike': 2.7,
#        'humidity': 62.19,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 18.4,
#        'winddir': 290.0,
#        'pressure': 1016.0,
#        'visibility': 16.3,
#        'cloudcover': 19.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '23:00:00',
#        'datetimeEpoch': 1763092800,
#        'temp': 5.6,
#        'feelslike': 2.0,
#        'humidity': 64.83,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.5,
#        'windspeed': 18.4,
#        'winddir': 290.0,
#        'pressure': 1016.0,
#        'visibility': 16.3,
#        'cloudcover': 18.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'}]},
#     {'datetime': '2025-11-14',
#      'datetimeEpoch': 1763096400,
#      'tempmax': 9.5,
#      'tempmin': 3.4,
#      'temp': 6.4,
#      'feelslikemax': 6.5,
#      'feelslikemin': -0.5,
#      'feelslike': 3.0,
#      'dew': -1.1,
#      'humidity': 59.7,
#      'precip': 0.0,
#      'precipprob': 3.0,
#      'precipcover': 0.0,
#      'preciptype': None,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'windgust': 38.9,
#      'windspeed': 24.1,
#      'winddir': 301.8,
#      'pressure': 1016.3,
#      'cloudcover': 34.1,
#      'visibility': 16.3,
#      'solarradiation': 105.9,
#      'solarenergy': 9.2,
#      'uvindex': 3.0,
#      'severerisk': 10.0,
#      'sunrise': '06:42:07',
#      'sunriseEpoch': 1763120527,
#      'sunset': '16:38:17',
#      'sunsetEpoch': 1763156297,
#      'moonphase': 0.81,
#      'conditions': 'Partially cloudy',
#      'description': 'Partly cloudy throughout the day.',
#      'icon': 'partly-cloudy-day',
#      'stations': None,
#      'source': 'fcst',
#      'hours': [{'datetime': '00:00:00',
#        'datetimeEpoch': 1763096400,
#        'temp': 5.6,
#        'feelslike': 2.2,
#        'humidity': 64.83,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 31.3,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1016.0,
#        'visibility': 16.3,
#        'cloudcover': 17.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '01:00:00',
#        'datetimeEpoch': 1763100000,
#        'temp': 5.0,
#        'feelslike': 1.5,
#        'humidity': 67.59,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 31.3,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1016.0,
#        'visibility': 16.3,
#        'cloudcover': 16.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '02:00:00',
#        'datetimeEpoch': 1763103600,
#        'temp': 4.5,
#        'feelslike': 0.9,
#        'humidity': 69.99,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 29.5,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1017.0,
#        'visibility': 16.2,
#        'cloudcover': 15.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '03:00:00',
#        'datetimeEpoch': 1763107200,
#        'temp': 4.5,
#        'feelslike': 0.9,
#        'humidity': 69.99,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 29.5,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1017.0,
#        'visibility': 16.2,
#        'cloudcover': 15.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '04:00:00',
#        'datetimeEpoch': 1763110800,
#        'temp': 4.5,
#        'feelslike': 0.9,
#        'humidity': 69.99,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 29.5,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1017.0,
#        'visibility': 16.3,
#        'cloudcover': 14.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '05:00:00',
#        'datetimeEpoch': 1763114400,
#        'temp': 3.9,
#        'feelslike': 0.1,
#        'humidity': 72.99,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 29.5,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1017.0,
#        'visibility': 16.3,
#        'cloudcover': 18.0,
#        'solarradiation': 1.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '06:00:00',
#        'datetimeEpoch': 1763118000,
#        'temp': 3.4,
#        'feelslike': -0.5,
#        'humidity': 75.61,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 27.7,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1018.0,
#        'visibility': 16.3,
#        'cloudcover': 22.0,
#        'solarradiation': 3.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '07:00:00',
#        'datetimeEpoch': 1763121600,
#        'temp': 3.4,
#        'feelslike': -0.5,
#        'humidity': 75.61,
#        'dew': -0.5,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 27.7,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1019.0,
#        'visibility': 16.3,
#        'cloudcover': 26.0,
#        'solarradiation': 4.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '08:00:00',
#        'datetimeEpoch': 1763125200,
#        'temp': 4.5,
#        'feelslike': 0.9,
#        'humidity': 66.99,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 29.5,
#        'windspeed': 16.6,
#        'winddir': 290.0,
#        'pressure': 1018.0,
#        'visibility': 16.3,
#        'cloudcover': 28.0,
#        'solarradiation': 111.0,
#        'solarenergy': 0.4,
#        'uvindex': 1.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '09:00:00',
#        'datetimeEpoch': 1763128800,
#        'temp': 6.2,
#        'feelslike': 2.7,
#        'humidity': 59.52,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.5,
#        'windspeed': 18.4,
#        'winddir': 290.0,
#        'pressure': 1018.0,
#        'visibility': 16.3,
#        'cloudcover': 31.0,
#        'solarradiation': 218.0,
#        'solarenergy': 0.8,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '10:00:00',
#        'datetimeEpoch': 1763132400,
#        'temp': 7.8,
#        'feelslike': 4.5,
#        'humidity': 53.34,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 2.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 20.5,
#        'winddir': 300.0,
#        'pressure': 1018.0,
#        'visibility': 16.3,
#        'cloudcover': 34.0,
#        'solarradiation': 325.0,
#        'solarenergy': 1.2,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '11:00:00',
#        'datetimeEpoch': 1763136000,
#        'temp': 8.4,
#        'feelslike': 5.1,
#        'humidity': 51.21,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 3.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 36.4,
#        'windspeed': 21.6,
#        'winddir': 300.0,
#        'pressure': 1017.0,
#        'visibility': 16.3,
#        'cloudcover': 42.7,
#        'solarradiation': 313.0,
#        'solarenergy': 1.1,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '12:00:00',
#        'datetimeEpoch': 1763139600,
#        'temp': 8.9,
#        'feelslike': 5.6,
#        'humidity': 49.51,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 3.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.8,
#        'windspeed': 23.0,
#        'winddir': 300.0,
#        'pressure': 1016.0,
#        'visibility': 16.3,
#        'cloudcover': 51.3,
#        'solarradiation': 300.0,
#        'solarenergy': 1.1,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '13:00:00',
#        'datetimeEpoch': 1763143200,
#        'temp': 9.5,
#        'feelslike': 6.3,
#        'humidity': 47.55,
#        'dew': -1.1,
#        'precip': 0.0,
#        'precipprob': 3.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.9,
#        'windspeed': 24.1,
#        'winddir': 300.0,
#        'pressure': 1015.0,
#        'visibility': 16.3,
#        'cloudcover': 60.0,
#        'solarradiation': 288.0,
#        'solarenergy': 1.0,
#        'uvindex': 3.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '14:00:00',
#        'datetimeEpoch': 1763146800,
#        'temp': 9.5,
#        'feelslike': 6.4,
#        'humidity': 46.86,
#        'dew': -1.3,
#        'precip': 0.0,
#        'precipprob': 3.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.2,
#        'windspeed': 23.4,
#        'winddir': 303.3,
#        'pressure': 1015.0,
#        'visibility': 16.3,
#        'cloudcover': 57.7,
#        'solarradiation': 246.0,
#        'solarenergy': 0.9,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '15:00:00',
#        'datetimeEpoch': 1763150400,
#        'temp': 9.5,
#        'feelslike': 6.4,
#        'humidity': 46.51,
#        'dew': -1.4,
#        'precip': 0.0,
#        'precipprob': 3.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.8,
#        'windspeed': 23.0,
#        'winddir': 306.7,
#        'pressure': 1015.0,
#        'visibility': 16.3,
#        'cloudcover': 55.3,
#        'solarradiation': 204.0,
#        'solarenergy': 0.7,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '16:00:00',
#        'datetimeEpoch': 1763154000,
#        'temp': 9.5,
#        'feelslike': 6.5,
#        'humidity': 45.83,
#        'dew': -1.6,
#        'precip': 0.0,
#        'precipprob': 3.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.1,
#        'windspeed': 22.3,
#        'winddir': 310.0,
#        'pressure': 1015.0,
#        'visibility': 16.3,
#        'cloudcover': 53.0,
#        'solarradiation': 162.0,
#        'solarenergy': 0.6,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '17:00:00',
#        'datetimeEpoch': 1763157600,
#        'temp': 8.6,
#        'feelslike': 5.6,
#        'humidity': 49.42,
#        'dew': -1.4,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 19.8,
#        'winddir': 313.3,
#        'pressure': 1015.0,
#        'visibility': 16.3,
#        'cloudcover': 48.3,
#        'solarradiation': 131.0,
#        'solarenergy': 0.5,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '18:00:00',
#        'datetimeEpoch': 1763161200,
#        'temp': 7.6,
#        'feelslike': 4.6,
#        'humidity': 53.29,
#        'dew': -1.3,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.1,
#        'windspeed': 17.3,
#        'winddir': 316.7,
#        'pressure': 1015.0,
#        'visibility': 16.3,
#        'cloudcover': 43.7,
#        'solarradiation': 99.0,
#        'solarenergy': 0.4,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
# ...
#        'temp': 6.4,
#        'feelslike': 4.6,
#        'humidity': 93.97,
#        'dew': 5.5,
#        'precip': 0.0,
#        'precipprob': 12.9,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 28.1,
#        'windspeed': 8.6,
#        'winddir': 134.1,
#        'pressure': 1023.0,
#        'visibility': 10.0,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '02:00:00',
#        'datetimeEpoch': 1764140400,
#        'temp': 6.7,
#        'feelslike': 4.6,
#        'humidity': 93.98,
#        'dew': 5.8,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 30.6,
#        'windspeed': 10.4,
#        'winddir': 136.0,
#        'pressure': 1022.0,
#        'visibility': 8.8,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '03:00:00',
#        'datetimeEpoch': 1764144000,
#        'temp': 7.0,
#        'feelslike': 4.7,
#        'humidity': 94.65,
#        'dew': 6.2,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 32.8,
#        'windspeed': 11.9,
#        'winddir': 137.8,
#        'pressure': 1021.0,
#        'visibility': 7.6,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '04:00:00',
#        'datetimeEpoch': 1764147600,
#        'temp': 7.3,
#        'feelslike': 4.7,
#        'humidity': 94.66,
#        'dew': 6.5,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 13.7,
#        'winddir': 139.7,
#        'pressure': 1020.0,
#        'visibility': 6.4,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '05:00:00',
#        'datetimeEpoch': 1764151200,
#        'temp': 7.5,
#        'feelslike': 5.0,
#        'humidity': 95.32,
#        'dew': 6.8,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 36.4,
#        'windspeed': 13.7,
#        'winddir': 136.0,
#        'pressure': 1019.0,
#        'visibility': 6.7,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '06:00:00',
#        'datetimeEpoch': 1764154800,
#        'temp': 7.8,
#        'feelslike': 5.3,
#        'humidity': 95.33,
#        'dew': 7.1,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.4,
#        'windspeed': 13.7,
#        'winddir': 132.4,
#        'pressure': 1018.0,
#        'visibility': 7.0,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '07:00:00',
#        'datetimeEpoch': 1764158400,
#        'temp': 8.0,
#        'feelslike': 5.6,
#        'humidity': 95.99,
#        'dew': 7.4,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.5,
#        'windspeed': 13.7,
#        'winddir': 128.7,
#        'pressure': 1017.0,
#        'visibility': 7.3,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '08:00:00',
#        'datetimeEpoch': 1764162000,
#        'temp': 8.4,
#        'feelslike': 6.3,
#        'humidity': 97.32,
#        'dew': 8.0,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 36.7,
#        'windspeed': 12.2,
#        'winddir': 124.8,
#        'pressure': 1016.0,
#        'visibility': 5.1,
#        'cloudcover': 100.0,
#        'solarradiation': 2.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '09:00:00',
#        'datetimeEpoch': 1764165600,
#        'temp': 8.9,
#        'feelslike': 7.2,
#        'humidity': 97.33,
#        'dew': 8.5,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 35.3,
#        'windspeed': 10.4,
#        'winddir': 121.0,
#        'pressure': 1015.0,
#        'visibility': 2.8,
#        'cloudcover': 100.0,
#        'solarradiation': 3.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '10:00:00',
#        'datetimeEpoch': 1764169200,
#        'temp': 9.3,
#        'feelslike': 7.9,
#        'humidity': 98.66,
#        'dew': 9.1,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.5,
#        'windspeed': 9.0,
#        'winddir': 117.1,
#        'pressure': 1014.0,
#        'visibility': 0.6,
#        'cloudcover': 100.0,
#        'solarradiation': 5.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'fog',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '11:00:00',
#        'datetimeEpoch': 1764172800,
#        'temp': 9.3,
#        'feelslike': 7.9,
#        'humidity': 98.66,
#        'dew': 9.1,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 28.1,
#        'windspeed': 9.0,
#        'winddir': 85.2,
#        'pressure': 1013.0,
#        'visibility': 0.5,
#        'cloudcover': 100.0,
#        'solarradiation': 8.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'fog',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '12:00:00',
#        'datetimeEpoch': 1764176400,
#        'temp': 9.2,
#        'feelslike': 7.9,
#        'humidity': 98.66,
#        'dew': 9.0,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 22.7,
#        'windspeed': 8.6,
#        'winddir': 53.4,
#        'pressure': 1011.0,
#        'visibility': 0.3,
#        'cloudcover': 100.0,
#        'solarradiation': 10.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'fog',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '13:00:00',
#        'datetimeEpoch': 1764180000,
#        'temp': 9.2,
#        'feelslike': 7.9,
#        'humidity': 98.66,
#        'dew': 9.0,
#        'precip': 0.0,
#        'precipprob': 9.7,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 17.3,
#        'windspeed': 8.6,
#        'winddir': 21.5,
#        'pressure': 1010.0,
#        'visibility': 0.2,
#        'cloudcover': 100.0,
#        'solarradiation': 13.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'fog',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '14:00:00',
#        'datetimeEpoch': 1764183600,
#        'temp': 9.2,
#        'feelslike': 8.1,
#        'humidity': 98.0,
#        'dew': 8.9,
#        'precip': 0.0,
#        'precipprob': 12.9,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 16.6,
#        'windspeed': 7.6,
#        'winddir': 116.1,
#        'pressure': 1010.0,
#        'visibility': 6.7,
#        'cloudcover': 100.0,
#        'solarradiation': 18.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '15:00:00',
#        'datetimeEpoch': 1764187200,
#        'temp': 9.3,
#        'feelslike': 8.4,
#        'humidity': 97.34,
#        'dew': 8.9,
#        'precip': 0.0,
#        'precipprob': 12.9,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 16.2,
#        'windspeed': 6.8,
#        'winddir': 210.7,
#        'pressure': 1010.0,
#        'visibility': 13.3,
#        'cloudcover': 100.0,
#        'solarradiation': 22.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '16:00:00',
#        'datetimeEpoch': 1764190800,
#        'temp': 9.3,
#        'feelslike': 8.7,
#        'humidity': 96.68,
#        'dew': 8.8,
#        'precip': 0.0,
#        'precipprob': 12.9,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 15.5,
#        'windspeed': 5.8,
#        'winddir': 305.3,
#        'pressure': 1010.0,
#        'visibility': 19.8,
#        'cloudcover': 100.0,
#        'solarradiation': 27.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '17:00:00',
#        'datetimeEpoch': 1764194400,
#        'temp': 9.2,
#        'feelslike': 8.6,
#        'humidity': 94.74,
#        'dew': 8.4,
#        'precip': 0.0,
#        'precipprob': 12.9,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 13.7,
#        'windspeed': 5.8,
#        'winddir': 289.8,
#        'pressure': 1010.0,
#        'visibility': 21.2,
#        'cloudcover': 100.0,
#        'solarradiation': 18.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '18:00:00',
#        'datetimeEpoch': 1764198000,
#        'temp': 9.1,
#        'feelslike': 8.6,
#        'humidity': 92.19,
#        'dew': 7.9,
#        'precip': 0.0,
#        'precipprob': 12.9,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 12.2,
#        'windspeed': 5.4,
#        'winddir': 274.4,
#        'pressure': 1011.0,
#        'visibility': 22.7,
#        'cloudcover': 100.0,
#        'solarradiation': 9.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '19:00:00',
#        'datetimeEpoch': 1764201600,
#        'temp': 9.0,
#        'feelslike': 8.5,
#        'humidity': 90.32,
#        'dew': 7.5,
#        'precip': 0.6,
#        'precipprob': 12.9,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': ['rain'],
#        'windgust': 10.4,
#        'windspeed': 5.4,
#        'winddir': 258.9,
#        'pressure': 1011.0,
#        'visibility': 24.1,
#        'cloudcover': 100.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '20:00:00',
#        'datetimeEpoch': 1764205200,
#        'temp': 9.0,
#        'feelslike': 7.7,
#        'humidity': 89.1,
#        'dew': 7.3,
#        'precip': 0.0,
#        'precipprob': 6.5,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 22.3,
#        'windspeed': 8.3,
#        'winddir': 279.0,
#        'pressure': 1011.0,
#        'visibility': 24.1,
#        'cloudcover': 77.2,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '21:00:00',
#        'datetimeEpoch': 1764208800,
#        'temp': 9.0,
#        'feelslike': 7.2,
#        'humidity': 88.49,
#        'dew': 7.2,
#        'precip': 0.0,
#        'precipprob': 6.5,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 34.6,
#        'windspeed': 11.2,
#        'winddir': 299.2,
#        'pressure': 1012.0,
#        'visibility': 24.1,
#        'cloudcover': 54.3,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '22:00:00',
#        'datetimeEpoch': 1764212400,
#        'temp': 9.0,
#        'feelslike': 6.8,
#        'humidity': 87.28,
#        'dew': 7.0,
#        'precip': 0.0,
#        'precipprob': 6.5,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 46.4,
#        'windspeed': 14.0,
#        'winddir': 319.3,
#        'pressure': 1012.0,
#        'visibility': 24.1,
#        'cloudcover': 31.5,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'},
#       {'datetime': '23:00:00',
#        'datetimeEpoch': 1764216000,
#        'temp': 8.6,
#        'feelslike': 6.0,
#        'humidity': 84.88,
#        'dew': 6.2,
#        'precip': 0.0,
#        'precipprob': 6.5,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 44.3,
#        'windspeed': 16.2,
#        'winddir': 317.7,
#        'pressure': 1013.0,
#        'visibility': 24.1,
#        'cloudcover': 54.3,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': None,
#        'source': 'fcst'}]}],
#    'stations': {'KLGA': {'distance': 6005.0,
#      'latitude': 40.77,
#      'longitude': -73.9,
#      'useCount': 0,
#      'id': 'KLGA',
#      'name': 'KLGA',
#      'quality': 100,
#      'contribution': 0.0},
#     'KTEB': {'distance': 10873.0,
#      'latitude': 40.85,
#      'longitude': -74.06,
#      'useCount': 0,
#      'id': 'KTEB',
#      'name': 'KTEB',
#      'quality': 100,
#      'contribution': 0.0},
#     'F8726': {'distance': 12173.0,
#      'latitude': 40.671,
#      'longitude': -73.981,
#      'useCount': 0,
#      'id': 'F8726',
#      'name': 'FW8726 Brooklyn NY US',
#      'quality': 0,
#      'contribution': 0.0},
#     'F1417': {'distance': 6312.0,
#      'latitude': 40.745,
#      'longitude': -74.029,
#      'useCount': 0,
#      'id': 'F1417',
#      'name': 'FW1417 Hoboken NJ US',
#      'quality': 0,
#      'contribution': 0.0},
#     'KNYC': {'distance': 1396.0,
#      'latitude': 40.77,
#      'longitude': -73.98,
#      'useCount': 0,
#      'id': 'KNYC',
#      'name': 'KNYC',
#      'quality': 100,
#      'contribution': 0.0}}}}}

# %% [markdown]
# ## Visual Crossing historical example
# Queries the previous 7 days using the timeline endpoint with explicit start and end dates.

# %%
visual_crossing_historical = {}
# Limit to first location and 1-day window to reduce API cost/quota
import datetime as dt
first = next(iter_locations())
name, lat, lon = first
start = dt.date.today() - dt.timedelta(days=2)
end = start
request = {
    "location": f"{lat},{lon}",
    "start": start,
    "end": end,
    "include": ["hours"],
    "unit_group": "metric",
}
try:
    single = visual_crossing.get_historical(**request)
except Exception as e:
    single = {"error": str(e)}
try:
    batch = visual_crossing.get_historical_batch([request])[0]
except Exception as e:
    batch = {"error": str(e)}
visual_crossing_historical[name] = {"single": single, "batch": batch}
visual_crossing_historical
# Out:
# {'new_york_ny': {'single': {'queryCost': 24,
#    'latitude': 40.78,
#    'longitude': -73.97,
#    'resolvedAddress': '40.78,-73.97',
#    'address': '40.78,-73.97',
#    'timezone': 'America/New_York',
#    'tzoffset': -5.0,
#    'days': [{'datetime': '2025-11-11',
#      'datetimeEpoch': 1762837200,
#      'tempmax': 5.0,
#      'tempmin': 0.7,
#      'temp': 2.9,
#      'feelslikemax': 2.0,
#      'feelslikemin': -4.9,
#      'feelslike': -1.2,
#      'dew': -6.4,
#      'humidity': 50.4,
#      'precip': 0.0,
#      'precipprob': 0.0,
#      'precipcover': 0.0,
#      'preciptype': None,
#      'snow': 0.0,
#      'snowdepth': 0.0,
#      'windgust': 56.8,
#      'windspeed': 35.4,
#      'winddir': 273.4,
#      'pressure': 1007.2,
#      'cloudcover': 85.2,
#      'visibility': 16.0,
#      'solarradiation': 75.4,
#      'solarenergy': 6.5,
#      'uvindex': 6.0,
#      'severerisk': 10.0,
#      'sunrise': '06:38:33',
#      'sunriseEpoch': 1762861113,
#      'sunset': '16:40:57',
#      'sunsetEpoch': 1762897257,
#      'moonphase': 0.71,
#      'conditions': 'Partially cloudy',
#      'description': 'Partly cloudy throughout the day.',
#      'icon': 'partly-cloudy-day',
#      'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#      'source': 'obs',
#      'hours': [{'datetime': '00:00:00',
#        'datetimeEpoch': 1762837200,
#        'temp': 1.8,
#        'feelslike': -2.9,
#        'humidity': 49.61,
#        'dew': -7.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 37.8,
#        'windspeed': 18.9,
#        'winddir': 280.0,
#        'pressure': 1006.0,
#        'visibility': 16.0,
#        'cloudcover': 27.8,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '01:00:00',
#        'datetimeEpoch': 1762840800,
#        'temp': 1.2,
#        'feelslike': -4.9,
#        'humidity': 53.69,
#        'dew': -7.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 51.1,
#        'windspeed': 29.5,
#        'winddir': 290.0,
#        'pressure': 1005.9,
#        'visibility': 16.0,
#        'cloudcover': 1.3,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '02:00:00',
#        'datetimeEpoch': 1762844400,
#        'temp': 1.2,
#        'feelslike': -3.0,
#        'humidity': 51.54,
#        'dew': -7.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 36.3,
#        'windspeed': 15.1,
#        'winddir': 281.0,
#        'pressure': 1006.0,
#        'visibility': 16.0,
#        'cloudcover': 85.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '03:00:00',
#        'datetimeEpoch': 1762848000,
#        'temp': 1.2,
#        'feelslike': -2.7,
#        'humidity': 49.49,
#        'dew': -8.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.8,
#        'windspeed': 13.5,
#        'winddir': 272.0,
#        'pressure': 1005.9,
#        'visibility': 16.0,
#        'cloudcover': 86.1,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '04:00:00',
#        'datetimeEpoch': 1762851600,
#        'temp': 1.2,
#        'feelslike': -2.0,
#        'humidity': 51.27,
#        'dew': -7.8,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 44.6,
#        'windspeed': 10.3,
#        'winddir': 299.0,
#        'pressure': 1005.7,
#        'visibility': 16.0,
#        'cloudcover': 1.3,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Clear',
#        'icon': 'clear-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '05:00:00',
#        'datetimeEpoch': 1762855200,
#        'temp': 1.2,
#        'feelslike': -1.5,
#        'humidity': 51.33,
#        'dew': -7.8,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 27.7,
#        'windspeed': 8.4,
#        'winddir': 271.0,
#        'pressure': 1005.5,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '06:00:00',
#        'datetimeEpoch': 1762858800,
#        'temp': 1.2,
#        'feelslike': -2.7,
#        'humidity': 55.73,
#        'dew': -6.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 32.2,
#        'windspeed': 13.7,
#        'winddir': 279.0,
#        'pressure': 1005.0,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '07:00:00',
#        'datetimeEpoch': 1762862400,
#        'temp': 0.7,
#        'feelslike': -3.0,
#        'humidity': 57.76,
#        'dew': -6.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 45.2,
#        'windspeed': 12.0,
#        'winddir': 285.0,
#        'pressure': 1005.4,
#        'visibility': 16.0,
#        'cloudcover': 88.0,
#        'solarradiation': 32.0,
#        'solarenergy': 0.1,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '08:00:00',
#        'datetimeEpoch': 1762866000,
#        'temp': 1.2,
#        'feelslike': -3.4,
#        'humidity': 60.25,
#        'dew': -5.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 36.1,
#        'windspeed': 17.5,
#        'winddir': 289.0,
#        'pressure': 1006.1,
#        'visibility': 15.9,
#        'cloudcover': 99.2,
#        'solarradiation': 54.0,
#        'solarenergy': 0.2,
#        'uvindex': 1.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '09:00:00',
#        'datetimeEpoch': 1762869600,
#        'temp': 2.2,
#        'feelslike': -3.5,
#        'humidity': 45.97,
#        'dew': -8.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 53.8,
#        'windspeed': 29.5,
#        'winddir': 288.0,
#        'pressure': 1006.2,
#        'visibility': 16.0,
#        'cloudcover': 88.0,
#        'solarradiation': 224.0,
#        'solarenergy': 0.8,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-day',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '10:00:00',
#        'datetimeEpoch': 1762873200,
#        'temp': 2.9,
#        'feelslike': -0.8,
#        'humidity': 45.56,
#        'dew': -7.8,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 46.8,
#        'windspeed': 14.3,
#        'winddir': 280.0,
#        'pressure': 1006.4,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 212.0,
#        'solarenergy': 0.8,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '11:00:00',
#        'datetimeEpoch': 1762876800,
#        'temp': 2.9,
#        'feelslike': -2.0,
#        'humidity': 49.29,
#        'dew': -6.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 46.6,
#        'windspeed': 23.0,
#        'winddir': 242.0,
#        'pressure': 1006.4,
#        'visibility': 15.9,
#        'cloudcover': 100.0,
#        'solarradiation': 152.0,
#        'solarenergy': 0.5,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '12:00:00',
#        'datetimeEpoch': 1762880400,
#        'temp': 2.9,
#        'feelslike': -3.2,
#        'humidity': 51.54,
#        'dew': -6.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 56.8,
#        'windspeed': 35.4,
#        'winddir': 265.0,
#        'pressure': 1006.0,
#        'visibility': 15.9,
#        'cloudcover': 99.4,
#        'solarradiation': 617.0,
#        'solarenergy': 2.2,
#        'uvindex': 6.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '13:00:00',
#        'datetimeEpoch': 1762884000,
#        'temp': 3.9,
#        'feelslike': 1.0,
#        'humidity': 44.31,
#        'dew': -7.2,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.7,
#        'windspeed': 11.3,
#        'winddir': 270.0,
#        'pressure': 1005.4,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 102.0,
#        'solarenergy': 0.4,
#        'uvindex': 1.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '14:00:00',
#        'datetimeEpoch': 1762887600,
#        'temp': 3.9,
#        'feelslike': 0.0,
#        'humidity': 42.32,
#        'dew': -7.8,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 47.3,
#        'windspeed': 17.5,
#        'winddir': 279.0,
#        'pressure': 1005.6,
#        'visibility': 16.0,
#        'cloudcover': 100.0,
#        'solarradiation': 211.0,
#        'solarenergy': 0.8,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '15:00:00',
#        'datetimeEpoch': 1762891200,
#        'temp': 3.9,
#        'feelslike': -1.2,
#        'humidity': 44.53,
#        'dew': -7.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 47.4,
#        'windspeed': 28.4,
#        'winddir': 281.0,
#        'pressure': 1005.9,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 192.0,
#        'solarenergy': 0.7,
#        'uvindex': 2.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '16:00:00',
#        'datetimeEpoch': 1762894800,
#        'temp': 4.4,
#        'feelslike': 0.8,
#        'humidity': 46.37,
#        'dew': -6.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 49.1,
#        'windspeed': 16.1,
#        'winddir': 271.0,
#        'pressure': 1006.7,
#        'visibility': 16.0,
#        'cloudcover': 99.2,
#        'solarradiation': 12.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '17:00:00',
#        'datetimeEpoch': 1762898400,
#        'temp': 4.4,
#        'feelslike': -0.4,
#        'humidity': 48.09,
#        'dew': -5.7,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 52.4,
#        'windspeed': 26.4,
#        'winddir': 271.0,
#        'pressure': 1007.7,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 2.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '18:00:00',
#        'datetimeEpoch': 1762902000,
#        'temp': 4.4,
#        'feelslike': 0.2,
#        'humidity': 50.16,
#        'dew': -5.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 48.5,
#        'windspeed': 21.0,
#        'winddir': 280.0,
#        'pressure': 1009.1,
#        'visibility': 16.0,
#        'cloudcover': 99.2,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '19:00:00',
#        'datetimeEpoch': 1762905600,
#        'temp': 4.9,
#        'feelslike': 1.8,
#        'humidity': 52.64,
#        'dew': -3.9,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 30.6,
#        'windspeed': 14.2,
#        'winddir': 260.0,
#        'pressure': 1010.0,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '20:00:00',
#        'datetimeEpoch': 1762909200,
#        'temp': 4.4,
#        'feelslike': 0.9,
#        'humidity': 57.28,
#        'dew': -3.3,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.8,
#        'windspeed': 15.4,
#        'winddir': 279.0,
#        'pressure': 1010.7,
#        'visibility': 16.0,
#        'cloudcover': 88.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '21:00:00',
#        'datetimeEpoch': 1762912800,
#        'temp': 5.0,
#        'feelslike': 2.0,
#        'humidity': 52.6,
#        'dew': -3.9,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 43.3,
#        'windspeed': 13.7,
#        'winddir': 270.0,
#        'pressure': 1011.3,
#        'visibility': 16.0,
#        'cloudcover': 99.2,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '22:00:00',
#        'datetimeEpoch': 1762916400,
#        'temp': 4.9,
#        'feelslike': 1.8,
#        'humidity': 48.26,
#        'dew': -5.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 33.5,
#        'windspeed': 14.0,
#        'winddir': 241.0,
#        'pressure': 1011.7,
#        'visibility': 16.0,
#        'cloudcover': 99.4,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Overcast',
#        'icon': 'cloudy',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'},
#       {'datetime': '23:00:00',
#        'datetimeEpoch': 1762920000,
#        'temp': 4.4,
#        'feelslike': 0.1,
#        'humidity': 50.21,
#        'dew': -5.1,
#        'precip': 0.0,
#        'precipprob': 0.0,
#        'snow': 0.0,
#        'snowdepth': 0.0,
#        'preciptype': None,
#        'windgust': 38.9,
#        'windspeed': 21.4,
#        'winddir': 240.0,
#        'pressure': 1011.9,
#        'visibility': 16.0,
#        'cloudcover': 88.0,
#        'solarradiation': 0.0,
#        'solarenergy': 0.0,
#        'uvindex': 0.0,
#        'severerisk': 10.0,
#        'conditions': 'Partially cloudy',
#        'icon': 'partly-cloudy-night',
#        'stations': ['KTEB', 'KLGA', 'F1417', 'KNYC'],
#        'source': 'obs'}]}],
#    'stations': {'KLGA': {'distance': 6005.0,
#      'latitude': 40.77,
#      'longitude': -73.9,
#      'useCount': 0,
#      'id': 'KLGA',
#      'name': 'KLGA',
#      'quality': 100,
#      'contribution': 0.0},
#     'KTEB': {'distance': 10873.0,
#      'latitude': 40.85,
#      'longitude': -74.06,
#      'useCount': 0,
#      'id': 'KTEB',
#      'name': 'KTEB',
#      'quality': 100,
#      'contribution': 0.0},
#     'F1417': {'distance': 6312.0,
#      'latitude': 40.745,
#      'longitude': -74.029,
#      'useCount': 0,
#      'id': 'F1417',
#      'name': 'FW1417 Hoboken NJ US',
#      'quality': 0,
#      'contribution': 0.0},
#     'KNYC': {'distance': 1396.0,
#      'latitude': 40.77,
#      'longitude': -73.98,
#      'useCount': 0,
#      'id': 'KNYC',
#      'name': 'KNYC',
#      'quality': 100,
#      'contribution': 0.0}}},
#   'batch': clients.visual_crossing_client.ApiError('Visual Crossing error 429: Maximum daily cost exceeded')}}

# %% [markdown]
# ## NOAA ISD client
# Integrated Surface Database (global-hourly) via the Access Data Service.

# %%
noaa_isd = NoaaIsdClient(config_path="../weather_config.json")
noaa_isd.base_url, noaa_isd.dataset
# Out:
# ('https://www.ncei.noaa.gov/access/services/data/v1', 'global-hourly')

# %% [markdown]
# ## NOAA ISD observation example
# Fetch the past 24 hours of hourly observations for each configured location.

# %%
import datetime as dt

DEMO_NOAA_ISD_START = dt.datetime(2024, 3, 1, tzinfo=dt.timezone.utc)
DEMO_NOAA_ISD_END = DEMO_NOAA_ISD_START + dt.timedelta(days=1)

noaa_isd_results = {}
for name, *_coords in iter_locations():
    station_id = LOCATIONS.get(name, {}).get('noaaIsdStation')
    if not station_id:
        print(f"{name}: missing 'noaaIsdStation'; skipping.")
        continue
    payload = noaa_isd.get_observations(
        station_id=station_id,
        start_time=DEMO_NOAA_ISD_START,
        end_time=DEMO_NOAA_ISD_END,
    )
    noaa_isd_results[name] = payload
    print(f"{name}: {len(payload)} ISD rows for {DEMO_NOAA_ISD_START.date()}")

sample_isd_city, sample_isd_payload = next(iter(noaa_isd_results.items()))
pd.DataFrame(sample_isd_payload)[['DATE', 'TMP', 'DEW', 'WND']].head()
# Out:
# new_york_ny: 26 ISD rows for 2024-03-01
# austin_tx: 47 ISD rows for 2024-03-01
# chicago_midway_il: 30 ISD rows for 2024-03-01
# los_angeles_ca: 41 ISD rows for 2024-03-01
# miami_fl: 36 ISD rows for 2024-03-01
#                   DATE      TMP      DEW             WND
# 0  2024-03-01T00:51:00  +0033,5  -0100,5  290,5,N,0021,5
# 1  2024-03-01T01:51:00  +0022,5  -0117,5  290,5,N,0026,5
# 2  2024-03-01T02:51:00  +0017,5  -0117,5  999,9,V,0015,5
# 3  2024-03-01T03:51:00  +0017,5  -0117,5  300,5,N,0036,5
# 4  2024-03-01T04:51:00  +0011,5  -0117,5  999,9,V,0021,5

# %% [markdown]
# ## NOAA LCD observation example
# Hourly Local Climatological Data via the same access service.

# %%
import datetime as dt

DEMO_NOAA_LCD_START = dt.datetime(2024, 3, 1, tzinfo=dt.timezone.utc)
DEMO_NOAA_LCD_END = DEMO_NOAA_LCD_START + dt.timedelta(days=1)

noaa_lcd = NoaaLcdClient(config_path="../weather_config.json")
noaa_lcd_results = {}
for name, *_coords in iter_locations():
    station_id = LOCATIONS.get(name, {}).get('noaaLcdStation')
    if not station_id:
        print(f"{name}: missing 'noaaLcdStation'; skipping.")
        continue
    payload = noaa_lcd.get_observations(
        station_id=station_id,
        start_time=DEMO_NOAA_LCD_START,
        end_time=DEMO_NOAA_LCD_END,
    )
    noaa_lcd_results[name] = payload
    print(f"{name}: {len(payload)} LCD rows for {DEMO_NOAA_LCD_START.date()}")
# Out:
# new_york_ny: 25 LCD rows for 2024-03-01
# austin_tx: 41 LCD rows for 2024-03-01
# chicago_midway_il: 29 LCD rows for 2024-03-01
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[25], line 13
#      11     print(f"{name}: missing 'noaaLcdStation'; skipping.")
#      12     continue
# ---> 13 payload = noaa_lcd.get_observations(
#      14     station_id=station_id,
#      15     start_time=DEMO_NOAA_LCD_START,
#      16     end_time=DEMO_NOAA_LCD_END,
#      17 )
#      18 noaa_lcd_results[name] = payload
#      19 print(f"{name}: {len(payload)} LCD rows for {DEMO_NOAA_LCD_START.date()}")
#
# File D:\DL Project\clients\noaa_access_client.py:130, in NoaaAccessClient.get_observations(self, station_id, start_time, end_time, data_types, units, options)
#     128 for key, value in effective_options.items():
#     129     params[key] = value
# --> 130 return self._request(params)
#
# File D:\DL Project\clients\noaa_access_client.py:92, in NoaaAccessClient._request(self, params)
#      90 response = requests.get(self.base_url, params=query, headers=headers, timeout=60)
#      91 if response.status_code >= 400:
# ---> 92     raise ApiError(f"NOAA access error {response.status_code}: {response.text}")
#      93 if self.response_format.lower() == "json":
#      94     data = response.json()
#
# ApiError: NOAA access error 503: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>

# %%
sample_lcd_city, sample_lcd_payload = next(iter(noaa_lcd_results.items()))
pd.DataFrame(sample_lcd_payload)[["DATE", "HourlyDryBulbTemperature", "HourlyDewPointTemperature"]].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sample_lcd_city, sample_lcd_payload = next(iter(noaa_lcd_results.items()))
#       2 pd.DataFrame(sample_lcd_payload)[["DATE", "HourlyDryBulbTemperature", "HourlyDewPointTemperature"]].head()
#
# NameError: name 'noaa_lcd_results' is not defined

# %% [markdown]
# ## Meteostat client
# Hourly observations via the Meteostat Python library (Point API).

# %%
meteostat_client = MeteostatClient(config_path="../weather_config.json")

# %%
import datetime as dt
METEOSTAT_DEMO_START = dt.datetime(2024, 3, 1)
METEOSTAT_DEMO_END = METEOSTAT_DEMO_START + dt.timedelta(days=1)
meteostat_results = {}
for name, lat, lon in iter_locations():
    payload = meteostat_client.get_hourly(
        location=(lat, lon),
        start_time=METEOSTAT_DEMO_START,
        end_time=METEOSTAT_DEMO_END,
    )
    meteostat_results[name] = payload
    print(f"{name}: {len(payload)} Meteostat rows for {METEOSTAT_DEMO_START.date()}")
sample_meteostat_city, sample_meteostat_payload = next(iter(meteostat_results.items()))
pd.DataFrame(sample_meteostat_payload)[['timestamp', 'temp', 'dwpt']].head()
# Out:
# new_york_ny: 25 Meteostat rows for 2024-03-01
# austin_tx: 25 Meteostat rows for 2024-03-01
# chicago_midway_il: 25 Meteostat rows for 2024-03-01
# los_angeles_ca: 25 Meteostat rows for 2024-03-01
# miami_fl: 25 Meteostat rows for 2024-03-01
#             timestamp  temp  dwpt
# 0 2024-03-01 00:00:00   3.0 -10.3
# 1 2024-03-01 01:00:00   3.3  -9.3
# 2 2024-03-01 02:00:00   3.3 -10.0
# 3 2024-03-01 03:00:00   2.0 -11.5
# 4 2024-03-01 04:00:00   1.0 -11.7

# %% [markdown]
# ## NASA POWER client
# NASA POWER hourly API via REST.

# %%
nasa_power = NasaPowerClient(config_path="../weather_config.json")

# %%
import datetime as dt

NASA_DEMO_START = dt.datetime(2024, 3, 1)
NASA_DEMO_END = NASA_DEMO_START + dt.timedelta(days=1)

nasa_power_results = {}
for name, lat, lon in iter_locations():
    payload = nasa_power.get_hourly(
        location=(lat, lon),
        start_time=NASA_DEMO_START,
        end_time=NASA_DEMO_END,
    )
    nasa_power_results[name] = payload
    count = 0
    props = payload.get('properties', {}) if isinstance(payload, dict) else {}
    param_block = props.get('parameter', {})
    if param_block:
        first_param = next(iter(param_block.values()))
        count = len(first_param)
    print(f"{name}: {count} NASA POWER rows for {NASA_DEMO_START.date()}")

sample_nasa_city, sample_nasa_payload = next(iter(nasa_power_results.items()))
parameters = sample_nasa_payload.get('properties', {}).get('parameter', {})
rows = {}
for param, series in parameters.items():
    for stamp, value in series.items():
        rows.setdefault(stamp, {})[param] = value
records = []
for stamp, values in rows.items():
    ts = dt.datetime.strptime(stamp, '%Y%m%d%H')
    values = dict(values)
    values['timestamp'] = ts
    records.append(values)
pd.DataFrame(records)[['timestamp', 'T2M', 'RH2M', 'WS10M']].head()
# Out:
# new_york_ny: 48 NASA POWER rows for 2024-03-01
# austin_tx: 48 NASA POWER rows for 2024-03-01
# chicago_midway_il: 48 NASA POWER rows for 2024-03-01
# los_angeles_ca: 48 NASA POWER rows for 2024-03-01
# miami_fl: 48 NASA POWER rows for 2024-03-01
#             timestamp   T2M   RH2M  WS10M
# 0 2024-03-01 00:00:00 -2.25  82.05   3.62
# 1 2024-03-01 01:00:00 -2.98  85.25   3.30
# 2 2024-03-01 02:00:00 -3.44  87.24   3.04
# 3 2024-03-01 03:00:00 -3.62  87.88   2.84
# 4 2024-03-01 04:00:00 -3.78  89.09   2.62

# %% [markdown]
# ## Copernicus ERA5 datasets
# Four CDS-backed providers are configured: ERA5 single levels, ERA5-Land, ERA5 pressure levels, and ERA5-Land time-series. Each provider uses its own bounding box metadata in `weather_config.json`. The cell below loops through all four providers and fetches a one-day sample for every configured location.

# %%
from clients.noaa_access_client import NoaaIsdClient, NoaaLcdClient
from clients.meteostat_client import MeteostatClient
from clients.nasa_power_client import NasaPowerClient
from clients.iem_asos_client import IemAsosClient
from clients.copernicus_cds_client import CopernicusCdsClient

from IPython.display import display
import datetime as dt

COPERNICUS_DEMOS = [
    {
        "label": "ERA5 single levels",
        "provider": "copernicus_era5_single",
        "area_attr": "copernicusEra5Area",
        "date": dt.date(2024, 1, 1),
    },
    {
        "label": "ERA5-Land",
        "provider": "copernicus_era5_land",
        "area_attr": "copernicusEra5LandArea",
        "date": dt.date(2024, 1, 1),
    },
    {
        "label": "ERA5 pressure levels",
        "provider": "copernicus_era5_pressure",
        "area_attr": "copernicusEra5Area",
        "date": dt.date(2024, 1, 1),
    },
    {
        "label": "ERA5-Land time-series",
        "provider": "copernicus_era5_land_timeseries",
        "area_attr": None,
        "date": dt.date(2024, 1, 1),
    },
]


def _run_copernicus_demo(cfg):
    client = CopernicusCdsClient(config_path="../weather_config.json", provider=cfg["provider"])
    results = {}
    for name, lat, lon in iter_locations():
        extras = LOCATIONS.get(name, {})
        area_attr = cfg.get("area_attr")
        area = extras.get(area_attr) if area_attr else None
        if area_attr and not area:
            print(f"{cfg['label']} -> {name}: missing {area_attr}; skipping.")
            continue
        payload = client.get_dataset(
            area=area,
            start_date=cfg["date"],
            end_date=cfg["date"],
            latitude=lat,
            longitude=lon,
        )
        results[name] = payload
        length = 0 if payload is None else len(payload)
        print(f"{cfg['label']} -> {name}: {length} rows on {cfg['date']}")
    return results


def _preview_dataframe(df):
    cols = [col for col in ("timestamp", "pressure_level", "t2m", "tp", "temperature", "u10", "v10") if col in df.columns]
    if not cols:
        cols = list(df.columns[:5])
    return df[cols].head()

copernicus_results = {}
for cfg in COPERNICUS_DEMOS:
    print(f"=== {cfg['label']} ===")
    copernicus_results[cfg["provider"]] = _run_copernicus_demo(cfg)

for provider_key, results in copernicus_results.items():
    sample_item = next(((city, payload) for city, payload in results.items() if payload is not None and not payload.empty), None)
    if sample_item:
        city, payload = sample_item
        print(f"Sample preview for {provider_key} ({city})")
        display(_preview_dataframe(payload))
    else:
        print(f"No sample data to preview for {provider_key}.")
# Out:
# === ERA5 single levels ===
# ERA5 single levels -> new_york_ny: 24 rows on 2024-01-01
# ERA5 single levels -> austin_tx: 24 rows on 2024-01-01
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[30], line 70
#      68 for cfg in COPERNICUS_DEMOS:
#      69     print(f"=== {cfg['label']} ===")
# ---> 70     copernicus_results[cfg["provider"]] = _run_copernicus_demo(cfg)
#      72 for provider_key, results in copernicus_results.items():
#      73     sample_item = next(((city, payload) for city, payload in results.items() if payload is not None and not payload.empty), None)
#
# Cell In[30], line 48, in _run_copernicus_demo(cfg)
#      46     print(f"{cfg['label']} -> {name}: missing {area_attr}; skipping.")
#      47     continue
# ---> 48 payload = client.get_dataset(
#      49     area=area,
#      50     start_date=cfg["date"],
#      51     end_date=cfg["date"],
#      52     latitude=lat,
#      53     longitude=lon,
#      54 )
#      55 results[name] = payload
#      56 length = 0 if payload is None else len(payload)
#
# File D:\DL Project\clients\copernicus_cds_client.py:238, in CopernicusCdsClient.get_dataset(self, area, start_date, end_date, latitude, longitude, variables)
#     236 tmp_path = tempfile.mktemp(suffix=tmp_suffix)
#     237 try:
# --> 238     self.client.retrieve(self.dataset, request, tmp_path)
#     239     dataset_path = self._extract_dataset_path(tmp_path)
#     240     if self.format.lower() == "csv" and self.mode == "land_timeseries":
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\legacy_client.py:167, in LegacyClient.retrieve(self, name, request, target)
#     165 submitted: datastores.Remote | datastores.Results
#     166 if self.wait_until_complete:
# --> 167     submitted = self.client.submit_and_wait_on_results(
#     168         collection_id=name,
#     169         request=request,
#     170     )
#     171 else:
#     172     submitted = self.client.submit(
#     173         collection_id=name,
#     174         request=request,
#     175     )
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\client.py:414, in Client.submit_and_wait_on_results(self, collection_id, request)
#     398 def submit_and_wait_on_results(
#     399     self, collection_id: str, request: dict[str, Any]
#     400 ) -> datastores.Results:
#     401     """Submit a request and wait for the results to be ready.
#     402
#     403     Parameters
#    (...)
#     412     datastores.Results
#     413     """
# --> 414     return self._retrieve_api.submit(collection_id, request).get_results()
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:495, in Remote.get_results(self)
#     488 def get_results(self) -> Results:
#     489     """Retrieve results.
#     490
#     491     Returns
#     492     -------
#     493     datastores.Results
#     494     """
# --> 495     return self._make_results(wait=True)
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:479, in Remote._make_results(self, wait)
#     477 def _make_results(self, wait: bool) -> Results:
#     478     if wait:
# --> 479         self._wait_on_results()
#     480     response = self._get_api_response("get")
#     481     try:
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:457, in Remote._wait_on_results(self)
#     455 def _wait_on_results(self) -> None:
#     456     sleep = 1.0
# --> 457     while not self.results_ready:
#     458         self.debug(f"results not ready, waiting for {sleep} seconds")
#     459         time.sleep(sleep)
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:465, in Remote.results_ready(self)
#     462 @property
#     463 def results_ready(self) -> bool:
#     464     """Check if results are ready."""
# --> 465     status = self.status
#     466     if status == "successful":
#     467         return True
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:424, in Remote.status(self)
#     421 @property
#     422 def status(self) -> str:
#     423     """Request status."""
# --> 424     reply = self.json
#     425     self._log_metadata(reply.get("metadata", {}))
#     427     status = reply["status"]
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:409, in Remote.json(self)
#     407 if self.log_start_time:
#     408     params["logStartTime"] = self.log_start_time
# --> 409 return self._get_api_response("get", params=params)._json_dict
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:394, in Remote._get_api_response(self, method, **kwargs)
#     393 def _get_api_response(self, method: str, **kwargs: Any) -> ApiResponse:
# --> 394     return ApiResponse.from_request(
#     395         method, self.url, **self._request_kwargs, **kwargs
#     396     )
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:176, in ApiResponse.from_request(cls, method, url, headers, session, retry_options, request_options, download_options, sleep_max, cleanup, log_callback, log_messages, **kwargs)
#     171 response = robust_request(
#     172     method, url, headers=headers, **request_options, **kwargs
#     173 )
#     174 log(logging.DEBUG, f"REPLY {response.text}", callback=log_callback)
# --> 176 cads_raise_for_status(response)
#     178 self = cls(
#     179     response,
#     180     headers=headers,
#    (...)
#     187     log_callback=log_callback,
#     188 )
#     189 if log_messages:
#
# File d:\DL Project\.venv\lib\site-packages\ecmwf\datastores\processing.py:100, in cads_raise_for_status(response)
#      93         message = "\n".join(
#      94             [
#      95                 f"{response.status_code} Client Error: {response.reason} for url: {response.url}",
#      96                 error_json_to_message(error_json),
#      97             ]
#      98         )
#      99         raise requests.HTTPError(message, response=response)
# --> 100 response.raise_for_status()
#
# File d:\DL Project\.venv\lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/466fc410-bce4-44a8-8ce2-0dee350b1748?log=True&request=True

# %% [markdown]
# ## IEM ASOS client
# Iowa Environmental Mesonet 1-minute ASOS data.

# %%
iem_asos = IemAsosClient(config_path="../weather_config.json")

# %%
import datetime as dt

IEM_DEMO_START = dt.datetime(2025, 1, 1)
IEM_DEMO_END = IEM_DEMO_START + dt.timedelta(days=1)

iem_results = {}
for name, *_coords in iter_locations():
    station = LOCATIONS.get(name, {}).get('iemStation')
    network = LOCATIONS.get(name, {}).get('iemNetwork')
    if not station or not network:
        print(f"{name}: missing IEM metadata; skipping.")
        continue
    payload = iem_asos.get_observations(
        station=station,
        network=network,
        start_time=IEM_DEMO_START,
        end_time=IEM_DEMO_END,
    )
    iem_results[name] = payload
    length = 0 if payload is None else len(payload)
    print(f"{name}: {length} IEM rows for {IEM_DEMO_START.date()}")

sample_item = next(((city, payload) for city, payload in iem_results.items() if payload is not None and not payload.empty), None)
if sample_item:
    sample_city, sample_payload = sample_item
    pd.DataFrame(sample_payload)[['timestamp', 'tmpf', 'dwpf', 'sknt']].head()
else:
    print('No IEM sample data available.')
# Out:
# new_york_ny: 1130 IEM rows for 2025-01-01
# austin_tx: 937 IEM rows for 2025-01-01
# chicago_midway_il: 1249 IEM rows for 2025-01-01
# los_angeles_ca: 960 IEM rows for 2025-01-01
# miami_fl: 1270 IEM rows for 2025-01-01

# %% [markdown]
# ## WeatherAPI.com client
# WeatherAPI.com uses API key authentication via query parameters; the key lives in `weather_config.json`.

# %%
from clients.weatherapi_com_client import WeatherApiClient

weatherapi = WeatherApiClient(config_path="../weather_config.json")
weatherapi.base_url
# Out:
# 'https://api.weatherapi.com/v1'

# %% [markdown]
# ## WeatherAPI.com forecast example
# Requests a 3-day forecast (includes hourly segments) for the configured coordinates.

# %%
weatherapi_forecasts = {}
for name, lat, lon in iter_locations():
    request = {
        "location": (lat, lon),
        "days": 3,
        "aqi": 'yes',
        "alerts": 'yes',
    }
    weatherapi_forecasts[name] = {
        "single": weatherapi.get_forecast(**request),
        "batch": weatherapi.get_forecast_batch([request])[0],
    }
weatherapi_forecasts
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File d:\DL Project\.venv\lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File D:\DL Project\clients\weatherapi_com_client.py:133, in WeatherApiClient._request(self, path, params)
#     132 try:
# --> 133     return response.json()
#     134 except ValueError as exc:
#
# File d:\DL Project\.venv\lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# ApiError                                  Traceback (most recent call last)
# Cell In[34], line 10
#       2 for name, lat, lon in iter_locations():
#       3     request = {
#       4         "location": (lat, lon),
#       5         "days": 3,
#       6         "aqi": 'yes',
#       7         "alerts": 'yes',
#       8     }
#       9     weatherapi_forecasts[name] = {
# ---> 10         "single": weatherapi.get_forecast(**request),
#      11         "batch": weatherapi.get_forecast_batch([request])[0],
#      12     }
#      13 weatherapi_forecasts
#
# File D:\DL Project\clients\weatherapi_com_client.py:180, in WeatherApiClient.get_forecast(self, location, days, start_date, end_date, unix_start, unix_end, hour, aqi, alerts, lang, tp)
#     178 if tp is not None:
#     179     params["tp"] = int(tp)
# --> 180 return self._request("forecast.json", params)
#
# File D:\DL Project\clients\weatherapi_com_client.py:135, in WeatherApiClient._request(self, path, params)
#     133     return response.json()
#     134 except ValueError as exc:
# --> 135     raise ApiError("WeatherAPI.com returned a non-JSON response.") from exc
#
# ApiError: WeatherAPI.com returned a non-JSON response.

# %% [markdown]
# ## WeatherAPI.com historical example
# Fetches hourly history for a single day (WeatherAPI supports one date per call on standard plans).

# %%
import datetime as dt
history_date = dt.date.today() - dt.timedelta(days=1)
weatherapi_history = {}
first = next(iter_locations())
name, lat, lon = first
request = {
    "location": (lat, lon),
    "date": history_date,
    "aqi": 'yes',
}
try:
    single = weatherapi.get_historical(**request)
except Exception as e:
    single = {"error": str(e)}
try:
    batch = weatherapi.get_historical_batch([request])[0]
except Exception as e:
    batch = {"error": str(e)}
weatherapi_history[name] = {"single": single, "batch": batch}
weatherapi_history
# Out:
# {'new_york_ny': {'single': {'error': "get_historical() got an unexpected keyword argument 'aqi'"},
#   'batch': TypeError("get_historical() got an unexpected keyword argument 'aqi'")}}

# %% [markdown]
# ## OpenWeather client
# OpenWeather current and historical APIs both rely on latitude/longitude plus an API key stored in `weather_config.json`.

# %%
import importlib
from clients import openweather_client as _openweather_module
importlib.reload(_openweather_module)
from clients.openweather_client import OpenWeatherClient

openweather = OpenWeatherClient(config_path="../weather_config.json")
openweather.current_url, openweather.history_url
# Out:
# ('https://api.openweathermap.org/data/2.5/weather',
#  'https://history.openweathermap.org/data/2.5/history/city')

# %% [markdown]
# ## OpenWeather current example
# Fetches the latest observations for the configured coordinates.

# %%
current_results = {}
for name, lat, lon in iter_locations():
    request = {
        "location": (lat, lon),
        "units": 'metric',
        "language": 'en',
    }
    current_results[name] = {
        "single": openweather.get_current(**request),
        "batch": openweather.get_current_batch([request])[0],
    }
current_results
# Out:
# {'new_york_ny': {'single': {'coord': {'lon': -73.97, 'lat': 40.78},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'base': 'stations',
#    'main': {'temp': 9.22,
#     'feels_like': 6.03,
#     'temp_min': 7.82,
#     'temp_max': 9.97,
#     'pressure': 1009,
#     'humidity': 62,
#     'sea_level': 1009,
#     'grnd_level': 1007},
#    'visibility': 10000,
#    'wind': {'speed': 6.69, 'deg': 260, 'gust': 11.32},
#    'clouds': {'all': 40},
#    'dt': 1763005957,
#    'sys': {'type': 1,
#     'id': 5141,
#     'country': 'US',
#     'sunrise': 1762947579,
#     'sunset': 1762983638},
#    'timezone': -18000,
#    'id': 5125771,
#    'name': 'Manhattan',
#    'cod': 200},
#   'batch': {'coord': {'lon': -73.97, 'lat': 40.78},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'base': 'stations',
#    'main': {'temp': 9.22,
#     'feels_like': 6.03,
#     'temp_min': 7.82,
#     'temp_max': 9.97,
#     'pressure': 1009,
#     'humidity': 62,
#     'sea_level': 1009,
#     'grnd_level': 1007},
#    'visibility': 10000,
#    'wind': {'speed': 6.69, 'deg': 260, 'gust': 11.32},
#    'clouds': {'all': 40},
#    'dt': 1763005957,
#    'sys': {'type': 1,
#     'id': 5141,
#     'country': 'US',
#     'sunrise': 1762947579,
#     'sunset': 1762983638},
#    'timezone': -18000,
#    'id': 5125771,
#    'name': 'Manhattan',
#    'cod': 200}},
#  'austin_tx': {'single': {'coord': {'lon': -97.68, 'lat': 30.18},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'base': 'stations',
#    'main': {'temp': 20.79,
#     'feels_like': 20.86,
#     'temp_min': 19.55,
#     'temp_max': 21.29,
#     'pressure': 1020,
#     'humidity': 74,
#     'sea_level': 1020,
#     'grnd_level': 999},
#    'visibility': 10000,
#    'wind': {'speed': 4.12, 'deg': 160},
#    'clouds': {'all': 0},
#    'dt': 1763005957,
#    'sys': {'type': 1,
#     'id': 3355,
#     'country': 'US',
#     'sunrise': 1762952038,
#     'sunset': 1762990561},
#    'timezone': -21600,
#    'id': 4716734,
#    'name': 'Onion Creek',
#    'cod': 200},
#   'batch': {'coord': {'lon': -97.68, 'lat': 30.18},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'base': 'stations',
#    'main': {'temp': 20.79,
#     'feels_like': 20.86,
#     'temp_min': 19.55,
#     'temp_max': 21.29,
#     'pressure': 1020,
#     'humidity': 74,
#     'sea_level': 1020,
#     'grnd_level': 999},
#    'visibility': 10000,
#    'wind': {'speed': 4.12, 'deg': 160},
#    'clouds': {'all': 0},
#    'dt': 1763005957,
#    'sys': {'type': 1,
#     'id': 3355,
#     'country': 'US',
#     'sunrise': 1762952038,
#     'sunset': 1762990561},
#    'timezone': -21600,
#    'id': 4716734,
#    'name': 'Onion Creek',
#    'cod': 200}},
#  'chicago_midway_il': {'single': {'coord': {'lon': -87.76, 'lat': 41.78},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'base': 'stations',
#    'main': {'temp': 7.06,
#     'feels_like': 4.37,
#     'temp_min': 5.9,
#     'temp_max': 7.83,
#     'pressure': 1018,
#     'humidity': 66,
#     'sea_level': 1018,
#     'grnd_level': 994},
#    'visibility': 10000,
#    'wind': {'speed': 4.03, 'deg': 290, 'gust': 12.22},
#    'clouds': {'all': 97},
#    'dt': 1763005957,
#    'sys': {'type': 2,
#     'id': 2085812,
#     'country': 'US',
#     'sunrise': 1762951028,
#     'sunset': 1762986809},
#    'timezone': -21600,
#    'id': 4888176,
#    'name': 'Clearing',
#    'cod': 200},
#   'batch': {'coord': {'lon': -87.76, 'lat': 41.78},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'base': 'stations',
#    'main': {'temp': 7.06,
#     'feels_like': 4.37,
#     'temp_min': 5.9,
#     'temp_max': 7.83,
#     'pressure': 1018,
#     'humidity': 66,
#     'sea_level': 1018,
#     'grnd_level': 994},
#    'visibility': 10000,
#    'wind': {'speed': 4.03, 'deg': 290, 'gust': 12.22},
#    'clouds': {'all': 97},
#    'dt': 1763005957,
#    'sys': {'type': 2,
#     'id': 2085812,
#     'country': 'US',
#     'sunrise': 1762951028,
#     'sunset': 1762986809},
#    'timezone': -21600,
#    'id': 4888176,
#    'name': 'Clearing',
#    'cod': 200}},
#  'los_angeles_ca': {'single': {'coord': {'lon': -118.39, 'lat': 33.94},
#    'weather': [{'id': 701,
#      'main': 'Mist',
#      'description': 'mist',
#      'icon': '50n'}],
#    'base': 'stations',
#    'main': {'temp': 17.18,
#     'feels_like': 17.28,
#     'temp_min': 16.55,
#     'temp_max': 19.46,
#     'pressure': 1017,
#     'humidity': 89,
#     'sea_level': 1017,
#     'grnd_level': 1012},
#    'visibility': 10000,
#    'wind': {'speed': 1.54, 'deg': 290},
#    'clouds': {'all': 75},
#    'dt': 1763005958,
#    'sys': {'type': 1,
#     'id': 4667,
#     'country': 'US',
#     'sunrise': 1762957412,
#     'sunset': 1762995129},
#    'timezone': -28800,
#    'id': 5342425,
#    'name': 'Del Aire',
#    'cod': 200},
#   'batch': {'coord': {'lon': -118.39, 'lat': 33.94},
#    'weather': [{'id': 701,
#      'main': 'Mist',
#      'description': 'mist',
#      'icon': '50n'}],
#    'base': 'stations',
#    'main': {'temp': 17.18,
#     'feels_like': 17.28,
#     'temp_min': 16.55,
#     'temp_max': 19.46,
#     'pressure': 1017,
#     'humidity': 89,
#     'sea_level': 1017,
#     'grnd_level': 1012},
#    'visibility': 10000,
#    'wind': {'speed': 1.54, 'deg': 290},
#    'clouds': {'all': 75},
#    'dt': 1763005958,
#    'sys': {'type': 1,
#     'id': 4667,
#     'country': 'US',
#     'sunrise': 1762957412,
#     'sunset': 1762995129},
#    'timezone': -28800,
#    'id': 5342425,
#    'name': 'Del Aire',
#    'cod': 200}},
#  'miami_fl': {'single': {'coord': {'lon': -80.32, 'lat': 25.79},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'base': 'stations',
#    'main': {'temp': 20.14,
#     'feels_like': 20.04,
#     'temp_min': 18.9,
#     'temp_max': 21.01,
#     'pressure': 1023,
#     'humidity': 70,
#     'sea_level': 1023,
#     'grnd_level': 1022},
#    'visibility': 10000,
#    'wind': {'speed': 3.09, 'deg': 340},
#    'clouds': {'all': 100},
#    'dt': 1763005958,
#    'sys': {'type': 1,
#     'id': 4896,
#     'country': 'US',
#     'sunrise': 1762947440,
#     'sunset': 1762986826},
#    'timezone': -18000,
#    'id': 4176550,
#    'name': 'Virginia Gardens',
#    'cod': 200},
#   'batch': {'coord': {'lon': -80.32, 'lat': 25.79},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'base': 'stations',
#    'main': {'temp': 20.14,
#     'feels_like': 20.04,
#     'temp_min': 18.9,
#     'temp_max': 21.01,
#     'pressure': 1023,
#     'humidity': 70,
#     'sea_level': 1023,
#     'grnd_level': 1022},
#    'visibility': 10000,
#    'wind': {'speed': 3.09, 'deg': 340},
#    'clouds': {'all': 100},
#    'dt': 1763005958,
#    'sys': {'type': 1,
#     'id': 4896,
#     'country': 'US',
#     'sunrise': 1762947440,
#     'sunset': 1762986826},
#    'timezone': -18000,
#    'id': 4176550,
#    'name': 'Virginia Gardens',
#    'cod': 200}}}

# %% [markdown]
# ## OpenWeather historical example
# Requests sub-hourly history for the last 24 hours (data is returned in hourly buckets).

# %%
import datetime as dt
ow_end = dt.datetime.now(dt.timezone.utc)
ow_start = ow_end - dt.timedelta(hours=24)
openweather_history = {}
first = next(iter_locations())
name, lat, lon = first
request = {
    "location": (lat, lon),
    "start_time": ow_start,
    "end_time": ow_end,
    "units": 'metric',
    "interval_type": 'hour',
}
try:
    single = openweather.get_historical(**request)
except Exception as e:
    single = {"error": str(e)}
try:
    batch = openweather.get_historical_batch([request])[0]
except Exception as e:
    batch = {"error": str(e)}
openweather_history[name] = {"single": single, "batch": batch}
openweather_history
# Out:
# {'new_york_ny': {'single': {'message': 'Count: 24',
#    'cod': '200',
#    'city_id': 1,
#    'calctime': 0.044515794,
#    'cnt': 24,
#    'list': [{'dt': 1762920000,
#      'main': {'temp': 4.22,
#       'feels_like': -1,
#       'pressure': 1013,
#       'humidity': 58,
#       'temp_min': 3.23,
#       'temp_max': 4.8},
#      'wind': {'speed': 8.49, 'deg': 250},
#      'clouds': {'all': 75},
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1762923600,
#      'main': {'temp': 4.15,
#       'feels_like': -1.33,
#       'pressure': 1013,
#       'humidity': 57,
#       'temp_min': 3.03,
#       'temp_max': 4.8},
#      'wind': {'speed': 9.26, 'deg': 250, 'gust': 16.98},
#      'clouds': {'all': 75},
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1762927200,
#      'main': {'temp': 3.73,
#       'feels_like': -1.38,
#       'pressure': 1013,
#       'humidity': 56,
#       'temp_min': 2.81,
#       'temp_max': 4.5},
#      'wind': {'speed': 7.72, 'deg': 240, 'gust': 13.38},
#      'clouds': {'all': 0},
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1762930800,
#      'main': {'temp': 3.47,
#       'feels_like': -1.33,
#       'pressure': 1013,
#       'humidity': 56,
#       'temp_min': 2.47,
#       'temp_max': 4.24},
#      'wind': {'speed': 6.69, 'deg': 230},
#      'clouds': {'all': 0},
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1762934400,
#      'main': {'temp': 3.33,
#       'feels_like': -1.51,
#       'pressure': 1013,
#       'humidity': 57,
#       'temp_min': 2.25,
#       'temp_max': 4.24},
#      'wind': {'speed': 6.69, 'deg': 270, 'gust': 9.77},
#      'clouds': {'all': 40},
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1762938000,
#      'main': {'temp': 3.43,
#       'feels_like': -0.95,
#       'pressure': 1012,
#       'humidity': 55,
#       'temp_min': 2.35,
#       'temp_max': 4.24},
#      'wind': {'speed': 5.66, 'deg': 270},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762941600,
#      'main': {'temp': 3.68,
#       'feels_like': -0.38,
#       'pressure': 1012,
#       'humidity': 53,
#       'temp_min': 2.47,
#       'temp_max': 4.38},
#      'wind': {'speed': 5.14, 'deg': 230},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762945200,
#      'main': {'temp': 3.88,
#       'feels_like': -0.6,
#       'pressure': 1011,
#       'humidity': 53,
#       'temp_min': 2.68,
#       'temp_max': 4.38},
#      'wind': {'speed': 6.17, 'deg': 250, 'gust': 10.29},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762948800,
#      'main': {'temp': 4.12,
#       'feels_like': 0.42,
#       'pressure': 1011,
#       'humidity': 52,
#       'temp_min': 2.68,
#       'temp_max': 4.94},
#      'wind': {'speed': 4.63, 'deg': 220, 'gust': 9.26},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762952400,
#      'main': {'temp': 4.61,
#       'feels_like': 1.12,
#       'pressure': 1011,
#       'humidity': 52,
#       'temp_min': 3.03,
#       'temp_max': 5.46},
#      'wind': {'speed': 4.47, 'deg': 220, 'gust': 8.94},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762956000,
#      'main': {'temp': 5,
#       'feels_like': 1.04,
#       'pressure': 1010,
#       'humidity': 52,
#       'temp_min': 3.65,
#       'temp_max': 5.9},
#      'wind': {'speed': 5.66, 'deg': 230},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762959600,
#      'main': {'temp': 5.38,
#       'feels_like': 1.75,
#       'pressure': 1009,
#       'humidity': 54,
#       'temp_min': 4.12,
#       'temp_max': 6.01},
#      'wind': {'speed': 5.14, 'deg': 220},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762963200,
#      'main': {'temp': 5.88,
#       'feels_like': 2.47,
#       'pressure': 1008,
#       'humidity': 53,
#       'temp_min': 4.72,
#       'temp_max': 6.79},
#      'wind': {'speed': 4.92, 'deg': 220},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762966800,
#      'main': {'temp': 6.82,
#       'feels_like': 2.79,
#       'pressure': 1007,
#       'humidity': 50,
#       'temp_min': 5.69,
#       'temp_max': 7.78},
#      'wind': {'speed': 7.2, 'deg': 260, 'gust': 9.77},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762970400,
#      'main': {'temp': 7.87,
#       'feels_like': 3.98,
#       'pressure': 1007,
#       'humidity': 48,
#       'temp_min': 6.99,
#       'temp_max': 8.85},
#      'wind': {'speed': 7.72, 'deg': 240, 'gust': 10.29},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762974000,
#      'main': {'temp': 8.65,
#       'feels_like': 5.03,
#       'pressure': 1006,
#       'humidity': 46,
#       'temp_min': 7.81,
#       'temp_max': 9.82},
#      'wind': {'speed': 7.6, 'deg': 216, 'gust': 9.83},
#      'clouds': {'all': 75},
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04d'}]},
#     {'dt': 1762977600,
#      'main': {'temp': 8.75,
#       'feels_like': 5.6,
#       'pressure': 1006,
#       'humidity': 48,
#       'temp_min': 7.81,
#       'temp_max': 9.4},
#      'wind': {'speed': 6.17, 'deg': 260, 'gust': 10.29},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762981200,
#      'main': {'temp': 8.9,
#       'feels_like': 5.79,
#       'pressure': 1006,
#       'humidity': 48,
#       'temp_min': 7.81,
#       'temp_max': 9.94},
#      'wind': {'speed': 6.17, 'deg': 260, 'gust': 12.86},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762984800,
#      'main': {'temp': 9.09,
#       'feels_like': 6.15,
#       'pressure': 1007,
#       'humidity': 49,
#       'temp_min': 7.81,
#       'temp_max': 9.94},
#      'wind': {'speed': 5.81, 'deg': 260, 'gust': 12.52},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762988400,
#      'main': {'temp': 9.31,
#       'feels_like': 6.88,
#       'pressure': 1007,
#       'humidity': 50,
#       'temp_min': 7.47,
#       'temp_max': 9.94},
#      'wind': {'speed': 4.63, 'deg': 240},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762992000,
#      'main': {'temp': 9.42,
#       'feels_like': 7.01,
#       'pressure': 1008,
#       'humidity': 52,
#       'temp_min': 7.35,
#       'temp_max': 10.36},
#      'wind': {'speed': 4.63, 'deg': 230},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762995600,
#      'main': {'temp': 9.53,
#       'feels_like': 6,
#       'pressure': 1008,
#       'humidity': 56,
#       'temp_min': 7.91,
#       'temp_max': 10.5},
#      'wind': {'speed': 8.23, 'deg': 260, 'gust': 14.4},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762999200,
#      'main': {'temp': 9.43,
#       'feels_like': 5.92,
#       'pressure': 1009,
#       'humidity': 60,
#       'temp_min': 8.23,
#       'temp_max': 10.5},
#      'wind': {'speed': 8.05, 'deg': 260, 'gust': 14.31},
#      'clouds': {'all': 40},
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1763002800,
#      'main': {'temp': 9.25,
#       'feels_like': 6.07,
#       'pressure': 1009,
#       'humidity': 62,
#       'temp_min': 8.23,
#       'temp_max': 9.94},
#      'wind': {'speed': 6.69, 'deg': 260, 'gust': 11.32},
#      'clouds': {'all': 40},
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]}]},
#   'batch': {'message': 'Count: 24',
#    'cod': '200',
#    'city_id': 1,
#    'calctime': 0.005080866,
#    'cnt': 24,
#    'list': [{'dt': 1762920000,
#      'main': {'temp': 4.22,
#       'feels_like': -1,
#       'pressure': 1013,
#       'humidity': 58,
#       'temp_min': 3.23,
#       'temp_max': 4.8},
#      'wind': {'speed': 8.49, 'deg': 250},
#      'clouds': {'all': 75},
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1762923600,
#      'main': {'temp': 4.15,
#       'feels_like': -1.33,
#       'pressure': 1013,
#       'humidity': 57,
#       'temp_min': 3.03,
#       'temp_max': 4.8},
#      'wind': {'speed': 9.26, 'deg': 250, 'gust': 16.98},
#      'clouds': {'all': 75},
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1762927200,
#      'main': {'temp': 3.73,
#       'feels_like': -1.38,
#       'pressure': 1013,
#       'humidity': 56,
#       'temp_min': 2.81,
#       'temp_max': 4.5},
#      'wind': {'speed': 7.72, 'deg': 240, 'gust': 13.38},
#      'clouds': {'all': 0},
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1762930800,
#      'main': {'temp': 3.47,
#       'feels_like': -1.33,
#       'pressure': 1013,
#       'humidity': 56,
#       'temp_min': 2.47,
#       'temp_max': 4.24},
#      'wind': {'speed': 6.69, 'deg': 230},
#      'clouds': {'all': 0},
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1762934400,
#      'main': {'temp': 3.33,
#       'feels_like': -1.51,
#       'pressure': 1013,
#       'humidity': 57,
#       'temp_min': 2.25,
#       'temp_max': 4.24},
#      'wind': {'speed': 6.69, 'deg': 270, 'gust': 9.77},
#      'clouds': {'all': 40},
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1762938000,
#      'main': {'temp': 3.43,
#       'feels_like': -0.95,
#       'pressure': 1012,
#       'humidity': 55,
#       'temp_min': 2.35,
#       'temp_max': 4.24},
#      'wind': {'speed': 5.66, 'deg': 270},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762941600,
#      'main': {'temp': 3.68,
#       'feels_like': -0.38,
#       'pressure': 1012,
#       'humidity': 53,
#       'temp_min': 2.47,
#       'temp_max': 4.38},
#      'wind': {'speed': 5.14, 'deg': 230},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762945200,
#      'main': {'temp': 3.88,
#       'feels_like': -0.6,
#       'pressure': 1011,
#       'humidity': 53,
#       'temp_min': 2.68,
#       'temp_max': 4.38},
#      'wind': {'speed': 6.17, 'deg': 250, 'gust': 10.29},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762948800,
#      'main': {'temp': 4.12,
#       'feels_like': 0.42,
#       'pressure': 1011,
#       'humidity': 52,
#       'temp_min': 2.68,
#       'temp_max': 4.94},
#      'wind': {'speed': 4.63, 'deg': 220, 'gust': 9.26},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762952400,
#      'main': {'temp': 4.61,
#       'feels_like': 1.12,
#       'pressure': 1011,
#       'humidity': 52,
#       'temp_min': 3.03,
#       'temp_max': 5.46},
#      'wind': {'speed': 4.47, 'deg': 220, 'gust': 8.94},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762956000,
#      'main': {'temp': 5,
#       'feels_like': 1.04,
#       'pressure': 1010,
#       'humidity': 52,
#       'temp_min': 3.65,
#       'temp_max': 5.9},
#      'wind': {'speed': 5.66, 'deg': 230},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762959600,
#      'main': {'temp': 5.38,
#       'feels_like': 1.75,
#       'pressure': 1009,
#       'humidity': 54,
#       'temp_min': 4.12,
#       'temp_max': 6.01},
#      'wind': {'speed': 5.14, 'deg': 220},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762963200,
#      'main': {'temp': 5.88,
#       'feels_like': 2.47,
#       'pressure': 1008,
#       'humidity': 53,
#       'temp_min': 4.72,
#       'temp_max': 6.79},
#      'wind': {'speed': 4.92, 'deg': 220},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762966800,
#      'main': {'temp': 6.82,
#       'feels_like': 2.79,
#       'pressure': 1007,
#       'humidity': 50,
#       'temp_min': 5.69,
#       'temp_max': 7.78},
#      'wind': {'speed': 7.2, 'deg': 260, 'gust': 9.77},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762970400,
#      'main': {'temp': 7.87,
#       'feels_like': 3.98,
#       'pressure': 1007,
#       'humidity': 48,
#       'temp_min': 6.99,
#       'temp_max': 8.85},
#      'wind': {'speed': 7.72, 'deg': 240, 'gust': 10.29},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762974000,
#      'main': {'temp': 8.65,
#       'feels_like': 5.03,
#       'pressure': 1006,
#       'humidity': 46,
#       'temp_min': 7.81,
#       'temp_max': 9.82},
#      'wind': {'speed': 7.6, 'deg': 216, 'gust': 9.83},
#      'clouds': {'all': 75},
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04d'}]},
#     {'dt': 1762977600,
#      'main': {'temp': 8.75,
#       'feels_like': 5.6,
#       'pressure': 1006,
#       'humidity': 48,
#       'temp_min': 7.81,
#       'temp_max': 9.4},
#      'wind': {'speed': 6.17, 'deg': 260, 'gust': 10.29},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762981200,
#      'main': {'temp': 8.9,
#       'feels_like': 5.79,
#       'pressure': 1006,
#       'humidity': 48,
#       'temp_min': 7.81,
#       'temp_max': 9.94},
#      'wind': {'speed': 6.17, 'deg': 260, 'gust': 12.86},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1762984800,
#      'main': {'temp': 9.09,
#       'feels_like': 6.15,
#       'pressure': 1007,
#       'humidity': 49,
#       'temp_min': 7.81,
#       'temp_max': 9.94},
#      'wind': {'speed': 5.81, 'deg': 260, 'gust': 12.52},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762988400,
#      'main': {'temp': 9.31,
#       'feels_like': 6.88,
#       'pressure': 1007,
#       'humidity': 50,
#       'temp_min': 7.47,
#       'temp_max': 9.94},
#      'wind': {'speed': 4.63, 'deg': 240},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762992000,
#      'main': {'temp': 9.42,
#       'feels_like': 7.01,
#       'pressure': 1008,
#       'humidity': 52,
#       'temp_min': 7.35,
#       'temp_max': 10.36},
#      'wind': {'speed': 4.63, 'deg': 230},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762995600,
#      'main': {'temp': 9.53,
#       'feels_like': 6,
#       'pressure': 1008,
#       'humidity': 56,
#       'temp_min': 7.91,
#       'temp_max': 10.5},
#      'wind': {'speed': 8.23, 'deg': 260, 'gust': 14.4},
#      'clouds': {'all': 100},
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1762999200,
#      'main': {'temp': 9.43,
#       'feels_like': 5.92,
#       'pressure': 1009,
#       'humidity': 60,
#       'temp_min': 8.23,
#       'temp_max': 10.5},
#      'wind': {'speed': 8.05, 'deg': 260, 'gust': 14.31},
#      'clouds': {'all': 40},
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1763002800,
#      'main': {'temp': 9.25,
#       'feels_like': 6.07,
#       'pressure': 1009,
#       'humidity': 62,
#       'temp_min': 8.23,
#       'temp_max': 9.94},
#      'wind': {'speed': 6.69, 'deg': 260, 'gust': 11.32},
#      'clouds': {'all': 40},
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]}]}}}

# %% [markdown]
# ## Weatherbit client
# Weatherbit exposes hourly forecast data and sub-hourly historical archives; the API key lives in `weather_config.json`.

# %%
from clients.weatherbit_client import WeatherbitClient

weatherbit = WeatherbitClient(config_path="../weather_config.json")
weatherbit.forecast_url
# Out:
# 'https://api.weatherbit.io/v2.0/forecast/hourly'

# %% [markdown]
# ## Weatherbit forecast example
# Requests the next 48 hours of hourly forecast data for the configured coordinates.

# %%
weatherbit_forecasts = {}
for name, lat, lon in iter_locations():
    request = {
        "location": (lat, lon),
        "hours": 48,
        "units": 'M',
    }
    weatherbit_forecasts[name] = {
        "single": weatherbit.get_forecast(**request),
        "batch": weatherbit.get_forecast_batch([request])[0],
    }
weatherbit_forecasts
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[40], line 9
#       2 for name, lat, lon in iter_locations():
#       3     request = {
#       4         "location": (lat, lon),
#       5         "hours": 48,
#       6         "units": 'M',
#       7     }
#       8     weatherbit_forecasts[name] = {
# ----> 9         "single": weatherbit.get_forecast(**request),
#      10         "batch": weatherbit.get_forecast_batch([request])[0],
#      11     }
#      12 weatherbit_forecasts
#
# File D:\DL Project\clients\weatherbit_client.py:129, in WeatherbitClient.get_forecast(self, location, hours, units, **extra_params)
#     127 if extra_params:
#     128     params.update(extra_params)
# --> 129 return self._request(self.forecast_url, params)
#
# File D:\DL Project\clients\weatherbit_client.py:103, in WeatherbitClient._request(self, url, params)
#     101 response = requests.get(url, params=query, timeout=30, headers=build_request_headers())
#     102 if response.status_code >= 400:
# --> 103     raise ApiError(f"Weatherbit error {response.status_code}: {response.text}")
#     104 try:
#     105     return response.json()
#
# ApiError: Weatherbit error 403: {"error":"Your API key does not allow access to this endpoint."}

# %% [markdown]
# ## Weatherbit historical example
# Fetches the previous 24 hours using the sub-hourly historical endpoint (UTC timestamps required).

# %%
import datetime as dt
wb_end = dt.datetime.now(dt.timezone.utc)
wb_start = wb_end - dt.timedelta(hours=24)
weatherbit_history = {}
first = next(iter_locations())
name, lat, lon = first
request = {
    "location": (lat, lon),
    "start_time": wb_start,
    "end_time": wb_end,
    "units": 'M',
    "tz": 'UTC',
}
try:
    single = weatherbit.get_historical(**request)
except Exception as e:
    single = {"error": str(e)}
try:
    batch = weatherbit.get_historical_batch([request])[0]
except Exception as e:
    batch = {"error": str(e)}
weatherbit_history[name] = {"single": single, "batch": batch}
weatherbit_history
# Out:
# {'new_york_ny': {'single': {'error': 'Weatherbit error 403: {"error":"Your API Key does not allow access to this endpoint."}\n'},
#   'batch': clients.weatherbit_client.ApiError('Weatherbit error 403: {"error":"Your API Key does not allow access to this endpoint."}\n')}}
